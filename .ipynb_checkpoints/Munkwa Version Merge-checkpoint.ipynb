# %%
import pandas as pd
import numpy as np
import re
import uuid

# %% [markdown]
# For Lee:
# * `bpid`: unique id for each person
# * `lee_uuid`: unique id for each instance of taking a test
# * `repeated_testtaker`: True if the person has taken the test multiple times in the SAME YEAR, False otherwise
#
#
# For WS:
# * `ws_uuid`: unique id for each instance of taking a test. Directly tied to `id1`
# * `repeated_testtaker`: True if the person has taken the test multiple times in the SAME YEAR, False otherwise
# * Currently no unique id for each person
#
#
# Goals:
# * Need to detect and merge the same person from both datafiles
# * Each instance of taking a test has a unique ID in each datafile
#
# Edge Cases:
# * One person takes exam multiple times in the same year. More instances in Lee than in WS --> Copy each person in WS to each instance in Lee
# * One person takes exam multiple times in the same year. More instances in WS than in Lee --> Add extra rows to merged file, copying each instance in Lee to match each instance in WS

# %% [markdown]
# ## Join the different tables of the Lee Version

# %%
bangmok = pd.read_csv('data/lee_bangmok.csv')
career = pd.read_csv('data/lee_bangmok_career.csv')
person = pd.read_csv('data/lee_bangmok_person.csv')
family = pd.read_csv('data/lee_bangmok_family.csv')

# %%
len(bangmok), len(career), len(person), len(family)
# Out:
# (15151, 15151, 14638, 70468)

# %%
# merge bangmok and career
bangmok_career = pd.merge(bangmok,career, on='bid', how='outer')

# %%
eq = bangmok_career['bpid_x'] == bangmok_career['bpid_y']
[i for i, x in enumerate(eq) if not x]

# This means we can merge these two columns
bangmok_career = bangmok_career.rename(columns={"bpid_x":"bpid"}).drop(columns=["bpid_y"])

# %%
# merge bankmok, career, person
bangmok_career_person = pd.merge(bangmok_career,person,on='bpid',how='left')

# %%
# Not sure how to merge family so will not do that for now
len(family['source']), len(family['source'].unique())
# Out:
# (70468, 14634)

# %%
data_lee = bangmok_career_person
len(data_lee), len(data_lee['bid'].unique())
# Out:
# (15151, 15151)

# %% [markdown]
# Create UUID for each unique BID. This UUID is based off of a hash from the BID, so it will be the same for each BID

# %%
data_lee['uuid'] = [uuid.uuid5(uuid.NAMESPACE_DNS,x) for x in data_lee['bid']]
data_lee = data_lee.set_index('uuid')
data_lee['lee_uuid'] = data_lee.index

# %%
# Verify there are no duplicates
data_lee[data_lee.duplicated()]
# Out:
# Empty DataFrame
# Columns: [bid, bpid, affilliation, rank, competitors, exam_type, pass_year, king, lid, previous, exam_class, class_rank, pass_date, bc_level, solardate, bcid, gid, chnname, korname, family_clan, birth, death, plastic, lee_uuid]
# Index: []
#
# [0 rows x 24 columns]

# %%
# These are the people who took the same example multiple times in the SAME YEAR 
# i.e. they are the duplicates of the korean name/chinese name/pass year. 
data_lee[data_lee[['korname', 'chnname', 'pass_year']].duplicated(keep=False)][['korname', 'chnname', 'pass_year']].sort_values(by=['pass_year', 'korname'])
# Out:
#                                      korname chnname  pass_year
# uuid
# bce827d1-0d70-5d9b-8c3e-47692a94056e     이승소     李承召       1447
# 4dd2ba02-6605-52de-aa90-baedc1786856     이승소     李承召       1447
# 8b8eb1bb-dd28-5ead-8e78-3396a662b7c8     정종소     鄭從韶       1447
# c11cc3b8-55a2-5c41-9cf3-4c1c7539a08f     정종소     鄭從韶       1447
# 1097cf4b-1483-525d-991c-e9d253237f05      황위      黃瑋       1580
# fb9f8d9a-698d-5f09-b69e-6aa9624e1550     황유중     黃有中       1514
# f0707d61-7b65-5817-a0d6-bd1aaee00e31     황유중     黃有中       1606
# 1d7e7cba-ad77-5cf1-8404-864a02e27476     황인하     黃仁夏       1849
# 07f288ec-4f20-57ef-9498-fb0cd70c23d1     황인하     黃仁夏       1866
# 5c763460-ed0f-55be-8cd9-6e6a72544d06     황치경     黃致敬       1580
# 6242deda-2002-5dad-a4ab-62525a879a96     황치경     黃致敬       1608
# ad68ca50-0a6a-5041-bebc-b5d7140867c8      황필      黃㻶       1492
# 3e0bf9da-07d1-5564-8a20-8801ba5dc9a9      황필      黃㻶       1497
# 116ac1fe-e3f5-5eb4-be69-51fcbe9b0a4f      황현      黃鉉       1393
# 0d0e52fe-977f-5af7-8a9d-54205aac783a      황현      黃鉉       1407

# %%
# Marking those who took the test more than once as such
data_lee['repeated_testtaker'] = data_lee[['korname', 'chnname','pass_year']].duplicated(keep=False)

# %%
# This is the Lee file
data_lee.to_csv('/Users/yenniejun/Documents/code/JoseonMunkwa/data/Lee_Munkwa.csv')

# %%
len(data_lee)
# Out:
# 15151

# %%
# data_lee.head(3).T

# %% [markdown]
# ## Clean up WS Version

# %%
data_ws = pd.read_csv('data/WS_Munkwa.csv')
# Ensure there are no duplicate IDs
len(data_ws), len(data_ws['id1'].unique()), len(data_ws['source'].unique())
# Out:
# (14607, 14607, 10591)

# %% [markdown]
# Create UUID for each unique BID. This UUID is based off converting the id to a string because that is the only unique value we have in this df. Since this isn't the most secure, we could change this to be random. But I don't think it matters much

# %%
data_ws['uuid'] = [uuid.uuid5(uuid.NAMESPACE_DNS,str(x)) for x in data_ws['id1']]
data_ws = data_ws.set_index('uuid');
data_ws['ws_uuid'] = data_ws.index

# %%
# Verify there are no duplicates
data_ws[data_ws.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id1, namehg1, namehj1, year, prevdegreehg, prevdegreehj, source, courtesynamehg, courtesynamehj, ancestralseathg, choronymhg, ancestralseathj, choronymhj, addresshg, addresshj, pennamehg, pennamehj, posthumoustitlehg, posthumoustitlehj, error, ws_uuid]
# Index: []
#
# [0 rows x 21 columns]

# %%
# These are the people who took the same example multiple times in the SAME YEAR 
# i.e. they are the duplicates of the korean name/chinese name/pass year. 
data_ws[data_ws[['namehj1', 'namehg1', 'year']].duplicated(keep=False)][['namehg1', 'namehj1', 'year']].sort_values(by=['year', 'namehg1'])
# Out:
#                                      namehg1 namehj1    year
# uuid
# a28023af-8791-5c39-9f49-2856c57cf410      이목       李  1612.0
# 1da79682-6fb5-5029-bca5-9969dd572b9b      이목       李  1612.0
# 4f879759-7396-5b4f-8d6c-2a7c57ba1754     김익진     金益振  1651.0
# a29d8bb7-b3e1-5a90-b9db-29c779ae4513     김익진     金益振  1651.0
# 4e6fe550-8d80-5c69-89a4-5071bf539533      이육      李堉  1740.0
# cea144cd-a435-5bdd-a69c-7f7cc1a37de7      이육      李堉  1740.0
# 4bd1bb73-339b-58bb-921a-ae2e33f6bfb4     홍종협     洪鍾協  1880.0
# c0b57392-53c2-54a4-b0e4-e58e0f5e9e14     홍종협     洪鍾協  1880.0
# 26044751-d6bd-534a-ae6b-965fc8389ed4     이윤재     李允在  1887.0
# 5af472e3-2855-5288-851d-1b8698aae187     이윤재     李允在  1887.0

# %%
# Marking those who took the test more than once as such in the SAME YEAR
data_ws['repeated_testtaker'] = data_ws[['namehj1', 'namehg1', 'year']].duplicated(keep=False)

# %% [markdown]
# ## Clean up encodings

# %%
lee_character = '金'
ws_character = '金'

data_ws = data_ws.replace(to_replace=r'金', value=ws_character, regex=True)
                                                                
# ws_unmerged.loc['namehj1'] = ws_unmerged.loc['namehj1'].str.replace(lee_character, ws_character)

# %% [markdown]
# ## Merge the Overlapping Areas of the Two Versions

# %% [markdown]
# We want to create a master table, where we merge the WS into the Lee version
#
# We want to:
# * Make a list of different name spellings, if they exist
# * Indicate if a person is in Lee but not in WS
# * Indicate if a person is in WS but not Lee

# %%
data_lee[(data_lee['chnname'] == '宋介臣') & (data_lee['korname'] == '송개신') & (data_lee['pass_year'] == 1393)]
# Out:
#                                                                                     bid  \
# uuid
# 2827f0d2-c539-5988-9836-6ab6d955b060  http://people.aks.ac.kr/front/dirSer/exm/exmVi...
#
#                                                                     bpid  \
# uuid
# 2827f0d2-c539-5988-9836-6ab6d955b060  G002+AKS-KHF_13C1A1AC1CC2E0B1373X0
#
#                                      affilliation  rank  competitors  \
# uuid
# 2827f0d2-c539-5988-9836-6ab6d955b060           문과     1           33
#
#                                      exam_type  pass_year king  lid previous  \
# uuid
# 2827f0d2-c539-5988-9836-6ab6d955b060       식년시       1393   태조   96   생원(生員)
#
#                                       ...    bcid   gid chnname  korname  \
# uuid                                  ...
# 2827f0d2-c539-5988-9836-6ab6d955b060  ...  bc4676  2229     宋介臣      송개신
#
#                                      family_clan   birth  death plastic  \
# uuid
# 2827f0d2-c539-5988-9836-6ab6d955b060      홍주(洪州)  1373.0    NaN  silver
#
#                                                                   lee_uuid  \
# uuid
# 2827f0d2-c539-5988-9836-6ab6d955b060  2827f0d2-c539-5988-9836-6ab6d955b060
#
#                                      repeated_testtaker
# uuid
# 2827f0d2-c539-5988-9836-6ab6d955b060              False
#
# [1 rows x 25 columns]

# %%
def person_exists(kor_name, chi_name, exam_year):
    lee_person = data_lee[(data_lee['chnname'] == chi_name) 
                          & (data_lee['korname'] == kor_name) 
                          & (data_lee['pass_year'] == exam_year)]
        
    ws_person = data_ws[(data_ws['namehj1'] == chi_name) 
                          & (data_ws['namehg1'] == kor_name) 
                          & (data_ws['year'] == exam_year)]
    
    return lee_person, ws_person

# %%
len(data_lee), len(data_lee['lee_uuid'].unique())
# Out:
# (15151, 15151)

# %%
# First, inner merge on the Korean name, Chinese name, and exam year
master = pd.merge(data_lee, data_ws,  indicator=True, how='inner', left_on=['korname','chnname','pass_year'], right_on = ['namehg1','namehj1','year'])

# Drop duplicate Korean name, Chinese name, and exam year, then rename those columns to be clearer
master = master.drop(columns=['namehg1', 'namehj1', 'year'])
master = master.rename(columns={'korname':'kor_name', 'chnname':'chi_name'})

# For an edge case where there are repeats of the same person in both datasets, we get double the amount of
# repeats. For example, person A in lee takes test twice in same year, person A in WS takes twice in same year
# Then we end up with 4 entries, when we want 2, thus we will drop the duplicates
master = master.drop_duplicates(subset=['lee_uuid'])

len(master), len(master['lee_uuid'].unique()), len(master['ws_uuid'].unique())
# Out:
# (12052, 12052, 12043)

# %%
# master.head().T

# %%
merge1 = master.copy()

# %%
len(master), len(master['lee_uuid'].unique()), len(master['ws_uuid'].unique())
# Out:
# (12052, 12052, 12043)

# %% [markdown]
# ## Edge case for repeats

# %% [markdown]
# Cases:
# * Lee: True, WS: False -- This case is okay. We will match the repeats with each other and de-duplicate
# * Lee: False, WS: True -- Luckily, there is only one case of this, for 이윤재. Will just manually add this guy to data_lee to have an extra repeat of this dude

# %%
# Make sure number of times one person retook a test in the same year is the same across both datasets
for index, row in data_lee.iterrows():
    exam_year = row['pass_year']
    chi_name = row['chnname']
    kor_name = row['korname']
    repeated = row['repeated_testtaker']
    
    # only matching Chinese name and exam year
    ws_person = data_ws[(data_ws['namehj1'] == chi_name) & (data_ws['year'] == exam_year)]
    if (len(ws_person) > 0):
        if (repeated != ws_person['repeated_testtaker'][0]):
            print(kor_name, exam_year, repeated, ws_person['repeated_testtaker'][0])
# Out:
# 최호 1616 True 0.0
# 최호 1616 True 0.0
# 이승소 1447 True 0.0
# 정종소 1447 True 0.0
# 정종소 1447 True 0.0
# 이승소 1447 True 0.0
# 신승선 1466 True 0.0
# 신승선 1466 True 0.0
# 안대진 1586 True 0.0
# 안대진 1586 True 0.0
# 이윤재 1887 False 1.0
# 유내 1727 True 0.0
# 이제 1699 True 0.0
# 이제 1699 True 0.0
# 유내 1727 True 0.0

# %% [markdown]
# The following is an edge case. We have 8 different `ws_uuid` duplicated. This is shown below as happening because in Lee version, the person shows up as a repeated test taker, but in the WS version, the person is NOT shown up as a repeated test taker. So this duplication is OK to have.

# %%
len(master[master['ws_uuid'].duplicated(keep=False)])
# Out:
# 18

# %%
master[master['ws_uuid'].duplicated(keep=False)][['kor_name', 'chi_name', 'pass_year', 'lee_uuid', 'ws_uuid', 'repeated_testtaker_x', 'repeated_testtaker_y']]
# Out:
#      kor_name chi_name  pass_year                              lee_uuid  \
# 1110       최호       崔濩       1616  be273ba9-ceaf-5b7a-9d1e-ea34a4c48a7f
# 1111       최호       崔濩       1616  e8014037-f2ac-5686-beed-92a2cc2d9e91
# 4149      이승소      李承召       1447  bce827d1-0d70-5d9b-8c3e-47692a94056e
# 4150      이승소      李承召       1447  4dd2ba02-6605-52de-aa90-baedc1786856
# 4158      정종소      鄭從韶       1447  8b8eb1bb-dd28-5ead-8e78-3396a662b7c8
# 4159      정종소      鄭從韶       1447  c11cc3b8-55a2-5c41-9cf3-4c1c7539a08f
# 4383      신승선      愼承善       1466  4f8d3d5e-2087-5a3d-a49e-3f7784455da2
# 4384      신승선      愼承善       1466  2c1b6dc5-2624-51e2-a086-391d0ed444aa
# 5424      안대진      安大進       1586  2a509d8c-3cad-52b7-9251-9eaa2641e22a
# 5425      안대진      安大進       1586  28022a2b-925f-538f-b69a-a433c686c89c
# 7452      홍종협      洪鍾協       1880  76caa537-e6b1-5c89-a94b-847732b7bd4a
# 7454      홍종협      洪鍾協       1880  4663c45d-a6f2-5c33-b405-baed07cac13f
# 7531       이육       李堉       1740  92542b7a-6e09-5d1e-b277-15670311f752
# 7533       이육       李堉       1740  7ba41301-6da0-541d-9c48-3eec7cf1a2a1
# 9048      김익진      金益振       1651  a53a1875-d574-52a1-9ba1-c39620eced18
# 9050      김익진      金益振       1651  8ccdafa7-8b43-581e-9fff-d5c55316f7ff
# 9537       이제       李濟       1699  f5d3aa3b-0d1d-5b0a-b3f2-3b61d1c5d79b
# 9538       이제       李濟       1699  45461bb5-d687-5cbc-b782-de7f9a17c59c
#
#                                    ws_uuid  repeated_testtaker_x  \
# 1110  094f1a35-0dca-505f-bc57-e8c5bfe049bb                  True
# 1111  094f1a35-0dca-505f-bc57-e8c5bfe049bb                  True
# 4149  c0c3ba67-8bd0-5bb5-b5c2-49e8bada41ad                  True
# 4150  c0c3ba67-8bd0-5bb5-b5c2-49e8bada41ad                  True
# 4158  13ba0017-fd73-5524-9d09-97f2da35f6d7                  True
# 4159  13ba0017-fd73-5524-9d09-97f2da35f6d7                  True
# 4383  cb010d29-ea27-51ba-ad55-82d7e7fbcaf8                  True
# 4384  cb010d29-ea27-51ba-ad55-82d7e7fbcaf8                  True
# 5424  548b703b-a662-5979-ad64-4d19775e4878                  True
# 5425  548b703b-a662-5979-ad64-4d19775e4878                  True
# 7452  4bd1bb73-339b-58bb-921a-ae2e33f6bfb4                  True
# 7454  4bd1bb73-339b-58bb-921a-ae2e33f6bfb4                  True
# 7531  4e6fe550-8d80-5c69-89a4-5071bf539533                  True
# 7533  4e6fe550-8d80-5c69-89a4-5071bf539533                  True
# 9048  4f879759-7396-5b4f-8d6c-2a7c57ba1754                  True
# 9050  4f879759-7396-5b4f-8d6c-2a7c57ba1754                  True
# 9537  456051b8-b7da-5832-8b34-8781458044d0                  True
# 9538  456051b8-b7da-5832-8b34-8781458044d0                  True
#
#       repeated_testtaker_y
# 1110                   0.0
# 1111                   0.0
# 4149                   0.0
# 4150                   0.0
# 4158                   0.0
# 4159                   0.0
# 4383                   0.0
# 4384                   0.0
# 5424                   0.0
# 5425                   0.0
# 7452                   1.0
# 7454                   1.0
# 7531                   1.0
# 7533                   1.0
# 9048                   1.0
# 9050                   1.0
# 9537                   0.0
# 9538                   0.0

# %% [markdown]
# Manually for 이윤재, make extra row of him in master table to indicate that this guy has taken the exam twice

# %%
(len(data_lee[data_lee['korname'] == '이윤재']), 
len(data_ws[data_ws['namehg1'] == '이윤재']), 
len(master[master['kor_name'] == '이윤재']))
# Out:
# (1, 2, 1)

# %% [markdown]
# Add the one missing guy to master table

# %%
from_ws['id1'][0]
# Out:
# 13974.0

# %%
from_ws = data_ws[data_ws['namehg1'] == '이윤재'][1:2]
missing_man = master[master['kor_name'] == '이윤재'].copy()
missing_man['ws_uuid'] = from_ws['ws_uuid'][0]
missing_man['id1'] = from_ws['id1'][0]
master = master.append(missing_man)

# %%
(len(data_lee[data_lee['korname'] == '이윤재']), 
len(data_ws[data_ws['namehg1'] == '이윤재']), 
len(master[master['kor_name'] == '이윤재']))
# Out:
# (1, 2, 2)

# %% [markdown]
# ## Manually Merge the Rest

# %% [markdown]
# Next, do a manual merge of the ones that were not merged
#
# * Find those in data_lee not in master
# * Find those in data_ws not in master
# * See if any in data_ws meets 2/3 criteria for those in data_lee, and if so, add them to master

# %% [markdown]
# ### Korean names are similar 2/3 of time

# %%
# find the unique IDs in data_lee not in master
# len(data_lee['lee_uuid'].unique()), len(master['lee_uuid'].unique())
lee_unmerged = data_lee[~data_lee['lee_uuid'].isin(master['lee_uuid'].unique())]
len(lee_unmerged)
# Out:
# 3099

# %%
# Sanity Check
# 4727 + 10424 = 15151 + 1 (the extra 1 is the repeat we had to add)
assert (len(lee_unmerged) + len(master) == len(data_lee) + 1)

# %%
ws_unmerged = data_ws[~data_ws['ws_uuid'].isin(master['ws_uuid'].unique())]
len(ws_unmerged)
# Out:
# 2566

# %%
from difflib import SequenceMatcher

def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %%
# Find the dudes in Lee with same Chinese name and exam year as WS dudes
# If their Korean names are at least 60 percent similar, then add them to the merged master table
# TODO - add the UUID of the WS dude to the master table
# TODO - add a list of dictionary to master table including dude's other names, and what other sources these other names come from

# %% [markdown]
# These are the Korean names in WS that ALMOST match the names in Lee but are SUPER close but are not the same name. Can manually check the following list to make sure I'm right but most of them look like they're the same person

# %%
# Make sure number of times one person retook a test in the same year is the same across both datasets
# for index, row in lee_unmerged.iterrows():
#     exam_year = row['pass_year']
#     chi_name = row['chnname']
#     kor_name = row['korname']
#     repeated = row['repeated_testtaker']
    
#     # only matching Chinese name and exam year
#     ws_person = ws_unmerged[(ws_unmerged['namehj1'] == chi_name) & (ws_unmerged['year'] == exam_year)]
#     if (len(ws_person) > 0):
#         if (repeated != ws_person['repeated_testtaker'][0]):
#             print(kor_name, exam_year, repeated, ws_person['repeated_testtaker'][0])

# %%
df_similar_kor_name_lee = pd.DataFrame([])
df_similar_kor_name_ws = pd.DataFrame([])

# Iterate through each person in lee_unmerged
# Find that person in ws_person based on Chinese name and exam year
# Determine if if the person has similar Korean names, they are one person
# Look at the repeated_testtaker. If same numbers, fine
# If different numbers, take the larger of the values
# I guess for now, add repeat
for index, row in lee_unmerged.iterrows():
    exam_year = row['pass_year']
    chi_name = row['chnname']
    kor_name = row['korname']
    repeated = row['repeated_testtaker']
    
    # only matching Chinese name and exam year
    ws_person = ws_unmerged[(ws_unmerged['namehj1'] == chi_name) & (ws_unmerged['year'] == exam_year)]
    
    for person_index in range(len(ws_person)):
        if (similar(ws_person["namehg1"][person_index], kor_name) > 0.5):
            print(ws_person["namehg1"][person_index], kor_name, ws_person["ws_uuid"][person_index])
            row_copy = row.copy()
# 홍재룡 홍재용 5577ff7e-1441-5f46-a21e-d06bf338c901

# %%
(len(df_similar_kor_name_lee),len(df_similar_kor_name_ws))
# Out:
# (1050, 1050)

# %%
assert(len(df_similar_kor_name_lee) == len(df_similar_kor_name_ws))

# %%
# MERGING only on Chinese name and year
master2 = pd.merge(df_similar_kor_name_lee, df_similar_kor_name_ws, indicator=True, how='inner', left_on=['chnname','pass_year'], right_on = ['namehj1','year'])

# Drop duplicate Korean name, Chinese name, and exam year, then rename those columns to be clearer
master2 = master2.drop(columns=['namehg1', 'namehj1', 'year'])
master2 = master2.rename(columns={'korname':'kor_name', 'chnname':'chi_name'})

len(master2), len(master2['lee_uuid'].unique()), len(master2['ws_uuid'].unique())
# Out:
# (1050, 1050, 1050)

# %%
# Merge these with master
frames = [master, master2]
master = pd.concat(frames, sort=False)

merge2 = master.copy()

# %%
len(master[~master['other_kor_name_in_WS_version'].isnull()])
# Out:
# 2100

# %%
# Update these values
lee_unmerged = data_lee[~data_lee['lee_uuid'].isin(master['lee_uuid'].unique())]
ws_unmerged = data_ws[~data_ws['ws_uuid'].isin(master['ws_uuid'].unique())]
len(ws_unmerged),len(lee_unmerged)
# Out:
# (1516, 2049)

# %%
# We still have 3337 in data_ws that cannot be matched with data_lee
len(data_ws[~data_ws['ws_uuid'].isin(master['ws_uuid'].unique())])
# Out:
# 1516

# %% [markdown]
# ### Chinese names are similar 2/3 of time
#
# These are the CHINESE names in WS that ALMOST match the names in Lee but are SUPER close but are not the same name. Can manually check the following list to make sure I'm right but most of them look like they're the same person

# %%
df_similar_chi_name_lee = pd.DataFrame([])
df_similar_chi_name_ws = pd.DataFrame([])

# %%
# Make sure number of times one person retook a test in the same year is the same across both datasets
# Same as above but for Chinese names
for index, row in lee_unmerged.iterrows():
    exam_year = row['pass_year']
    chi_name = row['chnname']
    kor_name = row['korname']
    repeated = row['repeated_testtaker']
    
    # only matching Chinese name and exam year
    ws_person = ws_unmerged[(ws_unmerged['namehg1'] == kor_name) & (ws_unmerged['year'] == exam_year)]
    if (len(ws_person) > 0):
        if (repeated != ws_person['repeated_testtaker'][0]):
            print(kor_name, chi_name, exam_year, repeated, ws_person['repeated_testtaker'][0])
# Out:
# 이목 李楘 1612 False 1.0
# 이목 李莯 1612 False 1.0

# %%
ws_unmerged[(ws_unmerged['year'] == 1612)][["namehj1", "namehg1", "year"]].sort_values(['namehg1'])
# Out:
#                                      namehj1 namehg1    year
# uuid
# f2885d9a-2896-53d4-b5b7-179641a51cef     權省吾     권생오  1612.0
# d977fe7c-544d-5a03-b6e1-00281472a94e      金寧      김녕  1612.0
# 67583335-837c-598e-bb55-5d3dea7c85e5       金      김령  1612.0
# e744163d-f908-5175-8004-65e4b881f08b      南宮     남궁경  1612.0
# eb37f4eb-e102-5639-9309-1f9d9a54d2e9     申易于     신역우  1612.0
# 8b448c2e-c804-5616-8a60-5a8feb6e99e1       沈      심지  1612.0
# 5a91305f-c95c-5e51-8dde-3f7205b35227       吳      오숙  1612.0
# ad4515cf-9fa2-565c-9fcc-ae8d3e29e252       李      이계  1612.0
# a28023af-8791-5c39-9f49-2856c57cf410       李      이목  1612.0
# 1da79682-6fb5-5029-bca5-9969dd572b9b       李      이목  1612.0
# a42689a0-4bb0-5b44-8af5-90494a96fcec     李用晋     이용진  1612.0
# 90dd001e-8e90-564d-baf3-9f24aa3ffc44     李晋英     이진영  1612.0
# 9246c127-1757-5089-9124-b6b758bef23c       鄭      정전  1612.0
# 7b58879d-3d76-5f05-8aa8-c8ce9e171fa4     韓明勖     한명욱  1612.0

# %%
# Same as above, but with Chinese names

# TODO what to do if there are more than one people with similar names?

df_similar_chi_name_lee = pd.DataFrame([])
df_similar_chi_name_ws = pd.DataFrame([])

for index, row in lee_unmerged.iterrows():
    exam_year = row['pass_year']
    chi_name = row['chnname']
    kor_name = row['korname']
    
    # only matching Chinese name and exam year
    ws_person = ws_unmerged[(ws_unmerged['namehg1'] == kor_name) & (ws_unmerged['year'] == exam_year)]
    
    for person_index in range(len(ws_person)):
        if (similar(ws_person["namehj1"][person_index], chi_name) > 0.5):
            print(ws_person["namehj1"][person_index], chi_name, similar(ws_person["namehj1"][person_index], chi_name), ws_person['namehg1'][person_index])
            row_copy = row.copy()
            row_copy['other_chi_name_in_WS_version'] = ws_person.iloc[person_index]["namehj1"]
            row_copy['other_chi_name_in_WS_version_uuid'] = ws_person.iloc[person_index]["ws_uuid"]

            df_similar_chi_name_lee = df_similar_chi_name_lee.append(row_copy)
            df_similar_chi_name_ws = df_similar_chi_name_ws.append(ws_person.iloc[person_index])
# Out:
# 李廷 李廷熽 0.8 이정소
# 鄭 鄭墀 0.6666666666666666 정지
# 李章 李章垕 0.8 이장후
# 許 許禝 0.6666666666666666 허직
# 金 金伈 0.6666666666666666 김심
# 朴 朴頎 0.6666666666666666 박기
# 田 田馪 0.6666666666666666 전빈
# 李 李敉 0.6666666666666666 이미
# 朴 朴耋 0.6666666666666666 박질
# 林 林薈 0.6666666666666666 임회
# 金 金鑌 0.6666666666666666 김빈
# 崔之 崔瀹之 0.8 최약지
# 金 金貔 0.6666666666666666 김비
# 金 金鏗 0.6666666666666666 김갱
# 朴 朴叙 0.6666666666666666 박서
# 李士 李士侗 0.8 이사동
# 金 金㽔 0.6666666666666666 김유
# 趙 趙忭 0.6666666666666666 조변
# 裵 裵爚 0.6666666666666666 배약
# 姜 姜仡 0.6666666666666666 강흘
# 洪疇 洪叙疇 0.8 홍서주
# 金時 金時霔 0.8 김시주
# 金 金煒 0.6666666666666666 김위
# 孔 孔頎 0.6666666666666666 공기
# 曹好智 曺好智 0.6666666666666666 조호지
# 金 金軺 0.6666666666666666 김초
# 呂 呂箎 0.6666666666666666 여호
# 崔 崔涐 0.6666666666666666 최아
# 金晋錫 金晉錫 0.6666666666666666 김진석
# 崔 崔湑 0.6666666666666666 최서
# 金壽 金鏗壽 0.8 김갱수
# 黃 黃㻶 0.6666666666666666 황필
# 李世 李世蓁 0.8 이세진
# 金 金瑊 0.6666666666666666 김감
# 許 許穧 0.6666666666666666 허제
# 南 南趎 0.6666666666666666 남주
# 姜 姜㶏 0.6666666666666666 강은
# 姜允權 姜胤權 0.6666666666666666 강윤권
# 梁 梁訒 0.6666666666666666 양인
# 李 李訔 0.6666666666666666 이은
# 林 林薈 0.6666666666666666 임회
# 金世 金世趎 0.8 김세주
# 秦 秦嶷 0.6666666666666666 진의
# 沈 沈鍧 0.6666666666666666 심굉
# 權 權旰 0.6666666666666666 권간
# 蘇 蘇徯 0.6666666666666666 소혜
# 裵應 裵應褧 0.8 배응경
# 許 許澄 0.6666666666666666 허징
# 康 康偁 0.6666666666666666 강칭
# 朴明 朴明榑 0.8 박명부
# 李 李璈 0.6666666666666666 이오
# 趙 趙郈 0.6666666666666666 조후
# 金 金寭 0.6666666666666666 김혜
# 金 金簋 0.6666666666666666 김궤
# 韓 韓昫 0.6666666666666666 한구
# 田 田煒 0.6666666666666666 전위
# 崔 崔沺 0.6666666666666666 최전
# 鄭 鄭沺 0.6666666666666666 정전
# 李尙 李尙馪 0.8 이상빈
# 李尙 李尙馦 0.8 이상혐
# 徐挺 徐挺肰 0.8 서정연
# 金 金嶭 0.6666666666666666 김알
# 金 金鍌 0.6666666666666666 김선
# 朴思 朴思諴 0.8 박사함
# 韓 韓𧩦 0.6666666666666666 한극
# 宋 宋墁 0.6666666666666666 송만
# 李之 李之馧 0.8 이지온
# 田民 田皞民 0.8 전호민
# 權 權熀 0.6666666666666666 권엽
# 元 元簋 0.6666666666666666 원궤
# 張汝 張汝衎 0.8 장여간
# 朴亨 朴亨遘 0.8 박형구
# 朴 朴瑍 0.6666666666666666 박환
# 曺 曺烶 0.6666666666666666 조정
# 李英 李英馧 0.8 이영온
# 河晋善 河晉善 0.6666666666666666 하진선
# 郭 郭岌 0.6666666666666666 곽급
# 李 李瑴 0.6666666666666666 이곡
# 李時 李時橝 0.8 이시담
# 李英 李英馦 0.8 이영혐
# 李 李馣 0.6666666666666666 이암
# 李 李㝡 0.6666666666666666 이최
# 李 李榏 0.6666666666666666 이익
# 禹 禹鐤 0.6666666666666666 우정
# 尹 尹樀 0.6666666666666666 윤적
# 崔 崔鍌 0.6666666666666666 최선
# 黃壽 黃壽嶷 0.8 황수의
# 韓在 韓在垕 0.8 한재후
# 朱 朱椗 0.6666666666666666 주정
# 金 金垕 0.6666666666666666 김후
# 羅萬榮 羅晩榮 0.6666666666666666 나만영
# 金南 金南賮 0.8 김남신
# 崔 崔垕 0.6666666666666666 최후
# 尹 尹榏 0.6666666666666666 윤익
# 方 方濈 0.6666666666666666 방즙
# 李 李垕 0.6666666666666666 이후
# 洪 洪楀 0.6666666666666666 홍우
# 余 余垕 0.6666666666666666 여후
# 崔仁 崔仁垕 0.8 최인후
# 黃啓 黃啓垕 0.8 황계후
# 李時裁 李時栽 0.6666666666666666 이시재
# 申 申湚 0.6666666666666666 신인
# 李春 李囿春 0.8 이유춘
# 南溟 南溟翮 0.8 남명핵
# 金成鎔 金聖鎔 0.6666666666666666 김성용
# 金益 金益忱 0.8 김익침
# 鄭震 鄭震垕 0.8 정진후
# 韓始裕 韓始𥙿 0.6666666666666666 한시유
# 金夢 金夢垕 0.8 김몽후
# 金始 金始鑌 0.8 김시빈
# 裵慶 裵慶垕 0.8 배경후
# 金聖 金聖垕 0.8 김성후
# 柳 柳綋 0.6666666666666666 유굉
# 許 許鐔 0.6666666666666666 허심
# 洪 洪㬙 0.6666666666666666 홍위
# 金 金㙔 0.6666666666666666 김위
# 裵晋明 裵晉明 0.6666666666666666 배진명
# 金重 金垕重 0.8 김후중
# 崔龍 崔龍賢 0.8 최용현
# 金 金琂 0.6666666666666666 김언
# 鄭錫 鄭錫垕 0.8 정석후
# 成彦 成彦檝 0.8 성언즙
# 崔德 崔德垕 0.8 최덕후
# 金 金埅 0.6666666666666666 김방
# 李景 李景垕 0.8 이경후
# 李泰 李泰馧 0.8 이태온
# 朴輔 朴賢輔 0.8 박현보
# 李重晋 李重晉 0.6666666666666666 이중진
# 鄭彙晋 鄭彙晉 0.6666666666666666 정휘진
# 金 金煃 0.6666666666666666 김규
# 呂弘 呂弘㦿 0.8 여홍호
# 崔 崔憼 0.6666666666666666 최경
# 鄭章 鄭琂章 0.8 정언장
# 金益后 金益垕 0.6666666666666666 김익후
# 崔夢 崔夢嵒 0.8 최몽암
# 房喆 房喆謩 0.8 방철모
# 成 成穎 0.6666666666666666 성영
# 吳彦 吳彦洉 0.8 오언후
# 李昌燮 李昌爕 0.6666666666666666 이창섭
# 李 李穦 0.6666666666666666 이빈
# 李 李贇 0.6666666666666666 이빈
# 許 許洉 0.6666666666666666 허후
# 黃 黃檏 0.6666666666666666 황박
# 權正 權正忱 0.8 권정침
# 柳 柳楦 0.6666666666666666 유훤
# 金九 金叙九 0.8 김서구
# 申 申熤 0.6666666666666666 신익
# 金寅燮 金寅爕 0.6666666666666666 김인섭
# 金 金鑧 0.6666666666666666 김관
# 許 許鍒 0.6666666666666666 허유
# 鄭 鄭珒 0.6666666666666666 정진
# 尹昌 尹昌㷜 0.8 윤창혁
# 呂弘 呂弘榦 0.8 여홍간
# 李庸 李庸逌 0.8 이용유
# 趙彦 趙彦㷜 0.8 조언혁
# 李敬裕 李敬𥙿 0.6666666666666666 이경유
# 權 權𢜬 0.6666666666666666 권탁
# 金 金𤩶 0.6666666666666666 김업
# 洪箕 洪箕叙 0.8 홍기서
# 李 李爗 0.6666666666666666 이엽
# 金 金㙆 0.6666666666666666 김굉
# 柳光 柳光澺 0.8 유광억
# 柳 柳櫰 0.6666666666666666 유회
# 趙夢 趙夢鶠 0.8 조몽언
# 金禧燮 金禧爕 0.6666666666666666 김희섭
# 金應著 金膺著 0.6666666666666666 김응저
# 姜德恒 姜德 0.8 강덕항
# 劉師 劉師玶 0.8 유사평
# 姜世 姜世楑 0.8 강세규
# 鄭 鄭馦 0.6666666666666666 정혐
# 盧 盧鎛 0.6666666666666666 노박
# 宋 宋㯙 0.6666666666666666 송철
# 任 任㸁 0.6666666666666666 임한
# 方 方昜 0.6666666666666666 방양
# 柳 柳睠 0.6666666666666666 유권
# 李繼禎 李繼貞 0.6666666666666666 이계정
# 鄭 鄭忻 0.6666666666666666 정흔
# 許 許譔 0.6666666666666666 허선
# 尹 尹㬦 0.6666666666666666 윤확
# 李 李墀 0.6666666666666666 이지
# 曺河 曺兗河 0.8 조연하
# 金 金耋 0.6666666666666666 김질
# 金 金嶟 0.6666666666666666 김준
# 成 成俶 0.6666666666666666 성숙
# 鄭 鄭佸 0.6666666666666666 정괄
# 辛仲 辛仲琚 0.8 신중거
# 崔漢侯 崔漢候 0.6666666666666666 최한후
# 權 權侹 0.6666666666666666 권정
# 許 許葟 0.6666666666666666 허황
# 趙 趙鑌 0.6666666666666666 조빈
# 鄭 鄭晣 0.6666666666666666 정절
# 李 李垾 0.6666666666666666 이한
# 安晋生 安晉生 0.6666666666666666 안진생
# 金 金訢 0.6666666666666666 김흔
# 奇 奇襸 0.6666666666666666 기찬
# 辛季 辛季琚 0.8 신계거
# 李 李坫 0.6666666666666666 이점
# 姜景 姜景叙 0.8 강경서
# 宋 宋軼 0.6666666666666666 송일
# 李 李諿 0.6666666666666666 이집
# 朴 朴訒 0.6666666666666666 박인
# 李 李琚 0.6666666666666666 이거
# 李 李浤 0.6666666666666666 이굉
# 權 權璸 0.6666666666666666 권빈
# 金 金崶 0.6666666666666666 김봉
# 奇 奇褚 0.6666666666666666 기저
# 閔 閔頤 0.6666666666666666 민이
# 金 金磶 0.6666666666666666 김석
# 李 李瑺 0.6666666666666666 이상
# 李 李黿 0.6666666666666666 이원
# 李 李㙉 0.6666666666666666 이전
# 姜 姜諿 0.6666666666666666 강집
# 姜 姜澂 0.6666666666666666 강징
# 安 安覯 0.6666666666666666 안구
# 金 金璫 0.6666666666666666 김당
# 金 金熠 0.6666666666666666 김습
# 李云 李云秠 0.8 이운비
# 閔 閔㥳 0.6666666666666666 민원
# 李 李堣 0.6666666666666666 이우
# 金克 金克愊 0.8 김극핍
# 李 李頫 0.6666666666666666 이부
# 權 權橃 0.6666666666666666 권벌
# 李 李蘋 0.6666666666666666 이빈
# 金 金磧 0.6666666666666666 김적
# 許 許硡 0.6666666666666666 허굉
# 申 申鏛 0.6666666666666666 신상
# 宋 宋澂 0.6666666666666666 송징
# 金 金璠 0.6666666666666666 김번
# 李 李迨 0.6666666666666666 이태
# 李 李胖 0.6666666666666666 이반
# 黃 黃𣉮 0.6666666666666666 황진
# 李之 李之蕡 0.8 이지분
# 金 金埏 0.6666666666666666 김연
# 金 金顒 0.6666666666666666 김옹
# 李 李構 0.6666666666666666 이구
# 林 林畡 0.6666666666666666 임해
# 金彦 金彦琚 0.8 김언거
# 許 許礦 0.6666666666666666 허광
# 趙邦禎 趙邦楨 0.6666666666666666 조방정
# 李 李畬 0.6666666666666666 이여
# 羅士 羅士愃 0.8 나사선
# 鄭 鄭鍠 0.6666666666666666 정굉
# 鄭 鄭荃 0.6666666666666666 정전
# 禹 禹鏛 0.6666666666666666 우상
# 柳仲 柳仲郢 0.8 유중영
# 申承 申承澡 0.8 신승조
# 安 安舳 0.6666666666666666 안축
# 申 申抃 0.6666666666666666 신변
# 權 權輗 0.6666666666666666 권예
# 權 權㻩 0.6666666666666666 권겸
# 盧 盧禛 0.6666666666666666 노진
# 安 安嶒 0.6666666666666666 안증
# 洪疇 洪叙疇 0.8 홍서주
# 金 金漹 0.6666666666666666 김언
# 趙希 趙希嘏 0.8 조희하
# 韓 韓㞳 0.6666666666666666 한두
# 李 李菑 0.6666666666666666 이치
# 丁 丁熿 0.6666666666666666 정황
# 李彦 李彦忱 0.8 이언침
# 任臣 任鼐臣 0.8 임내신
# 崔 崔巏 0.6666666666666666 최권
# 金 金䃴 0.6666666666666666 김저
# 南宮 南宮忱 0.8 남궁침
# 梁應 梁應鮐 0.8 양응태
# 金宇 金宇顒 0.8 김우옹
# 李 李諴 0.6666666666666666 이함
# 曺景中 曹景中 0.6666666666666666 조경중
# 郭 郭趕 0.6666666666666666 곽간
# 李 李䤴 0.6666666666666666 이함
# 李 李墍 0.6666666666666666 이기
# 柳 柳溵 0.6666666666666666 유은
# 金 金誋 0.6666666666666666 김기
# 金 金軔 0.6666666666666666 김인
# 李 李訒 0.6666666666666666 이인
# 郭 郭𧾰 0.6666666666666666 곽익
# 南世 南世瑍 0.8 남세환
# 金德 金德鵾 0.8 김덕곤
# 秦冥鴻 秦溟鴻 0.6666666666666666 진명홍
# 河晋寶 河晉寶 0.6666666666666666 하진보
# 尹 尹趌 0.6666666666666666 윤길
# 金德 金德諴 0.8 김덕함
# 郭 郭趪 0.6666666666666666 곽황
# 林 林頲 0.6666666666666666 임정
# 李慶 李頤慶 0.8 이이경
# 崔 崔頲 0.6666666666666666 최정
# 朴 朴顒 0.6666666666666666 박옹
# 羅 羅紉 0.6666666666666666 나인
# 朴 朴箎 0.6666666666666666 박호
# 崔 崔葕 0.6666666666666666 최연
# 權 權悏 0.6666666666666666 권협
# 李汝 李汝馪 0.8 이여빈
# 尹 尹顗 0.6666666666666666 윤의
# 李 李𣙇 0.6666666666666666 이집
# 徐 徐渻 0.6666666666666666 서성
# 朴文 朴文叙 0.8 박문서
# 朴 朴澡 0.6666666666666666 박조
# 姜 姜綖 0.6666666666666666 강연
# 李 李讜 0.6666666666666666 이당
# 李 李𡼖 0.6666666666666666 이돈
# 姜 姜愐 0.6666666666666666 강면
# 權 權噵 0.6666666666666666 권도
# 吳汝 吳汝檼 0.8 오여은
# 吳 吳晪 0.6666666666666666 오전
# 尹 尹昫 0.6666666666666666 윤구
# 李 李蒧 0.6666666666666666 이점
# 沈 沈諿 0.6666666666666666 심집
# 吳汝 吳汝橃 0.8 오여벌
# 李民 李民寏 0.8 이민환
# 李 李惕 0.6666666666666666 이척
# 李惟 李惟諴 0.8 이유함
# 徐 徐忭 0.6666666666666666 서변
# 李時 李時馣 0.8 이시암
# 呂 呂焯 0.6666666666666666 여작
# 鄭 鄭杺 0.6666666666666666 정심
# 洪 洪霶 0.6666666666666666 홍방
# 兪晋曾 兪晉曾 0.6666666666666666 유진증
# 金 金灦 0.6666666666666666 김현
# 金 金𩑃 0.6666666666666666 김업
# 李起 李起浡 0.8 이기발
# 李生 李生浡 0.8 이생발
# 李興 李興浡 0.8 이흥발
# 許 許嵱 0.6666666666666666 허용
# 楊時晋 楊時晉 0.6666666666666666 양시진
# 李 李埁 0.6666666666666666 이잠
# 河 河溍 0.6666666666666666 하진
# 李錫晋 李錫晉 0.6666666666666666 이석진
# 金 金鋿 0.6666666666666666 김상
# 林 林墰 0.6666666666666666 임담
# 崔基 崔基銆 0.8 최기백
# 權 權諿 0.6666666666666666 권집
# 吳 吳熽 0.6666666666666666 오소
# 鄭 鄭慥 0.6666666666666666 정조
# 柳 柳椐 0.6666666666666666 유거
# 權 權寏 0.6666666666666666 권환
# 金 金迬 0.6666666666666666 김왕
# 呂 呂𤀂 0.6666666666666666 여경
# 趙 趙釴 0.6666666666666666 조익
# 睦欽 睦叙欽 0.8 목서흠
# 金 金昈 0.6666666666666666 김호
# 權 權晵 0.6666666666666666 권계
# 柳 柳霂 0.6666666666666666 유목
# 金 金錕 0.6666666666666666 김곤
# 韓 韓暿 0.6666666666666666 한희
# 鄭 鄭庥 0.6666666666666666 정휴
# 柳 柳榰 0.6666666666666666 유지
# 李彙晋 李彙晉 0.6666666666666666 이휘진
# 尹殷 尹棐殷 0.8 윤비은
# 朴 朴繘 0.6666666666666666 박율
# 朴 朴𥳍 0.6666666666666666 박심
# 李孝 李孝諴 0.8 이효함
# 金 金璁 0.6666666666666666 김총
# 權 權垕 0.6666666666666666 권후
# 郭 郭崦 0.6666666666666666 곽엄
# 韓 韓琂 0.6666666666666666 한언
# 南 南碝 0.6666666666666666 남연
# 柳 柳俰 0.6666666666666666 유화
# 趙時久 趙始久 0.6666666666666666 조시구
# 南 南垕 0.6666666666666666 남후
# 朴 朴澂 0.6666666666666666 박징
# 申 申㶅 0.6666666666666666 신학
# 權 權霔 0.6666666666666666 권주
# 朴 朴漪 0.6666666666666666 박의
# 李時 李時楳 0.8 이시매
# 沈 沈枅 0.6666666666666666 심계
# 許 許墀 0.6666666666666666 허지
# 申 申湙 0.6666666666666666 신역
# 吳 吳䎙 0.6666666666666666 오빈
# 鄭 鄭䎖 0.6666666666666666 정증
# 柳 柳頲 0.6666666666666666 유정
# 李 李袗 0.6666666666666666 이진
# 權 權𢜫 0.6666666666666666 권성
# 權 權忭 0.6666666666666666 권변
# 金 金鍰 0.6666666666666666 김환
# 權 權𢢝 0.6666666666666666 권수
# 沈 沈譔 0.6666666666666666 심선
# 呂 呂㴰 0.6666666666666666 여능
# 元 元檝 0.6666666666666666 원즙
# 朱 朱楘 0.6666666666666666 주목
# 姜裕後 姜𥙿後 0.6666666666666666 강유후
# 鄭 鄭勔 0.6666666666666666 정면
# 金晋重 金晉重 0.6666666666666666 김진중
# 趙 趙䃏 0.6666666666666666 조성
# 姜汝 姜汝㦿 0.8 강여호
# 元 元樀 0.6666666666666666 원적
# 權 權諔 0.6666666666666666 권숙
# 李彙晋 李彙晉 0.6666666666666666 이휘진
# 金 金政 0.6666666666666666 김정
# 金 金㙫 0.6666666666666666 김집
# 權 權𥛚 0.6666666666666666 권적
# 權斗 權斗綋 0.8 권두굉
# 李廷 李廷熽 0.8 이정소
# 洪 洪蒑 0.6666666666666666 홍은
# 申 申𩅿 0.6666666666666666 신박
# 元 元梲 0.6666666666666666 원탈
# 朴 朴烶 0.6666666666666666 박정
# 申 申𣷯 0.6666666666666666 신근
# 尹 尹焜 0.6666666666666666 윤혼
# 金厦 金厦梴 0.8 김하천
# 張善 張善澂 0.8 장선징
# 元 元㯙 0.6666666666666666 원철
# 李 李渻 0.6666666666666666 이성
# 李 李槳 0.6666666666666666 이장
# 閔 閔黯 0.6666666666666666 민암
# 李世 李世垕 0.8 이세후
# 李彙晋 李彙晉 0.6666666666666666 이휘진
# 金致 金致垕 0.8 김치후
# 南 南躔 0.6666666666666666 남전
# 崔 崔鎜 0.6666666666666666 최반
# 南宮 南宮垕 0.8 남궁후
# 李 李溭 0.6666666666666666 이직
# 朴世 朴世𤎱 0.8 박세준
# 韓 韓㙉 0.6666666666666666 한전
# 李命 李頤命 0.8 이이명
# 金 金霔 0.6666666666666666 김주
# 柳 柳埅 0.6666666666666666 유방
# 金 金澋 0.6666666666666666 김횡
# 權 權慜 0.6666666666666666 권민
# 李齊 李齊嵒 0.8 이제암
# 權 權𢢜 0.6666666666666666 권업
# 柳玄 柳頤玄 0.8 유이현
# 李 李㵓 0.6666666666666666 이식
# 趙 趙鏛 0.6666666666666666 조상
# 黃 黃㮋 0.6666666666666666 황욱
# 趙世 趙世垕 0.8 조세후
# 權 權顈 0.6666666666666666 권경
# 金始 金始㷜 0.8 김시혁
# 愼爾晋 愼爾晉 0.6666666666666666 신이진
# 姜 姜檏 0.6666666666666666 강박
# 李時 李時馠 0.8 이시함
# 金天 金天叙 0.8 김천서
# 權 權賅 0.6666666666666666 권해
# 韓朝 韓頤朝 0.8 한이조
# 韓顯 韓顯謩 0.8 한현모
# 安 安栻 0.6666666666666666 안식
# 趙 趙侹 0.6666666666666666 조정
# 柳 柳謇 0.6666666666666666 유건
# 李晋吉 李晉吉 0.6666666666666666 이진길
# 崔 崔晑 0.6666666666666666 최향
# 韓翼 韓翼謩 0.8 한익모
# 李光 李光躋 0.8 이광제
# 李光 李光溭 0.8 이광직
# 洪 洪曕 0.6666666666666666 홍염
# 權 權熻 0.6666666666666666 권흡
# 韓 韓栐 0.6666666666666666 한영
# 沈 沈瑴 0.6666666666666666 심곡
# 申 申𢢝 0.6666666666666666 신수
# 李 李溎 0.6666666666666666 이연
# 姜 姜俒 0.6666666666666666 강흔
# 李宜 李宜馣 0.8 이의암
# 柳 柳橚 0.6666666666666666 유숙
# 李廷 李廷𤩶 0.8 이정업
# 黃 黃柙 0.6666666666666666 황합
# 許 許晊 0.6666666666666666 허질
# 金 金廧 0.6666666666666666 김장
# 柳協基 柳恊基 0.6666666666666666 유협기
# 李 李埦 0.6666666666666666 이완
# 許 許晪 0.6666666666666666 허전
# 沈 沈鉍 0.6666666666666666 심필
# 洪 洪霫 0.6666666666666666 홍습
# 任 任絖 0.6666666666666666 임광
# 黃 黃㦿 0.6666666666666666 황호
# 權 權淰 0.6666666666666666 권심
# 李 李莆 0.6666666666666666 이보
# 李 李𥡦 0.6666666666666666 이적
# 柳 柳秠 0.6666666666666666 유비
# 姜 姜翯 0.6666666666666666 강학
# 李祥 李頤祥 0.8 이이상
# 尹 尹㻩 0.6666666666666666 윤겸
# 李 李㬅 0.6666666666666666 이만
# 柳 柳𥳍 0.6666666666666666 유심
# 洪 洪瑑 0.6666666666666666 홍전
# 權 權堣 0.6666666666666666 권우
# 李 李袤 0.6666666666666666 이무
# 申 申恦 0.6666666666666666 신상
# 李晟傳 李晠傳 0.6666666666666666 이성전
# 朴 朴遾 0.6666666666666666 박서
# 李 李禂 0.6666666666666666 이도
# 沈 沈𪗆 0.6666666666666666 심제
# 閔應協 閔應恊 0.6666666666666666 민응협
# 尹 尹敉 0.6666666666666666 윤미
# 兪 兪㯙 0.6666666666666666 유철
# 李有 李有淐 0.8 이유창
# 李 李溍 0.6666666666666666 이진
# 柳 柳淰 0.6666666666666666 유심
# 李賢 李頤賢 0.8 이이현
# 權 權澺 0.6666666666666666 권억
# 李純 李純馣 0.8 이순암
# 李 李𡐔 0.6666666666666666 이인
# 李守 李守諴 0.8 이수함
# 鄭 鄭榏 0.6666666666666666 정익
# 申 申洬 0.6666666666666666 신속
# 李 李垕 0.6666666666666666 이후
# 李 李椲 0.6666666666666666 이휘
# 金 金鉽 0.6666666666666666 김식
# 洪 洪鐩 0.6666666666666666 홍수
# 吳 吳翮 0.6666666666666666 오핵
# 趙晋錫 趙晉錫 0.6666666666666666 조진석
# 洪 洪葳 0.6666666666666666 홍위
# 兪 兪瑒 0.6666666666666666 유창
# 閔光 閔光熽 0.8 민광소
# 沈 沈棇 0.6666666666666666 심총
# 李敏 李敏叙 0.8 이민서
# 具 具崟 0.6666666666666666 구음
# 鄭 鄭檏 0.6666666666666666 정박
# 李 李堥 0.6666666666666666 이무
# 慶 慶㝡 0.6666666666666666 경최
# 李 李䎘 0.6666666666666666 이숙
# 金 金楀 0.6666666666666666 김우
# 柳晋昌 柳晉昌 0.6666666666666666 유진창
# 李 李柙 0.6666666666666666 이합
# 李 李𤍿 0.6666666666666666 이전
# 尹 尹抃 0.6666666666666666 윤변
# 李 李秞 0.6666666666666666 이유
# 尹 尹晢 0.6666666666666666 윤절
# 李 李嵇 0.6666666666666666 이혜
# 尹 尹堦 0.6666666666666666 윤계
# 鄭 鄭樍 0.6666666666666666 정적
# 韓 韓濙 0.6666666666666666 한영
# 權 權瑎 0.6666666666666666 권해
# 李 李藼 0.6666666666666666 이훤
# 李 李璾 0.6666666666666666 이제
# 李壽 李壽㬅 0.8 이수만
# 柳 柳㝚 0.6666666666666666 유연
# 尹 尹葕 0.6666666666666666 윤연
# 洪 洪𧡺 0.6666666666666666 홍기
# 許 許悏 0.6666666666666666 허협
# 權 權瑍 0.6666666666666666 권환
# 安 安烒 0.6666666666666666 안식
# 安 安垕 0.6666666666666666 안후
# 任 任瑎 0.6666666666666666 임해
# 趙 趙曮 0.6666666666666666 조엄
# 李 李堣 0.6666666666666666 이우
# 任 任㻐 0.6666666666666666 임준
# 李晋圭 李晉圭 0.6666666666666666 이진규
# 柳五 柳叙五 0.8 유서오
# 李 李瀰 0.6666666666666666 이미
# 黃 黃榦 0.6666666666666666 황간
# 李 李溵 0.6666666666666666 이은
# 李益 李益烍 0.8 이익선
# 趙 趙㻐 0.6666666666666666 조준
# 金 金熤 0.6666666666666666 김익
# 沈之 沈頤之 0.8 심이지
# 趙 趙瑍 0.6666666666666666 조환
# 朴長燮 朴長爕 0.6666666666666666 박장섭
# 金柱 金頤柱 0.8 김이주
# 沈 沈埉 0.6666666666666666 심협
# 韓鼎裕 韓鼎𥙿 0.6666666666666666 한정유
# 李宗燮 李宗爕 0.6666666666666666 이종섭
# 崔 崔烜 0.6666666666666666 최훤
# 許 許霮 0.6666666666666666 허담
# 韓晩裕 韓晩𥙿 0.6666666666666666 한만유
# 申 申曮 0.6666666666666666 신엄
# 韓光 韓光綮 0.8 한광계
# 崔守 崔守忱 0.8 최수침
# 安 安筞 0.6666666666666666 안책
# 權 權儐 0.6666666666666666 권빈
# 李翼晋 李翼晉 0.6666666666666666 이익진
# 沈晋賢 沈晉賢 0.6666666666666666 심진현
# 鄭成 鄭㝡成 0.8 정최성
# 鄭行 鄭㝡行 0.8 정최행
# 申 申漵 0.6666666666666666 신서
# 李 李垿 0.6666666666666666 이서
# 兪漢 兪漢㝢 0.8 유한우
# 徐有 徐有榘 0.8 서유구
# 姜 姜儐 0.6666666666666666 강빈
# 洪大協 洪大恊 0.6666666666666666 홍대협
# 鄭東 鄭東榦 0.8 정동간
# 尹 尹愭 0.6666666666666666 윤기
# 韓耆裕 韓耆𥙿 0.6666666666666666 한기유
# 尹 尹瀗 0.6666666666666666 윤헌
# 尹 尹穳 0.6666666666666666 윤찬
# 金 金𨩿 0.6666666666666666 김후
# 趙晋和 趙晉和 0.6666666666666666 조진화
# 柳 柳訸 0.6666666666666666 유화
# 沈 沈鈁 0.6666666666666666 심방
# 金基 金基叙 0.8 김기서
# 權 權傛 0.6666666666666666 권용
# 李晋淵 李晉淵 0.6666666666666666 이진연
# 金根 金逌根 0.8 김유근
# 韓晋赫 韓晉赫 0.6666666666666666 한진혁
# 金 金䥧 0.6666666666666666 김선
# 金 金鍏 0.6666666666666666 김위
# 李圭 李圭祊 0.8 이규팽
# 韓鎭 韓鎭㦿 0.8 한진호
# 黃 黃𥞵 0.6666666666666666 황겹
# 權 權筴 0.6666666666666666 권협
# 權 權溭 0.6666666666666666 권직
# 李鼎 李鼎叙 0.8 이정서
# 李寅皐 李寅臯 0.6666666666666666 이인고
# 李範晋 李範晉 0.6666666666666666 이범진
# 鄭朝 鄭㝡朝 0.8 정최조
# 李晋翼 李晉翼 0.6666666666666666 이진익
# 李 李㘾 0.6666666666666666 이우
# 睦仁 睦仁㘽 0.8 목인재
# 李裕膺 李𥙿膺 0.6666666666666666 이유응
# 林洙 林謇洙 0.8 임건수
# 洪承裕 洪承𥙿 0.6666666666666666 홍승유
# 趙定燮 趙定爕 0.6666666666666666 조정섭
# 李裕承 李𥙿承 0.6666666666666666 이유승
# 李承皐 李承臯 0.6666666666666666 이승고
# 姜 姜𧄽 0.6666666666666666 강찬
# 韓東 韓晢東 0.8 한절동
# 金 金㠎 0.6666666666666666 김집
# 金 金嶷 0.6666666666666666 김의
# 金翼 金隼翼 0.8 김준익
# 李丙 李丙逌 0.8 이병유
# 李大 李大頤 0.8 이대이
# 許 許㥌 0.6666666666666666 허국
# 玉晋輝 玉晉輝 0.6666666666666666 옥진휘
# 金昌 金昌鼐 0.8 김창내
# 徐道裕 徐道𥙿 0.6666666666666666 서도유
# 朴 朴鎤 0.6666666666666666 박황
# 李 李濰 0.6666666666666666 이유
# 權 權愃 0.6666666666666666 권선
# 李 李偰 0.6666666666666666 이설
# 張彦 張彦忱 0.8 장언침
# 權世 權世橚 0.8 권세숙
# 羅 羅㶷 0.6666666666666666 나순
# 朴柱 朴 0.6666666666666666 박기주
# 權 權偌 0.6666666666666666 권야
# 金 金琂 0.6666666666666666 김언
# 尹 尹㻻 0.6666666666666666 윤돈
# 李 李茳 0.6666666666666666 이강
# 琴 琴𢢜 0.6666666666666666 금업
# 李晩 李晩煃 0.8 이만규
# 張晋遠 張晉遠 0.6666666666666666 장진원
# 朴 朴嶔 0.6666666666666666 박금
# 閔 閔忱 0.6666666666666666 민침
# 李承 李㝡承 0.8 이최승
# 金晋鐸 金晉鐸 0.6666666666666666 김진탁
# 閔 閔惕 0.6666666666666666 민척
# 尹滋 尹滋畊 0.8 윤자경
# 權 權愭 0.6666666666666666 권기
# 全勳 全鼐勳 0.8 전내훈
# 姜 姜詗 0.6666666666666666 강형
# 尹士 尹士昀 0.8 윤사윤
# 柳晋三 柳晉三 0.6666666666666666 유진삼
# 李 李禬 0.6666666666666666 이회
# 崔 崔瑍 0.6666666666666666 최환
# 金炳 金炳㴤 0.8 김병주

# %%
# THESE NEED TO BE THE SAME
assert(len(df_similar_chi_name_lee) == len(df_similar_chi_name_ws))
print(len(df_similar_chi_name_lee), len(df_similar_chi_name_ws))
# Out:
# 1055 1055

# %%
# There are repeates
len(df_similar_chi_name_lee['lee_uuid'].unique()),len(df_similar_chi_name_ws['ws_uuid'].unique())
# Out:
# (1053, 1051)

# %%
df_similar_chi_name_lee[df_similar_chi_name_lee['lee_uuid'].duplicated(False)][['lee_uuid','korname', 'chnname', 'other_chi_name_in_WS_version', 'other_chi_name_in_WS_version_uuid']]
# Out:
#                                                                   lee_uuid  \
# c5b8a0c3-fe87-5004-b7bb-cd6d2c7da9be  c5b8a0c3-fe87-5004-b7bb-cd6d2c7da9be
# c5b8a0c3-fe87-5004-b7bb-cd6d2c7da9be  c5b8a0c3-fe87-5004-b7bb-cd6d2c7da9be
# a6382748-0883-5c51-afe7-1bebc60152f7  a6382748-0883-5c51-afe7-1bebc60152f7
# a6382748-0883-5c51-afe7-1bebc60152f7  a6382748-0883-5c51-afe7-1bebc60152f7
#
#                                      korname chnname  \
# c5b8a0c3-fe87-5004-b7bb-cd6d2c7da9be      이목      李楘
# c5b8a0c3-fe87-5004-b7bb-cd6d2c7da9be      이목      李楘
# a6382748-0883-5c51-afe7-1bebc60152f7      이목      李莯
# a6382748-0883-5c51-afe7-1bebc60152f7      이목      李莯
#
#                                      other_chi_name_in_WS_version  \
# c5b8a0c3-fe87-5004-b7bb-cd6d2c7da9be                            李
# c5b8a0c3-fe87-5004-b7bb-cd6d2c7da9be                            李
# a6382748-0883-5c51-afe7-1bebc60152f7                            李
# a6382748-0883-5c51-afe7-1bebc60152f7                            李
#
#                                          other_chi_name_in_WS_version_uuid
# c5b8a0c3-fe87-5004-b7bb-cd6d2c7da9be  a28023af-8791-5c39-9f49-2856c57cf410
# c5b8a0c3-fe87-5004-b7bb-cd6d2c7da9be  1da79682-6fb5-5029-bca5-9969dd572b9b
# a6382748-0883-5c51-afe7-1bebc60152f7  a28023af-8791-5c39-9f49-2856c57cf410
# a6382748-0883-5c51-afe7-1bebc60152f7  1da79682-6fb5-5029-bca5-9969dd572b9b

# %%
# Since there are so few I will just manually delete them
# GETTING RID OF REPEATS
df_similar_chi_name_lee = df_similar_chi_name_lee.reset_index()

i = df_similar_chi_name_lee[df_similar_chi_name_lee['lee_uuid'] == uuid.UUID('{c5b8a0c3-fe87-5004-b7bb-cd6d2c7da9be}')].index[0]
df_similar_chi_name_lee = df_similar_chi_name_lee.drop(i)

i = df_similar_chi_name_lee[df_similar_chi_name_lee['lee_uuid'] == uuid.UUID('{a6382748-0883-5c51-afe7-1bebc60152f7}')].index[1]
df_similar_chi_name_lee = df_similar_chi_name_lee.drop(i)

# %%
# MERGING only on Korean name and year
master2 = pd.DataFrame([])
master2 = pd.merge(df_similar_chi_name_lee, df_similar_chi_name_ws, indicator=True, how='left', left_on=['korname','pass_year'], right_on = ['namehg1','year'])

# Drop duplicate Korean name, Chinese name, and exam year, then rename those columns to be clearer
master2 = master2.drop(columns=['namehg1', 'namehj1', 'year'])
master2 = master2.rename(columns={'korname':'kor_name', 'chnname':'chi_name'})

# These numbers are unequal bc of all of the extra duplicates, etc
len(master2), len(master2['lee_uuid'].unique()), len(master2['ws_uuid'].unique())
# Out:
# (1063, 1053, 1051)

# %%
# Merge these with master
frames = [master, master2]
master = pd.concat(frames, sort=False)

merge3 = master.copy()

# %%
len(master[~master['other_chi_name_in_WS_version'].isnull()])
# Out:
# 1063

# %%
# Update these values
lee_unmerged = data_lee[~data_lee['lee_uuid'].isin(master['lee_uuid'].unique())]
ws_unmerged = data_ws[~data_ws['ws_uuid'].isin(master['ws_uuid'].unique())]

len(ws_unmerged),len(lee_unmerged)
# Out:
# (465, 996)

# %%
# We still have 467 in data_ws that cannot be matched with data_lee
len(data_ws[~data_ws['ws_uuid'].isin(master['ws_uuid'].unique())])
# Out:
# 465

# %% [markdown]
# ### Chinese names are similar, again, this time 50%

# %%
# If Chinese names are the same and Korean names are FIFTY PERCENT (this is less than before)
# Use eyes to make sure these are right
# Manually choose the people who are the same

df_similar_chi_name_lee = pd.DataFrame([])
df_similar_chi_name_ws = pd.DataFrame([])

for index, row in lee_unmerged.iterrows():
    exam_year = row['pass_year']
    chi_name = row['chnname']
    kor_name = row['korname']
    
    # only matching Chinese name and exam year
    ws_person = ws_unmerged[(ws_unmerged['namehg1'] == kor_name) & (ws_unmerged['year'] == exam_year)]
    if (len(ws_person) > 0) :
        for person_index in range(len(ws_person)):
            if (similar(ws_person["namehj1"][person_index], chi_name) >= 0.5):
                print(ws_person["namehj1"][0], chi_name, similar(ws_person["namehj1"][0], chi_name), ws_person['namehg1'][0], row['korname'])
                row_copy = row.copy()
                row_copy['other_chi_name_in_WS_version'] = ws_person.iloc[person_index]["namehj1"]
                row_copy['other_chi_name_in_WS_version_uuid'] = ws_person.iloc[person_index]["ws_uuid"]

                df_similar_chi_name_lee = df_similar_chi_name_lee.append(row_copy)
                df_similar_chi_name_ws = df_similar_chi_name_ws.append(ws_person.iloc[person_index])
# Out:
# 康輻 康福 0.5 강복 강복
# 安熹 安憙 0.5 안희 안희
# 張晋 張晉 0.5 장진 장진
# 李晋 李晉 0.5 이진 이진
# 李瑛 李𡎘 0.5 이영 이영
# 徐岡 徐崗 0.5 서강 서강
# 郭珣 郭恂 0.5 곽순 곽순
# 徐晋 徐晉 0.5 서진 서진
# 李韜 李蹈 0.5 이도 이도
# 韓卷 韓淃 0.5 한권 한권
# 康晋 康晉 0.5 강진 강진
# 成晋 成晉 0.5 성진 성진
# 孫澍 孫㴻 0.5 손주 손주
# 金沖 金冲 0.5 김충 김충
# 許晋 許晉 0.5 허진 허진
# 李沖 李冲 0.5 이충 이충
# 尹晋 尹晉 0.5 윤진 윤진
# 沈坪 沈枰 0.5 심평 심평
# 鄭協 鄭恊 0.5 정협 정협
# 鄭晋 鄭晉 0.5 정진 정진
# 李 李惕然 0.5 이척연 이척연
# 許潁 許頴 0.5 허영 허영
# 洪墩 洪墪 0.5 홍돈 홍돈
# 權華 權𠌶 0.5 권화 권화

# %%
# THESE NEED TO BE THE SAME
assert(len(df_similar_chi_name_lee) == len(df_similar_chi_name_ws))
print(len(df_similar_chi_name_lee), len(df_similar_chi_name_ws))
# Out:
# 24 24

# %%
df_similar_chi_name_lee[df_similar_chi_name_lee['lee_uuid'].duplicated(False)][['lee_uuid','korname', 'chnname', 'other_chi_name_in_WS_version', 'other_chi_name_in_WS_version_uuid']]
# Out:
# Empty DataFrame
# Columns: [lee_uuid, korname, chnname, other_chi_name_in_WS_version, other_chi_name_in_WS_version_uuid]
# Index: []

# %%
# MERGING only on Korean name and year
master2 = pd.DataFrame([])
master2 = pd.merge(df_similar_chi_name_lee, df_similar_chi_name_ws, indicator=True, how='left', left_on=['korname','pass_year'], right_on = ['namehg1','year'])

# Drop duplicate Korean name, Chinese name, and exam year, then rename those columns to be clearer
master2 = master2.drop(columns=['namehg1', 'namehj1', 'year'])
master2 = master2.rename(columns={'korname':'kor_name', 'chnname':'chi_name'})

# These numbers are unequal bc of all of the extra duplicates, etc
len(master2), len(master2['lee_uuid'].unique()), len(master2['ws_uuid'].unique())

# Merge these with master
frames = [master, master2]
master = pd.concat(frames, sort=False)

merge4 = master.copy()

# %%
# Update these values
lee_unmerged = data_lee[~data_lee['lee_uuid'].isin(master['lee_uuid'].unique())]
ws_unmerged = data_ws[~data_ws['ws_uuid'].isin(master['ws_uuid'].unique())]

len(ws_unmerged),len(lee_unmerged)
# Out:
# (441, 972)

# %% [markdown]
# ### Korean names are similar, again, this time 50%

# %%
df_similar_kor_name_lee = pd.DataFrame([])
df_similar_kor_name_ws = pd.DataFrame([])

# Iterate through each person in lee_unmerged
# Find that person in ws_person based on Chinese name and exam year
# Determine if if the person has similar Korean names, they are one person
# Look at the repeated_testtaker. If same numbers, fine
# If different numbers, take the larger of the values
# I guess for now, add repeat
for index, row in lee_unmerged.iterrows():
    exam_year = row['pass_year']
    chi_name = row['chnname']
    kor_name = row['korname']
    repeated = row['repeated_testtaker']
    
    # only matching Chinese name and exam year
    ws_person = ws_unmerged[(ws_unmerged['namehj1'] == chi_name) & (ws_unmerged['year'] == exam_year)]
    
    for person_index in range(len(ws_person)):
#         print(ws_person["namehg1"][person_index], kor_name, ws_person["namehj1"][person_index], similar(ws_person["namehg1"][person_index], kor_name))
        if (similar(ws_person["namehg1"][person_index], kor_name) >= 0.5):
            print(ws_person["namehg1"][person_index], kor_name, ws_person["namehj1"][person_index])
            row_copy = row.copy()
            row_copy['other_kor_name_in_WS_version'] = ws_person["namehg1"][person_index]
            row_copy['other_kor_name_in_WS_version_uuid'] = ws_person["ws_uuid"][person_index]
            df_similar_kor_name_lee = df_similar_kor_name_lee.append(row_copy)    
            df_similar_kor_name_ws = df_similar_kor_name_ws.append(ws_person)
# Out:
# 김녕 김영 金寧
# 서륜 서윤 徐倫
# 강륜 강윤 姜綸
# 김렴 김염 金濂
# 이뢰 이뇌 李賴
# 강리 강이 康理
# 박린 박인 朴璘
# 김률 김율 金慄
# 옥려 옥여 玉礪
# 황린 황인 黃璘
# 이류 이유 李溜
# 표윤 표빈 表贇
# 권륜 권윤 權綸
# 허량 허양 許亮
# 이란 이난 李蘭
# 박률 박율 朴慄
# 김녕 김영 金寧
# 봉륜 봉윤 奉綸
# 정윤 정빈 鄭贇
# 김렬 김열 金洌
# 박린 박인 朴璘
# 강린 강인 姜麟
# 유송 유책 柳
# 권륙 권육 權
# 김련 김연 金輦
# 승륜 승윤 承綸
# 허륜 허윤 許綸
# 정려 정여 鄭旅
# 조녕 조영 趙寧
# 채륜 채윤 蔡倫
# 박려 박여 朴旅
# 강로 강노 姜老
# 권륜 권윤 權綸
# 권람 권남 權擥
# 김려 김여 金礪
# 박량 박양 朴良
# 권률 권율 權慄
# 이륙 이육 李陸
# 이래 이내 李徠
# 김륜 김윤 金崙
# 오릉 오능 吳凌
# 안림 안임 安琳
# 정륜 정윤 鄭綸
# 권류 권유 權瑠
# 최린 최인 崔潾
# 남률 남율 南慄
# 신류 신유 申瑠
# 임류 임유 任瀏
# 이령 이영 李翎
# 채락 채낙 蔡洛
# 박란 박난 朴蘭
# 임려 임여 任呂
# 신련 신연 辛璉
# 박률 박율 朴栗
# 김렴 김염 金濂
# 신륜 신윤 辛崙
# 장령 장영 張翎
# 이량 이양 李樑
# 이령 이영 李翎
# 권률 권율 權慄
# 이로 이노 李魯
# 이렴 이염 李濂
# 황뉴 황유 黃紐
# 한련 한연 韓璉
# 신률 신율 申慄
# 황림 황임 黃琳
# 김련 김연 金璉
# 윤리 윤이 尹理
# 윤윤 윤빈 尹贇
# 이류 이유 李瀏
# 신로 신노 申魯
# 강련 강연 姜鍊
# 최린 최인 崔璘
# 황념 황염 黃恬
# 임량 임양 任樑
# 성륜 성윤 成倫
# 김로 김노 金魯
# 이로 이노 李輅
# 성락 성낙 成洛
# 박렴 박염 朴簾
# 이립 이입 李砬
# 이윤 이빈 李贇
# 정륜 정윤 鄭崙
# 최렴 최염 崔濂
# 황락 황낙 黃洛
# 이람 이남 李覽
# 이옥 이욱 李稶
# 김륜 김윤 金崙
# 조윤 조빈 趙贇
# 임박 임부 林
# 유래 유내 柳徠
# 이륜 이윤 李綸
# 엄륜 엄윤 嚴綸
# 김려 김여 金礪
# 유래 유내 柳徠
# 엄린 엄인 嚴璘
# 이로 이노 李潞
# 남로 남노 南潞
# 장륙 장육 張陸
# 최윤 최빈 崔贇
# 이림 이임 李霖
# 김뉴 김유 金紐
# 문려 문여 文勵
# 조림 조임 趙琳

# %%
(len(df_similar_kor_name_lee),len(df_similar_kor_name_ws))
# Out:
# (104, 104)

# %%
assert(len(df_similar_kor_name_lee) == len(df_similar_kor_name_ws))

# %%
master2 = pd.merge(df_similar_kor_name_lee, df_similar_kor_name_ws, indicator=True, how='inner', left_on=['chnname','pass_year'], right_on = ['namehj1','year'])

# %%
# MERGING only on Chinese name and year
master2 = pd.merge(df_similar_kor_name_lee, df_similar_kor_name_ws, indicator=True, how='inner', left_on=['chnname','pass_year'], right_on = ['namehj1','year'])

# Drop duplicate Korean name, Chinese name, and exam year, then rename those columns to be clearer
master2 = master2.drop(columns=['namehg1', 'namehj1', 'year'])
master2 = master2.rename(columns={'korname':'kor_name', 'chnname':'chi_name'})

len(master2), len(master2['lee_uuid'].unique()), len(master2['ws_uuid'].unique())
# Out:
# (106, 104, 103)

# %%
# Merge these with master
frames = [master, master2]
master = pd.concat(frames, sort=False)

merge5 = master.copy()

# %%
# Update these values
lee_unmerged = data_lee[~data_lee['lee_uuid'].isin(master['lee_uuid'].unique())]
ws_unmerged = data_ws[~data_ws['ws_uuid'].isin(master['ws_uuid'].unique())]
len(ws_unmerged),len(lee_unmerged)
# Out:
# (338, 868)

# %% [markdown]
# # THIS NEEDS TO BE DOUBLE CHECKED

# %% [markdown]
# ## Year is the Same ... Korean and Chinese names 50% similar or less
# For this one I will ONLY be checking if for the given year, the Korean and Chinese names are more than 50 percent similar

# %%
master = master.reset_index(drop=True)

# %%
len(ws_unmerged),len(lee_unmerged), len(master)
# Out:
# (338, 868, 15476)

# %%
a = '省'
b = '省'
a == b
# Out:
# False

# %%
a = '龜'
b = '龜'
a == b
# Out:
# False

# %%
pd.set_option('display.max_rows', None)

# %%
df_similar_kor_name_lee = pd.DataFrame([])
df_similar_kor_name_ws = pd.DataFrame([])

# Iterate through each person in lee_unmerged
# Find that person in ws_person based on Chinese name and exam year
# Determine if if the person has similar Korean names, they are one person
# Look at the repeated_testtaker. If same numbers, fine
# If different numbers, take the larger of the values
# I guess for now, add repeat
for index, row in lee_unmerged.iterrows():
    exam_year = row['pass_year']
    chi_name = row['chnname']
    kor_name = row['korname']
    repeated = row['repeated_testtaker']
    
    # only matching Chinese name and exam year
    ws_person = ws_unmerged[(ws_unmerged['year'] == exam_year)]
    
    for person_index in range(len(ws_person)):
        if (similar(ws_person["namehg1"][person_index], kor_name) >= 0.5) and (similar(ws_person["namehj1"][person_index], chi_name) >= 0.5):
            print(kor_name, ws_person["namehg1"][person_index], chi_name, ws_person["namehj1"][person_index])
            row_copy = row.copy()
            row_copy['other_kor_name_in_WS_version'] = ws_person["namehg1"][person_index]
            row_copy['other_chi_name_in_WS_version'] = ws_person["namehj1"][person_index]
            row_copy['other_kor_name_in_WS_version_uuid'] = ws_person["ws_uuid"][person_index]
            df_similar_kor_name_lee = df_similar_kor_name_lee.append(row_copy)    
            df_similar_kor_name_ws = df_similar_kor_name_ws.append(ws_person)
# Out:
# 곽성귀 곽성구 郭聖龜 郭聖龜
# 이하 이복 李𩡘 李馥
# 정인 정린 鄭鄰 鄭隣
# 곽상 정상 郭常 鄭常
# 김이 김니 金膩 金
# 손서윤 손서륜 孫叙倫 孫倫
# 김귀 김구 金龜 金龜
# 장인신 장린신 張鄰臣 張隣臣
# 강삼 강참 姜參 姜參
# 섭천지 엽천지 葉千枝 葉千枝
# 박원영 박원령 朴元秢 朴元
# 김유 김류 金鏐 金
# 박귀원 박구원 朴龜元 朴龜元
# 최희삼 최희참 崔希參 崔希參
# 이전손 이부손 李傳孫 李傅孫
# 성몽열 성몽설 成夢說 成夢說
# 한세해 최세해 韓世瀣 崔世瀣
# 구정열 구정설 仇廷說 仇廷說
# 장언인 장언린 張彦鄰 張彦隣
# 김이 김니 金柅 金
# 최희열 최희설 崔希說 崔希說
# 박몽열 박몽설 朴夢說 朴夢說
# 양몽열 양몽설 梁夢說 梁夢說
# 이삼성 이삼생 李三省 李三省
# 김의민 전의민 金義民 全義民
# 노인진 노인전 盧仁瑱 盧仁
# 김삼낙 김삼악 金三樂 金三樂
# 강시성 강시생 康時省 康時省
# 김명열 김명설 金命說 金命說
# 김염 김렴 金𥖝 金
# 오억 오의 吳嶷 吳
# 노열지 노의지 盧說之 盧議之
# 장진 장전 張瑱 張
# 홍유귀 홍유구 洪有龜 洪有龜
# 김영 김령 金坽 金
# 권희열 권희설 權希說 權希說
# 김진내 김진래 金晉來 金晋來
# 유귀감 유구감 柳龜鑑 柳龜鑑
# 김정귀 김정구 金正龜 金正龜
# 정단 정현 鄭𦒜 鄭
# 이경열 이경설 李景說 李景說
# 홍낙인 홍악인 洪樂仁 洪樂仁
# 홍낙신 홍악신 洪樂信 洪樂信
# 홍낙임 홍악임 洪樂任 洪樂任
# 심상운 심익운 沈翔雲 沈翊雲
# 한용귀 한용구 韓用龜 韓用龜
# 유칭 유이 柳偁 柳
# 홍낙빈 홍악빈 洪樂彬 洪樂彬
# 윤열 윤설 尹說 尹說
# 홍낙정 홍악정 洪樂貞 洪樂貞
# 홍낙민 홍악민 洪樂敏 洪樂敏
# 홍낙안 홍악안 洪樂安 洪樂安
# 신귀조 신구조 申龜朝 申龜朝
# 홍낙준 홍악준 洪樂浚 洪樂浚
# 이동환 이동경 李東𤎈 李東
# 이경삼 이경참 李敬參 李敬參
# 김염 김렴 金鐮 金
# 조석귀 조석구 趙錫龜 趙錫龜
# 김노 김로 金鏴 金
# 조병귀 조병구 趙秉龜 趙秉龜
# 홍열모 홍설모 洪說謨 洪說謨
# 조귀하 조구하 趙龜夏 趙龜夏
# 이삼현 이참현 李參鉉 李參鉉
# 조귀식 조구식 趙龜植 趙龜植
# 강기 강지 姜𣹡 姜
# 김병계 김병연 金炳溎 金炳
# 강노 강로 姜㳣 姜
# 홍석종 홍종석 洪奭鍾 洪鍾奭
# 이낙중 이악중 李樂重 李樂重
# 홍대종 홍종대 洪大鐘 洪鐘大
# 김영노 김영로 金永珯 金永
# 이재귀 이재구 李載龜 李載龜
# 홍문영 홍문해 洪文泳 洪文海
# 김지 김륵 金漬 金
# 강인 강린 姜繗 姜
# 홍낙조 홍악조 洪樂祖 洪樂祖
# 윤좌벽 윤좌피 尹左辟 尹左
# 이입 이립 李苙 李
# 이지용 이은용 李址鎔 李垠鎔
# 백효삼 백효참 白效參 白效參
# 홍귀서 홍구서 洪龜瑞 洪龜瑞
# 나만섭 나만엽 羅萬葉 羅萬葉
# 강숙돌 강숙요 姜叔突 姜叔
# 김유 김구 金紐 金龜
# 김유 김구 金紐 金龜

# %%
(len(df_similar_kor_name_lee),len(df_similar_kor_name_ws))
# Out:
# (314, 627)

# %%
# MERGING only on Chinese name and year
master2 = pd.merge(df_similar_kor_name_lee, df_similar_kor_name_ws, indicator=True, how='inner', left_on=['pass_year'], right_on = ['year'])

# Drop duplicate Korean name, Chinese name, and exam year, then rename those columns to be clearer
master2 = master2.drop(columns=['namehg1', 'namehj1', 'year'])
master2 = master2.rename(columns={'korname':'kor_name', 'chnname':'chi_name'})

len(master2), len(master2['lee_uuid'].unique()), len(master2['ws_uuid'].unique())
# Out:
# (1627, 313, 323)

# %%
# Merge these with master
frames = [master, master2]
master = pd.concat(frames, sort=False)

merge6 = master.copy()

# %%
# Update these values
lee_unmerged = data_lee[~data_lee['lee_uuid'].isin(master['lee_uuid'].unique())]
ws_unmerged = data_ws[~data_ws['ws_uuid'].isin(master['ws_uuid'].unique())]
len(ws_unmerged),len(lee_unmerged)
# Out:
# (15, 555)

# %% [markdown]
# ### ALMOST DONE! Only 15 don't match

# %%
len(ws_unmerged),len(lee_unmerged)
# Out:
# (12, 555)

# %%
ws_unmerged[['namehg1', 'namehj1', 'year']]
# Out:
#                                      namehg1 namehj1    year
# uuid
# cc2f6185-57d6-5995-91d1-4922a2849055     노진해     盧晋諧  1435.0
# f4db3f2f-a1f5-5238-8df5-a5b00dbd959d     최니로     崔泥老  1441.0
# b897a60d-1c85-5ad0-a1cb-f2c3cda5680b     이극배     李克培     NaN
# 893bcf9f-b7b6-59fa-8e02-98c4b00cfb80     이운봉      李云  1453.0
# 4ed91eba-f1df-5747-8ad2-ec5c333a4e68      서근    徐土+甲  1462.0
# 78b1d4a1-c0e5-5092-84c7-2c55f44420dc     권구로     權龜老  1693.0
# 02a9d67c-53e1-589e-a023-0affbc08903b     장수구     張守龜  1708.0
# cea144cd-a435-5bdd-a69c-7f7cc1a37de7      이육      李堉  1740.0
# 82b40807-e32a-53ec-ad79-df1cf83da7b0     신리록     申履祿  1822.0
# 537ff78f-c509-5ef7-9104-2af8e562dd50     권구락     權龜洛  1837.0
# f9bed04b-1cf1-5f77-bb1d-11a1bc931dc8     박로참     朴魯參  1876.0
# c0b57392-53c2-54a4-b0e4-e58e0f5e9e14     홍종협     洪鍾協  1880.0

# %%
# MANUAL CHECK
lee_unmerged[lee_unmerged['pass_year'] == 1876][['korname', 'chnname']][4:5]
# Out:
#                                      korname chnname
# uuid
# 5aa6c870-9d40-508f-abcb-ec0fd7ea5818     박노삼     朴魯參

# %%
ws_person["namehg1"][0]
# Out:
# '최니로'

# %%
# Out:
#                                      korname chnname  pass_year
# uuid
# af5a2271-4040-573c-ad39-08c46f8a114f     이극배     李克培       1447

# %%
# Just do some manual merging
df_similar_kor_name_lee = pd.DataFrame([])
df_similar_kor_name_ws = pd.DataFrame([])

years = [1441, 1453, 1462, 1693, 1708, 1822, 1837]

for year in years:
    lee_person = lee_unmerged[lee_unmerged['pass_year'] == year]
    ws_person = ws_unmerged[ws_unmerged['year'] == year]
    lee_person['other_kor_name_in_WS_version'] = ws_person["namehg1"][0]
    lee_person['other_chi_name_in_WS_version'] = ws_person["namehj1"][0]
    lee_person['other_kor_name_in_WS_version_uuid'] = ws_person["ws_uuid"][0]

    df_similar_kor_name_lee = df_similar_kor_name_lee.append(lee_person)    
    df_similar_kor_name_ws = df_similar_kor_name_ws.append(ws_person)
    
# Special case is the year 1876
year = 1876
lee_person = lee_unmerged[lee_unmerged['pass_year'] == year][4:5]
ws_person = ws_unmerged[ws_unmerged['year'] == year]
lee_person['other_kor_name_in_WS_version'] = ws_person["namehg1"][0]
lee_person['other_chi_name_in_WS_version'] = ws_person["namehj1"][0]
lee_person['other_kor_name_in_WS_version_uuid'] = ws_person["ws_uuid"][0]

df_similar_kor_name_lee = df_similar_kor_name_lee.append(lee_person)    
df_similar_kor_name_ws = df_similar_kor_name_ws.append(ws_person)
# Out:
# /Users/yenniejun/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/yenniejun/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/yenniejun/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_similar_kor_name_lee
# Out:
#                                                                                     bid  \
# uuid
# af5a2271-4040-573c-ad39-08c46f8a114f  http://people.aks.ac.kr/front/dirSer/exm/exmVi...
#
#                                                                     bpid  \
# uuid
# af5a2271-4040-573c-ad39-08c46f8a114f  G002+AKS-KHF_13C774ADF9BC30B1422X0
#
#                                      affilliation  rank  competitors  \
# uuid
# af5a2271-4040-573c-ad39-08c46f8a114f           문과    15           33
#
#                                      exam_type  pass_year king  lid  \
# uuid
# af5a2271-4040-573c-ad39-08c46f8a114f       식년시       1447   세종  305
#
#                                         previous  ... korname  family_clan  \
# uuid                                              ...
# af5a2271-4040-573c-ad39-08c46f8a114f  신방생원(新榜生員)  ...     이극배       광주(廣州)
#
#                                        birth   death plastic  \
# uuid
# af5a2271-4040-573c-ad39-08c46f8a114f  1422.0  1495.0  silver
#
#                                                                   lee_uuid  \
# uuid
# af5a2271-4040-573c-ad39-08c46f8a114f  af5a2271-4040-573c-ad39-08c46f8a114f
#
#                                       repeated_testtaker  \
# uuid
# af5a2271-4040-573c-ad39-08c46f8a114f               False
#
#                                      other_kor_name_in_WS_version  \
# uuid
# af5a2271-4040-573c-ad39-08c46f8a114f                          이극배
#
#                                      other_chi_name_in_WS_version  \
# uuid
# af5a2271-4040-573c-ad39-08c46f8a114f                          李克培
#
#                                          other_kor_name_in_WS_version_uuid
# uuid
# af5a2271-4040-573c-ad39-08c46f8a114f  b897a60d-1c85-5ad0-a1cb-f2c3cda5680b
#
# [1 rows x 28 columns]

# %%
# MERGING only on Chinese name and year
master2 = pd.merge(df_similar_kor_name_lee, df_similar_kor_name_ws, indicator=True, how='inner', left_on=['pass_year'], right_on = ['year'])

# Drop duplicate Korean name, Chinese name, and exam year, then rename those columns to be clearer
master2 = master2.drop(columns=['namehg1', 'namehj1', 'year'])
master2 = master2.rename(columns={'korname':'kor_name', 'chnname':'chi_name'})

len(master2), len(master2['lee_uuid'].unique()), len(master2['ws_uuid'].unique())

# Merge these with master
frames = [master, master2]
master = pd.concat(frames, sort=False)

merge7 = master.copy()

# %%
# Update these values
lee_unmerged = data_lee[~data_lee['lee_uuid'].isin(master['lee_uuid'].unique())]
ws_unmerged = data_ws[~data_ws['ws_uuid'].isin(master['ws_uuid'].unique())]
len(ws_unmerged),len(lee_unmerged)
# Out:
# (7, 547)

# %% [markdown]
# ### ALMOST DONE - 4 more to go

# %%
# ws_unmerged.drop(ws_unmerged.tail(3).index,inplace=True)

# %%
lee_unmerged[lee_unmerged['korname'] == '이극배'][['korname', 'chnname', 'pass_year']]
# Out:
#                                      korname chnname  pass_year
# uuid
# af5a2271-4040-573c-ad39-08c46f8a114f     이극배     李克培       1447

# %%
# Another special case
lee_person = lee_unmerged[lee_unmerged['korname'] == '이극배']
ws_person = ws_unmerged[ws_unmerged['namehg1'] == '이극배']
lee_person['other_kor_name_in_WS_version'] = ws_person["namehg1"][0]
lee_person['other_chi_name_in_WS_version'] = ws_person["namehj1"][0]
lee_person['other_kor_name_in_WS_version_uuid'] = ws_person["ws_uuid"][0]

df_similar_kor_name_lee = df_similar_kor_name_lee.append(lee_person)    
df_similar_kor_name_ws = df_similar_kor_name_ws.append(ws_person)

# MERGING only on Chinese name and year
master2 = pd.merge(df_similar_kor_name_lee, df_similar_kor_name_ws, indicator=True, how='inner', left_on=['korname'], right_on = ['namehg1'])

# Drop duplicate Korean name, Chinese name, and exam year, then rename those columns to be clearer
master2 = master2.drop(columns=['namehg1', 'namehj1', 'year'])
master2 = master2.rename(columns={'korname':'kor_name', 'chnname':'chi_name'})

len(master2), len(master2['lee_uuid'].unique()), len(master2['ws_uuid'].unique())

# Merge these with master
frames = [master, master2]
master = pd.concat(frames, sort=False)

merge7 = master.copy()
# Out:
# /Users/yenniejun/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/yenniejun/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/yenniejun/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Update these values
lee_unmerged = data_lee[~data_lee['lee_uuid'].isin(master['lee_uuid'].unique())]
ws_unmerged = data_ws[~data_ws['ws_uuid'].isin(master['ws_uuid'].unique())]
len(ws_unmerged),len(lee_unmerged)
# Out:
# (6, 546)

# %%
len(ws_unmerged),len(lee_unmerged)
# Out:
# (6, 546)

# %% [markdown]
# ### Can't match these. IDK ㅠㅠㅠㅠ

# %%
ws_unmerged[['namehg1', 'namehj1', 'year']]
# Out:
#                                      namehg1 namehj1    year
# uuid
# cc2f6185-57d6-5995-91d1-4922a2849055     노진해     盧晋諧  1435.0
# cea144cd-a435-5bdd-a69c-7f7cc1a37de7      이육      李堉  1740.0
# c0b57392-53c2-54a4-b0e4-e58e0f5e9e14     홍종협     洪鍾協  1880.0
# namehj1                                  NaN     NaN     NaN
# prevdegreehj                             NaN     NaN     NaN
# choronymhj                               NaN     NaN     NaN

# %% [markdown]
# ## Just merge the remaining unmatchable ones with Master

# %%
len(lee_unmerged)
# Out:
# 546

# %%
lee_unmerged.head().T
# Out:
# uuid                             8cee2162-e5a0-5ebf-b4ab-65cc828c8f87  \
# bid                 http://people.aks.ac.kr/front/dirSer/exm/exmVi...
# bpid                               G002+AKS-KHF_13C720C5B8C220B1703X0
# affilliation                                                       문과
# rank                                                                3
# competitors                                                         7
# exam_type                                                          중시
# pass_year                                                        1757
# king                                                               영조
# lid                                                                30
# previous                                             세자시강원보덕(世子侍講院輔德)
# exam_class                                                     을과(乙科)
# class_rank                                                          2
# pass_date                                                  1757-07-01
# bc_level                                                          4.5
# solardate                                                  1757-07-01
# bcid                                                          bc11148
# gid                                                               815
# chnname                                                           兪彦述
# korname                                                           유언술
# family_clan                                                    기계(杞溪)
# birth                                                            1703
# death                                                            1773
# plastic                                                        silver
# lee_uuid                         8cee2162-e5a0-5ebf-b4ab-65cc828c8f87
# repeated_testtaker                                              False
#
# uuid                             4024acde-e21b-532c-b7c2-0191b1cf948e  \
# bid                 http://people.aks.ac.kr/front/dirSer/exm/exmVi...
# bpid                               G002+AKS-KHF_13C815AD11C6D0U9999X0
# affilliation                                                       문과
# rank                                                                3
# competitors                                                         5
# exam_type                                                          중시
# pass_year                                                        1416
# king                                                               태종
# lid                                                                96
# previous                                                 성균관학유(成均館學諭)
# exam_class                                                 을과2등(乙科二等)
# class_rank                                                          1
# pass_date                                                  1416-07-01
# bc_level                                                         17.5
# solardate                                                  1416-07-01
# bcid                                                          bc11166
# gid                                                               799
# chnname                                                           鄭廣元
# korname                                                           정광원
# family_clan                                                    진양(晉陽)
# birth                                                             NaN
# death                                                             NaN
# plastic                                                       plastic
# lee_uuid                         4024acde-e21b-532c-b7c2-0191b1cf948e
# repeated_testtaker                                              False
#
# uuid                             ecf30d95-77b0-5eb8-a16b-09ddc8e20224  \
# bid                 http://people.aks.ac.kr/front/dirSer/exm/exmVi...
# bpid                               G002+AKS-KHF_12C548C9C0FFFFB1377X0
# affilliation                                                       문과
# rank                                                                5
# competitors                                                         5
# exam_type                                                          중시
# pass_year                                                        1416
# king                                                               태종
# lid                                                                96
# previous                                                 승문원정자(承文院正字)
# exam_class                                                 을과2등(乙科二等)
# class_rank                                                          3
# pass_date                                                  1416-07-01
# bc_level                                                         16.5
# solardate                                                  1416-07-01
# bcid                                                          bc11167
# gid                                                               891
# chnname                                                            安止
# korname                                                            안지
# family_clan                                                    탐진(耽津)
# birth                                                            1377
# death                                                            1464
# plastic                                                       plastic
# lee_uuid                         ecf30d95-77b0-5eb8-a16b-09ddc8e20224
# repeated_testtaker                                              False
#
# uuid                             a4c797c1-72b7-56ca-96f0-9e635dba41fd  \
# bid                 http://people.aks.ac.kr/front/dirSer/exm/exmVi...
# bpid                               G002+AKS-KHF_13D55CCC98BA85U9999X0
# affilliation                                                       문과
# rank                                                                7
# competitors                                                        12
# exam_type                                                          중시
# pass_year                                                        1427
# king                                                               세종
# lid                                                                96
# previous                                                       교리(校理)
# exam_class                                                 을과2등(乙科二等)
# class_rank                                                          4
# pass_date                                                  1427-07-01
# bc_level                                                          9.5
# solardate                                                  1427-07-01
# bcid                                                          bc11179
# gid                                                                17
# chnname                                                           韓處命
# korname                                                           한처명
# family_clan                                                    미상(未詳)
# birth                                                             NaN
# death                                                             NaN
# plastic                                                       plastic
# lee_uuid                         a4c797c1-72b7-56ca-96f0-9e635dba41fd
# repeated_testtaker                                              False
#
# uuid                             212661e1-c72d-5529-8031-4b0a4654b501
# bid                 http://people.aks.ac.kr/front/dirSer/exm/exmVi...
# bpid                               G002+AKS-KHF_13B178C120ACBDU9999X0
# affilliation                                                       문과
# rank                                                                6
# competitors                                                        33
# exam_type                                                         식년시
# pass_year                                                        1435
# king                                                               세종
# lid                                                                96
# previous                                                     신생원(新生員)
# exam_class                                                     병과(丙科)
# class_rank                                                          3
# pass_date                                                  1435-07-01
# bc_level                                                           15
# solardate                                                  1438-07-01
# bcid                                                            bc997
# gid                                                              2229
# chnname                                                           盧善卿
# korname                                                           노선경
# family_clan                                                    광주(光州)
# birth                                                             NaN
# death                                                             NaN
# plastic                                                       plastic
# lee_uuid                         212661e1-c72d-5529-8031-4b0a4654b501
# repeated_testtaker                                              False

# %%
lee_unmerged = lee_unmerged.rename(columns={'korname':'kor_name', 'chnname':'chi_name'})
lee_unmerged['ws_uuid'] = np.NaN

len(lee_unmerged), len(lee_unmerged['lee_uuid'].unique())

# Merge these with master
frames = [master, master2]
master = pd.concat(frames, sort=False)

merge8 = master.copy()

# %%
ws_unmerged = ws_unmerged.rename(columns={'namehg1':'kor_name', 'namehj1':'chi_name'})
ws_unmerged['lee_uuid'] = np.NaN

len(ws_unmerged), len(ws_unmerged['ws_uuid'].unique())

# Merge these with master
frames = [master, master2]
master = pd.concat(frames, sort=False)

merge8 = master.copy()

# %% [markdown]
# # Clean up Master

# %%
len(master)
# Out:
# 17133

# %%
master = master.reset_index(drop=True)

# %%
# Out:
#                                                                                    0  \
# bid                                http://people.aks.ac.kr/front/dirSer/exm/exmVi...
# bpid                                              G002+AKS-KHF_13C774C218B4DDB1697X0
# affilliation                                                                      문과
# rank                                                                               3
# competitors                                                                       15
# exam_type                                                                        정시2
# pass_year                                                                       1753
# king                                                                              영조
# lid                                                                               30
# previous                                                                    부사과(副司果)
# exam_class                                                                    을과(乙科)
# class_rank                                                                         2
# pass_date                                                                 1753-07-01
# bc_level                                                                        11.5
# solardate                                                                 1753-07-01
# bcid                                                                         bc11147
# gid                                                                             2274
# chi_name                                                                         李秀得
# kor_name                                                                         이수득
# family_clan                                                                   한산(韓山)
# birth                                                                           1697
# death                                                                           1775
# plastic                                                                       silver
# lee_uuid                                        4b854af7-3d4b-51c9-802e-117ff4825291
# repeated_testtaker_x                                                               0
# id1                                                                             8960
# prevdegreehg                                                                     부사과
# prevdegreehj                                                                     副司果
# source                                           MTPA 091B 4D; PSTP 13-013B, 19-032B
# courtesynamehg                                                                    중오
# courtesynamehj                                                                    仲五
# ancestralseathg                                                                   한산
# choronymhg                                                                      한산 이
# ancestralseathj                                                                   韓山
# choronymhj                                                                      韓山 李
# addresshg                                                                         공주
# addresshj                                                                         公州
# pennamehg                                                                        NaN
# pennamehj                                                                        NaN
# posthumoustitlehg                                                                NaN
# posthumoustitlehj                                                                NaN
# error                                                                            NaN
# ws_uuid                                         660a2a20-d407-5ad0-b364-cd9e7edbb82c
# repeated_testtaker_y                                                               0
# _merge                                                                          both
# other_kor_name_in_WS_version                                                     NaN
# other_kor_name_in_WS_version_uuid                                                NaN
# index                                                                            NaN
# other_chi_name_in_WS_version                                                     NaN
# other_chi_name_in_WS_version_uuid                                                NaN
#
#                                                                                    1  \
# bid                                http://people.aks.ac.kr/front/dirSer/exm/exmVi...
# bpid                                              G002+AKS-KHF_13C2E0AE30D604B1747X0
# affilliation                                                                      문과
# rank                                                                              15
# competitors                                                                       18
# exam_type                                                                         정시
# pass_year                                                                       1784
# king                                                                              정조
# lid                                                                               30
# previous                                                                      유학(幼學)
# exam_class                                                                    병과(丙科)
# class_rank                                                                        12
# pass_date                                                                 1784-07-01
# bc_level                                                                          15
# solardate                                                                 1787-07-01
# bcid                                                                           bc758
# gid                                                                             2227
# chi_name                                                                         申驥顯
# kor_name                                                                         신기현
# family_clan                                                                   평산(平山)
# birth                                                                           1747
# death                                                                            NaN
# plastic                                                                       silver
# lee_uuid                                        8a1e8a21-4d10-5ae3-b92d-51acfbb31ba6
# repeated_testtaker_x                                                               0
# id1                                                                            10361
# prevdegreehg                                                                      유학
# prevdegreehj                                                                      幼學
# source                                           MTPB 046B 4B; PSTP 28-085A, 34-040B
# courtesynamehg                                                                   NaN
# courtesynamehj                                                                   NaN
# ancestralseathg                                                                   평산
# choronymhg                                                                      평산 신
# ancestralseathj                                                                   平山
# choronymhj                                                                      平山 申
# addresshg                                                                         공주
# addresshj                                                                         公州
# pennamehg                                                                         옥서
# pennamehj                                                                         玉署
# posthumoustitlehg                                                                NaN
# posthumoustitlehj                                                                NaN
# error                                                                            NaN
# ws_uuid                                         85fe658e-5b35-50b1-a41b-aeb916ae13bb
# repeated_testtaker_y                                                               0
# _merge                                                                          both
# other_kor_name_in_WS_version                                                     NaN
# other_kor_name_in_WS_version_uuid                                                NaN
# index                                                                            NaN
# other_chi_name_in_WS_version                                                     NaN
# other_chi_name_in_WS_version_uuid                                                NaN
#
#                                                                                    2  \
# bid                                http://people.aks.ac.kr/front/dirSer/exm/exmVi...
# bpid                                              G002+AKS-KHF_13BC15C885ACB8B1744X0
# affilliation                                                                      문과
# rank                                                                               5
# competitors                                                                       10
# exam_type                                                                         정시
# pass_year                                                                       1785
# king                                                                              정조
# lid                                                                               30
# previous                                                                      유학(幼學)
# exam_class                                                                    병과(丙科)
# class_rank                                                                         2
# pass_date                                                                 1785-07-01
# bc_level                                                                          15
# solardate                                                                 1788-07-01
# bcid                                                                           bc759
# gid                                                                             2227
# chi_name                                                                         朴宗謙
# kor_name                                                                         박종겸
# family_clan                                                                   반남(潘南)
# birth                                                                           1744
# death                                                                           1799
# plastic                                                                       silver
# lee_uuid                                        fecc75c4-0045-5485-b47c-851767e002e3
# repeated_testtaker_x                                                               0
# id1                                                                            10382
# prevdegreehg                                                                      유학
# prevdegreehj                                                                      幼學
# source                                                    MTPA 207A 4D; PSTP 26-023B
# courtesynamehg                                                                    군실
# courtesynamehj                                                                    君實
# ancestralseathg                                                                   반남
# choronymhg                                                                      반남 박
# ancestralseathj                                                                   潘南
# choronymhj                                                                      潘南 朴
# addresshg                                                                         공주
# addresshj                                                                         公州
# pennamehg                                                                        NaN
# pennamehj                                                                        NaN
# posthumoustitlehg                                                                NaN
# posthumoustitlehj                                                                NaN
# error                                                                            NaN
# ws_uuid                                         9b6c41ef-f960-5856-9a25-99c0f379e59f
# repeated_testtaker_y                                                               0
# _merge                                                                          both
# other_kor_name_in_WS_version                                                     NaN
# other_kor_name_in_WS_version_uuid                                                NaN
# index                                                                            NaN
# other_chi_name_in_WS_version                                                     NaN
# other_chi_name_in_WS_version_uuid                                                NaN
#
#                                                                                    3  \
# bid                                http://people.aks.ac.kr/front/dirSer/exm/exmVi...
# bpid                                              G002+AKS-KHF_13C5C4C775C870B1849X0
# affilliation                                                                      문과
# rank                                                                              29
# competitors                                                                       44
# exam_type                                                                         정시
# pass_year                                                                       1885
# king                                                                              고종
# lid                                                                               80
# previous                                                                      유학(幼學)
# exam_class                                                                    병과(丙科)
# class_rank                                                                        26
# pass_date                                                                 1885-07-01
# bc_level                                                                          15
# solardate                                                                 1888-07-01
# bcid                                                                           bc761
# gid                                                                             2227
# chi_name                                                                         嚴益祚
# kor_name                                                                         엄익조
# family_clan                                                                   영월(寧越)
# birth                                                                           1849
# death                                                                            NaN
# plastic                                                                      plastic
# lee_uuid                                        46963c7a-bb8b-52f1-a06a-f128133fe0ab
# repeated_testtaker_x                                                               0
# id1                                                                            13817
# prevdegreehg                                                                      유학
# prevdegreehj                                                                      幼學
# source                                                                        MTP NL
# courtesynamehg                                                                   NaN
# courtesynamehj                                                                   NaN
# ancestralseathg                                                                   영월
# choronymhg                                                                      영월 엄
# ancestralseathj                                                                   寧越
# choronymhj                                                                      寧越 嚴
# addresshg                                                                         덕원
# addresshj                                                                         德源
# pennamehg                                                                        NaN
# pennamehj                                                                        NaN
# posthumoustitlehg                                                                NaN
# posthumoustitlehj                                                                NaN
# error                                                                            NaN
# ws_uuid                                         eb3b33fc-139f-5a8e-952e-c26a1c7b0b48
# repeated_testtaker_y                                                               0
# _merge                                                                          both
# other_kor_name_in_WS_version                                                     NaN
# other_kor_name_in_WS_version_uuid                                                NaN
# index                                                                            NaN
# other_chi_name_in_WS_version                                                     NaN
# other_chi_name_in_WS_version_uuid                                                NaN
#
#                                                                                    4
# bid                                http://people.aks.ac.kr/front/dirSer/exm/exmVi...
# bpid                                              G002+AKS-KHF_13B0A8C815AD6CB1866X0
# affilliation                                                                      문과
# rank                                                                               5
# competitors                                                                        8
# exam_type                                                                      함경도도과
# pass_year                                                                       1887
# king                                                                              고종
# lid                                                                               80
# previous                                                                      유학(幼學)
# exam_class                                                                    병과(丙科)
# class_rank                                                                         3
# pass_date                                                                 1887-07-01
# bc_level                                                                          15
# solardate                                                                 1890-07-01
# bcid                                                                           bc762
# gid                                                                             2227
# chi_name                                                                         南廷逑
# kor_name                                                                         남정구
# family_clan                                                                   의령(宜寧)
# birth                                                                           1866
# death                                                                            NaN
# plastic                                                                      plastic
# lee_uuid                                        5a860ee8-ecb6-5702-9d17-1bcabacdf769
# repeated_testtaker_x                                                               0
# id1                                                                            13956
# prevdegreehg                                                                      유학
# prevdegreehj                                                                      幼學
# source                                                                        MTP NL
# courtesynamehg                                                                   NaN
# courtesynamehj                                                                   NaN
# ancestralseathg                                                                   의녕
# choronymhg                                                                      의녕 남
# ancestralseathj                                                                   宜寧
# choronymhj                                                                      宜寧 南
# addresshg                                                                         덕원
# addresshj                                                                         德源
# pennamehg                                                                        NaN
# pennamehj                                                                        NaN
# posthumoustitlehg                                                                NaN
# posthumoustitlehj                                                                NaN
# error                                                                            NaN
# ws_uuid                                         18ed6221-5556-5632-86ed-848515adeafb
# repeated_testtaker_y                                                               0
# _merge                                                                          both
# other_kor_name_in_WS_version                                                     NaN
# other_kor_name_in_WS_version_uuid                                                NaN
# index                                                                            NaN
# other_chi_name_in_WS_version                                                     NaN
# other_chi_name_in_WS_version_uuid                                                NaN

# %%
# Find the dudes in Lee with same Chinese name and exam year as WS dudes
# If their Korean names are at least 60 percent similar, then add them to the merged master table
# TODO - add the UUID of the WS dude to the master table
# TODO - add a list of dictionary to master table including dude's other names, and what other sources these other names come from

# %%
# TO DO - add ID for the mastertable
