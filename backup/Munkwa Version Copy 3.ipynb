# %%
import pandas as pd
import numpy as np
import re
import uuid

# %% [markdown]
# For Lee:
# * `bpid`: unique id for each person
# * `lee_uuid`: unique id for each instance of taking a test
# * `repeated_testtaker`: True if the person has taken the test multiple times in the SAME YEAR, False otherwise
#
#
# For WS:
# * `ws_uuid`: unique id for each instance of taking a test. Directly tied to `id1`
# * `repeated_testtaker`: True if the person has taken the test multiple times in the SAME YEAR, False otherwise
# * Currently no unique id for each person
#
#
# Goals:
# * Need to detect and merge the same person from both datafiles
# * Each instance of taking a test has a unique ID in each datafile
#
# Edge Cases:
# * One person takes exam multiple times in the same year. More instances in Lee than in WS --> Copy each person in WS to each instance in Lee
# * One person takes exam multiple times in the same year. More instances in WS than in Lee --> Add extra rows to merged file, copying each instance in Lee to match each instance in WS

# %% [markdown]
# ## Lee Munkwa Version: `data_lee`

# %%
bangmok = pd.read_csv('../../data/preprocessing/bangmok/bangmok.csv')
career = pd.read_csv('../../data/preprocessing/bangmok/bangmok_career.csv')
person = pd.read_csv('../../data/preprocessing/bangmok/bangmok_person.csv')

# %%
len(bangmok), len(career), len(person)
# Out:
# (15151, 15151, 14638)

# %%
# merge bangmok and career
bangmok_career = pd.merge(bangmok,career, on='bid', how='outer')

# %%
eq = bangmok_career['bpid_x'] == bangmok_career['bpid_y']
[i for i, x in enumerate(eq) if not x]

# This means we can merge these two columns
bangmok_career = bangmok_career.rename(columns={"bpid_x":"bpid"}).drop(columns=["bpid_y"])

# %%
# merge bankmok, career, person
bangmok_career_person = pd.merge(bangmok_career,person,on='bpid',how='left')

# %%
data_lee = bangmok_career_person
len(data_lee), len(data_lee['bid'].unique())
# Out:
# (15151, 15151)

# %% [markdown]
# Create UUID for each unique BID. This UUID is based off of a hash from the BID, so it will be the same for each BID.

# %%
data_lee['uuid'] = [uuid.uuid5(uuid.NAMESPACE_DNS,x) for x in data_lee['bid']]
data_lee = data_lee.set_index('uuid')
data_lee['lee_uuid'] = data_lee.index

# %% [markdown]
# Data exploration: Those who have repeated taking the test multiple times in one year

# %%
# These are the people who took the same example multiple times in the SAME YEAR 
# i.e. they are the duplicates of the korean name/chinese name/pass year. 
# data_lee[data_lee[['korname', 'chnname', 'pass_year']].duplicated(keep=False)][['korname', 'chnname', 'pass_year']].sort_values(by=['pass_year', 'korname'])

# %%
# These are the people who took the test multiple times in any given year
# data_lee[data_lee[['korname', 'chnname']].duplicated(keep=False)][['korname', 'chnname', 'pass_year']].sort_values(by=['korname', 'pass_year'])

# %%
# Marking those who took the test more than once in the same year
data_lee['repeated_testtaker_lee'] = data_lee[['korname', 'chnname','pass_year']].duplicated(keep=False)

# %%
len(data_lee)
# Out:
# 15151

# %% [markdown]
# Drop the columns we don't need for the final table comparison

# %%
data_lee = data_lee[['lee_uuid', 'pass_year', 'korname', 'chnname', 'repeated_testtaker_lee']].copy()

# %%
data_lee.head(3).T
# Out:
# uuid                    4b854af7-3d4b-51c9-802e-117ff4825291  \
# lee_uuid                4b854af7-3d4b-51c9-802e-117ff4825291
# pass_year                                               1753
# korname                                                  이수득
# chnname                                                  李秀得
# repeated_testtaker_lee                                 False
#
# uuid                    8cee2162-e5a0-5ebf-b4ab-65cc828c8f87  \
# lee_uuid                8cee2162-e5a0-5ebf-b4ab-65cc828c8f87
# pass_year                                               1757
# korname                                                  유언술
# chnname                                                  兪彦述
# repeated_testtaker_lee                                 False
#
# uuid                    8a1e8a21-4d10-5ae3-b92d-51acfbb31ba6
# lee_uuid                8a1e8a21-4d10-5ae3-b92d-51acfbb31ba6
# pass_year                                               1784
# korname                                                  신기현
# chnname                                                  申驥顯
# repeated_testtaker_lee                                 False

# %% [markdown]
# ## WS Munkwa Version: `data_ws`

# %%
data_ws = pd.read_csv('../../data/raw/WS_Munkwa.csv')

# Ensure there are no duplicate IDs
len(data_ws), len(data_ws['id1'].unique()), len(data_ws['source'].unique())
# Out:
# (14607, 14607, 10591)

# %% [markdown]
# Create UUID for each unique BID. This UUID is based off converting the id to a string because that is the only unique value we have in this df. Since this isn't the most secure, we could change this to be random. But I don't think it matters much

# %%
data_ws['uuid'] = [uuid.uuid5(uuid.NAMESPACE_DNS,str(x)) for x in data_ws['id1']]
data_ws = data_ws.set_index('uuid');
data_ws['ws_uuid'] = data_ws.index

# %%
# data_ws.head().T

# %%
# Verify there are no duplicates
data_ws[data_ws.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id1, namehg1, namehj1, year, prevdegreehg, prevdegreehj, source, courtesynamehg, courtesynamehj, ancestralseathg, choronymhg, ancestralseathj, choronymhj, addresshg, addresshj, pennamehg, pennamehj, posthumoustitlehg, posthumoustitlehj, error, ws_uuid]
# Index: []
#
# [0 rows x 21 columns]

# %%
# These are the people who took the same example multiple times in the SAME YEAR 
# i.e. they are the duplicates of the korean name/chinese name/pass year. 
data_ws[data_ws[['namehj1', 'namehg1', 'year']].duplicated(keep=False)][['namehg1', 'namehj1', 'year']].sort_values(by=['year', 'namehg1'])
# Out:
#                                      namehg1 namehj1    year
# uuid
# a28023af-8791-5c39-9f49-2856c57cf410      이목       李  1612.0
# 1da79682-6fb5-5029-bca5-9969dd572b9b      이목       李  1612.0
# 4f879759-7396-5b4f-8d6c-2a7c57ba1754     김익진     金益振  1651.0
# a29d8bb7-b3e1-5a90-b9db-29c779ae4513     김익진     金益振  1651.0
# 4e6fe550-8d80-5c69-89a4-5071bf539533      이육      李堉  1740.0
# cea144cd-a435-5bdd-a69c-7f7cc1a37de7      이육      李堉  1740.0
# 4bd1bb73-339b-58bb-921a-ae2e33f6bfb4     홍종협     洪鍾協  1880.0
# c0b57392-53c2-54a4-b0e4-e58e0f5e9e14     홍종협     洪鍾協  1880.0
# 26044751-d6bd-534a-ae6b-965fc8389ed4     이윤재     李允在  1887.0
# 5af472e3-2855-5288-851d-1b8698aae187     이윤재     李允在  1887.0

# %%
# Marking those who took the test more than once as such in the SAME YEAR
data_ws['repeated_testtaker_ws'] = data_ws[['namehj1', 'namehg1', 'year']].duplicated(keep=False)

# %% [markdown]
# Drop the columns so we only have the ones we need

# %%
data_ws = data_ws[['ws_uuid', 'year', 'namehg1', 'namehj1', 'repeated_testtaker_ws']]

# %%
data_ws.head().T
# Out:
# uuid                   b04965e6-a9bb-591f-8f8a-1adcb2c8dc39  \
# ws_uuid                b04965e6-a9bb-591f-8f8a-1adcb2c8dc39
# year                                                   1393
# namehg1                                                 송개신
# namehj1                                                 宋介臣
# repeated_testtaker_ws                                 False
#
# uuid                   4b166dbe-d99d-5091-abdd-95b83330ed3a  \
# ws_uuid                4b166dbe-d99d-5091-abdd-95b83330ed3a
# year                                                   1393
# namehg1                                                 김효원
# namehj1                                                 金孝源
# repeated_testtaker_ws                                 False
#
# uuid                   98123fde-012f-5ff3-8b50-881449dac91a  \
# ws_uuid                98123fde-012f-5ff3-8b50-881449dac91a
# year                                                   1393
# namehg1                                                  이담
# namehj1                                                  李擔
# repeated_testtaker_ws                                 False
#
# uuid                   6ed955c6-506a-5343-9be4-2c0afae02eef  \
# ws_uuid                6ed955c6-506a-5343-9be4-2c0afae02eef
# year                                                   1393
# namehg1                                                  탁함
# namehj1                                                   卓
# repeated_testtaker_ws                                 False
#
# uuid                   c8691da2-158a-5ed6-8537-0e6f140801f2
# ws_uuid                c8691da2-158a-5ed6-8537-0e6f140801f2
# year                                                   1393
# namehg1                                                  윤정
# namehj1                                                  尹定
# repeated_testtaker_ws                                 False

# %% [markdown]
# ## Clean up encodings

# %%
len(data_lee), len(data_ws)
# Out:
# (15151, 14607)

# %% [markdown]
# A special Hanja character case: Looks the same but they're NOT

# %%
lee_character = '金'
ws_character = '金'

data_ws = data_ws.replace(to_replace=r'金', value=ws_character, regex=True)

# %% [markdown]
# These are dueum (두음) - Korean syllables that can be pronounced in different ways. Using this dictionary, I am keeping these consistent across versions

# %%
dueum = {
    '라': '나', '락': '낙', '란': '난', '랄': '날', '람': '남', '랍': '납', '랑': '낭', '래': '내', '랭': '냉', '냑': '약', '략': '약', '냥': '양', '량': '양', '녀': '여', '려': '여', '녁': '역', '력': '역', '년': '연', '련': '연', '녈': '열', '렬': '열', '념': '염', '렴': '염', '렵': '엽', '녕': '영', '령': '영', '녜': '예', '례': '예', '로': '노', '록': '녹', '론': '논', '롱': '농', '뢰': '뇌', '뇨': '요', '료': '요', '룡': '용', '루': '누', '뉴': '유', '류': '유', '뉵': '육', '륙': '육', '륜': '윤', '률': '율', '륭': '융', '륵': '늑', '름': '늠', '릉': '능', '니': '이', '리': '이', '린': '인', '림': '임', '립': '입'
}

# %%
# Replace duem in both versions and replace the csv in preprocessing file
for k, v in dueum.items():
    data_ws = data_ws.replace(to_replace=k, value=v, regex=True)
    data_lee = data_lee.replace(to_replace=k, value=v, regex=True)

# %%
# Little endian thing /ufeff
data_ws['namehj1'] = data_ws['namehj1'].str.replace('\ufeff','')
data_lee['chnname'] = data_lee['chnname'].str.replace('\ufeff','')

# %% [markdown]
# ## `merge1` - Merge the Overlapping Areas of the Two Versions

# %% [markdown]
# We want to create a master table, where we merge the WS into the Lee version
#
# We want to:
# * Make a list of different name spellings, if they exist
# * Indicate if a person is in Lee but not in WS
# * Indicate if a person is in WS but not Lee

# %%
len(data_lee), len(data_lee['lee_uuid'].unique())
# Out:
# (15151, 15151)

# %%
# First, inner merge on the Korean name, Chinese name, and exam year
master = pd.merge(data_lee, data_ws,  indicator=True, how='inner', left_on=['korname','chnname','pass_year'], right_on = ['namehg1','namehj1','year'])

# Drop duplicate Korean name, Chinese name, and exam year, then rename those columns to be clearer
master = master.drop(columns=['namehg1', 'namehj1', 'year'])
master = master.rename(columns={'korname':'kor_name', 'chnname':'chi_name'})

len(master), len(master['lee_uuid'].unique()), len(master['ws_uuid'].unique())
# Out:
# (13208, 13201, 13195)

# %% [markdown]
# Remove duplicates only if `repeated_testtaker_lee` and `repeated_testtaker_ws` are BOTH `True`.
#
# (For other cases, it means that we WANT to keep the repeats)
#
# In the case when both are True, currently we are getting double the amount of repeats. For example, if person A in Lee takes test twice in the same year, and person A in WS takes the test twice in the same year, then we end up with 4 entries, when we want 2. We need to be careful about how we drop the duplicates.

# %%
# Duplicates of the lee_uuid
lee_dup = master[master.duplicated('lee_uuid', False)]

# %%
lee_dup[['kor_name', 'pass_year', 'lee_uuid', 'ws_uuid', 'repeated_testtaker_lee', 'repeated_testtaker_ws']]
# Out:
#      kor_name  pass_year                              lee_uuid  \
# 7892      이윤재       1887  383bd960-4527-540f-bb30-ba9643645ce7
# 7893      이윤재       1887  383bd960-4527-540f-bb30-ba9643645ce7
# 8237      홍종협       1880  76caa537-e6b1-5c89-a94b-847732b7bd4a
# 8238      홍종협       1880  76caa537-e6b1-5c89-a94b-847732b7bd4a
# 8239      홍종협       1880  4663c45d-a6f2-5c33-b405-baed07cac13f
# 8240      홍종협       1880  4663c45d-a6f2-5c33-b405-baed07cac13f
# 8321       이육       1740  92542b7a-6e09-5d1e-b277-15670311f752
# 8322       이육       1740  92542b7a-6e09-5d1e-b277-15670311f752
# 8323       이육       1740  7ba41301-6da0-541d-9c48-3eec7cf1a2a1
# 8324       이육       1740  7ba41301-6da0-541d-9c48-3eec7cf1a2a1
# 9959      김익진       1651  a53a1875-d574-52a1-9ba1-c39620eced18
# 9960      김익진       1651  a53a1875-d574-52a1-9ba1-c39620eced18
# 9961      김익진       1651  8ccdafa7-8b43-581e-9fff-d5c55316f7ff
# 9962      김익진       1651  8ccdafa7-8b43-581e-9fff-d5c55316f7ff
#
#                                    ws_uuid  repeated_testtaker_lee  \
# 7892  26044751-d6bd-534a-ae6b-965fc8389ed4                   False
# 7893  5af472e3-2855-5288-851d-1b8698aae187                   False
# 8237  4bd1bb73-339b-58bb-921a-ae2e33f6bfb4                    True
# 8238  c0b57392-53c2-54a4-b0e4-e58e0f5e9e14                    True
# 8239  4bd1bb73-339b-58bb-921a-ae2e33f6bfb4                    True
# 8240  c0b57392-53c2-54a4-b0e4-e58e0f5e9e14                    True
# 8321  4e6fe550-8d80-5c69-89a4-5071bf539533                    True
# 8322  cea144cd-a435-5bdd-a69c-7f7cc1a37de7                    True
# 8323  4e6fe550-8d80-5c69-89a4-5071bf539533                    True
# 8324  cea144cd-a435-5bdd-a69c-7f7cc1a37de7                    True
# 9959  4f879759-7396-5b4f-8d6c-2a7c57ba1754                    True
# 9960  a29d8bb7-b3e1-5a90-b9db-29c779ae4513                    True
# 9961  4f879759-7396-5b4f-8d6c-2a7c57ba1754                    True
# 9962  a29d8bb7-b3e1-5a90-b9db-29c779ae4513                    True
#
#       repeated_testtaker_ws
# 7892                   True
# 7893                   True
# 8237                   True
# 8238                   True
# 8239                   True
# 8240                   True
# 8321                   True
# 8322                   True
# 8323                   True
# 8324                   True
# 9959                   True
# 9960                   True
# 9961                   True
# 9962                   True

# %%
# Manually remove the people repeated in both Lee and in WS so there is 1-1 mapping
# Deduplicate if the person is marked as repeated in both datasets

# Test to make sure this is true. Once we have manually validated, then drop from master table
lee_dup = lee_dup.drop([8237, 8240, 8321, 8324, 9959, 9962])
lee_dup[['kor_name', 'pass_year', 'lee_uuid', 'ws_uuid', 'repeated_testtaker_lee', 'repeated_testtaker_ws']]
# Out:
#      kor_name  pass_year                              lee_uuid  \
# 7892      이윤재       1887  383bd960-4527-540f-bb30-ba9643645ce7
# 7893      이윤재       1887  383bd960-4527-540f-bb30-ba9643645ce7
# 8238      홍종협       1880  76caa537-e6b1-5c89-a94b-847732b7bd4a
# 8239      홍종협       1880  4663c45d-a6f2-5c33-b405-baed07cac13f
# 8322       이육       1740  92542b7a-6e09-5d1e-b277-15670311f752
# 8323       이육       1740  7ba41301-6da0-541d-9c48-3eec7cf1a2a1
# 9960      김익진       1651  a53a1875-d574-52a1-9ba1-c39620eced18
# 9961      김익진       1651  8ccdafa7-8b43-581e-9fff-d5c55316f7ff
#
#                                    ws_uuid  repeated_testtaker_lee  \
# 7892  26044751-d6bd-534a-ae6b-965fc8389ed4                   False
# 7893  5af472e3-2855-5288-851d-1b8698aae187                   False
# 8238  c0b57392-53c2-54a4-b0e4-e58e0f5e9e14                    True
# 8239  4bd1bb73-339b-58bb-921a-ae2e33f6bfb4                    True
# 8322  cea144cd-a435-5bdd-a69c-7f7cc1a37de7                    True
# 8323  4e6fe550-8d80-5c69-89a4-5071bf539533                    True
# 9960  a29d8bb7-b3e1-5a90-b9db-29c779ae4513                    True
# 9961  4f879759-7396-5b4f-8d6c-2a7c57ba1754                    True
#
#       repeated_testtaker_ws
# 7892                   True
# 7893                   True
# 8238                   True
# 8239                   True
# 8322                   True
# 8323                   True
# 9960                   True
# 9961                   True

# %%
master = master.drop([8237, 8240, 8321, 8324, 9959, 9962])

# %%
len(master), len(master['lee_uuid'].unique()), len(master['ws_uuid'].unique())
# Out:
# (13202, 13201, 13195)

# %%
# master.head().T

# %%
merge1 = master.copy()

# %% [markdown]
# ## `merge2` - Merge Similar Korean Names

# %% [markdown]
# Next, do a manual merge of the ones that were not merged
#
# * Find those in data_lee not in master
# * Find those in data_ws not in master
# * See if any in data_ws meets 2/3 criteria for those in data_lee, and if so, add them to master

# %%
master = merge1

# %%
len(master[master.duplicated('lee_uuid')])
# Out:
# 1

# %%
# Unique IDs in data_lee NOT in master
lee_unmerged = data_lee[~data_lee['lee_uuid'].isin(master['lee_uuid'].unique())]

# Unique IDs in data_ws NOT in master
ws_unmerged = data_ws[~data_ws['ws_uuid'].isin(master['ws_uuid'].unique())]

len(lee_unmerged), len(ws_unmerged)
# Out:
# (1950, 1412)

# %%
# Sanity Check
# 1950 + 13202 = 15151 + 1 (repeat)
repeated = len(master[master.duplicated('lee_uuid')])
assert (len(lee_unmerged) + len(master) == len(data_lee) + repeated)

# %%
from difflib import SequenceMatcher

def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %% [markdown]
# These are the Korean names in WS that ALMOST match the names in Lee but are SUPER close but are not the same name. Can manually check the following list to make sure I'm right but most of them look like they're the same person.
#
# If their Chinese names and exam year are the same, but the Korean names are more than 50 percent similar, add to the Master table.

# %%
# Make sure number of times one person retook a test in the same year is the same across both datasets
# for index, row in lee_unmerged.iterrows():
#     exam_year = row['pass_year']
#     chi_name = row['chnname']
#     kor_name = row['korname']
#     repeated = row['repeated_testtaker']
    
#     # only matching Chinese name and exam year
#     ws_person = ws_unmerged[(ws_unmerged['namehj1'] == chi_name) & (ws_unmerged['year'] == exam_year)]
#     if (len(ws_person) > 0):
#         if (repeated != ws_person['repeated_testtaker'][0]):
#             print(kor_name, exam_year, repeated, ws_person['repeated_testtaker'][0])

# %%
df_similar_kor_name_lee = pd.DataFrame([])
df_similar_kor_name_ws = pd.DataFrame([])

# Iterate through each person in lee_unmerged
# Find that person in ws_person based on Chinese name and exam year
# Determine if if the person has similar Korean names, they are one person
# Look at the repeated_testtaker. If same numbers, fine
# If different numbers, take the larger of the values
# I guess for now, add repeat
for index, row in lee_unmerged.iterrows():
    exam_year = row['pass_year']
    chi_name = row['chnname']
    kor_name = row['korname']
    repeated = row['repeated_testtaker_lee']
    
    # only matching Chinese name and exam year
    ws_person = ws_unmerged[(ws_unmerged['namehj1'] == chi_name) & (ws_unmerged['year'] == exam_year)]
    for person_index in range(len(ws_person)):
#         print(ws_person["namehg1"].iloc[person_index])
        if (similar(ws_person["namehg1"].iloc[person_index].replace('구', '귀'), kor_name) > 0.5):
            print(kor_name, ws_person["namehg1"].iloc[person_index], similar(ws_person["namehg1"].iloc[person_index], kor_name), ws_person["ws_uuid"].iloc[person_index])
            row_copy = row.copy()
            row_copy['other_kor_name_in_WS_version'] = ws_person["namehg1"].iloc[person_index]
            row_copy['other_kor_name_in_WS_version_uuid'] = ws_person["ws_uuid"].iloc[person_index]
            df_similar_kor_name_lee = df_similar_kor_name_lee.append(row_copy)    
            df_similar_kor_name_ws = df_similar_kor_name_ws.append(ws_person)
# Out:
# 민재문 민ެ문 0.6666666666666666 ccbafb31-0648-5e8b-9930-3ac6eef5d57c
# 윤기번 윤기반 0.6666666666666666 e0736d9f-2e42-5d27-9a7f-d2fb716bfe78
# 정석부 정석빙 0.6666666666666666 78bf3f0e-4efc-5f66-8ae4-5d57d1346cc7

# %%
(len(df_similar_kor_name_lee),len(df_similar_kor_name_ws))
# Out:
# (3, 3)

# %%
assert(len(df_similar_kor_name_lee) == len(df_similar_kor_name_ws))

# %%
# MERGING only on Chinese name and year
master2 = pd.merge(df_similar_kor_name_lee, df_similar_kor_name_ws, indicator=True, how='inner', left_on=['chnname','pass_year'], right_on = ['namehj1','year'])

# Drop duplicate Korean name, Chinese name, and exam year, then rename those columns to be clearer
master2 = master2.drop(columns=['namehg1', 'namehj1', 'year'])
master2 = master2.rename(columns={'korname':'kor_name', 'chnname':'chi_name'})

len(master2), len(master2['lee_uuid'].unique()), len(master2['ws_uuid'].unique())
# Out:
# (3, 3, 3)

# %%
# Merge these with master
frames = [master, master2]
master = pd.concat(frames, sort=False)

merge2 = master.copy()

# %%
len(master[~master['other_kor_name_in_WS_version'].isnull()])
# Out:
# 3

# %%
# Update these values
lee_unmerged = data_lee[~data_lee['lee_uuid'].isin(master['lee_uuid'].unique())]
ws_unmerged = data_ws[~data_ws['ws_uuid'].isin(master['ws_uuid'].unique())]
len(ws_unmerged),len(lee_unmerged)
# Out:
# (1409, 1947)

# %%
# We still have 1409 in data_ws that cannot be matched with data_lee
len(data_ws[~data_ws['ws_uuid'].isin(master['ws_uuid'].unique())])
# Out:
# 1409

# %% [markdown]
# ## `merge3` - Merge Similar Chinese Names

# %% [markdown]
# These are the CHINESE names in WS that ALMOST match the names in Lee but are SUPER close but are not the same name. Can manually check the following list to make sure I'm right but most of them look like they're the same person
#
# <b>Extra thing to check</b>: If the WS name is shorter than ("contains") Lee name, then we can merge them because the names may just be truncated in the Lee version

# %%
master = merge2

# %%
df_similar_chi_name_lee = pd.DataFrame([])
df_similar_chi_name_ws = pd.DataFrame([])

# %%
# Make sure number of times one person retook a test in the same year is the same across both datasets
# Same as above but for Chinese names
# for index, row in lee_unmerged.iterrows():
#     exam_year = row['pass_year']
#     chi_name = row['chnname']
#     kor_name = row['korname']
#     repeated = row['repeated_testtaker_lee']
    
#     # only matching Chinese name and exam year
#     ws_person = ws_unmerged[(ws_unmerged['namehg1'] == kor_name) & (ws_unmerged['year'] == exam_year)]
#     if (len(ws_person) > 0):
#         if (repeated != ws_person['repeated_testtaker_ws'][0]):
#             print(kor_name, chi_name, exam_year, repeated, ws_person['repeated_testtaker_ws'][0])

# %%
# ws_unmerged[(ws_unmerged['year'] == 1612)][["namehj1", "namehg1", "year"]].sort_values(['namehg1'])

# %%
# TODO what to do if there are more than one people with similar names?

df_similar_chi_name_lee = pd.DataFrame([])
df_similar_chi_name_ws = pd.DataFrame([])

for index, row in lee_unmerged.iterrows():
    exam_year = row['pass_year']
    chi_name = row['chnname']
    kor_name = row['korname']
    
    # only matching Chinese name and exam year
    ws_person = ws_unmerged[(ws_unmerged['namehg1'] == kor_name) & (ws_unmerged['year'] == exam_year)]
    
    for person_index in range(len(ws_person)):
        if (similar(ws_person["namehj1"].iloc[person_index], chi_name) > 0.5):
#             if (re.search(re.escape(ws_person["namehj1"][person_index]), chi_name)):
            print(chi_name, ws_person["namehj1"].iloc[person_index], similar(ws_person["namehj1"].iloc[person_index], chi_name), ws_person['namehg1'].iloc[person_index])
            row_copy = row.copy()
            row_copy['other_chi_name_in_WS_version'] = ws_person.iloc[person_index]["namehj1"]
            row_copy['other_chi_name_in_WS_version_uuid'] = ws_person.iloc[person_index]["ws_uuid"]

            df_similar_chi_name_lee = df_similar_chi_name_lee.append(row_copy)
            df_similar_chi_name_ws = df_similar_chi_name_ws.append(ws_person.iloc[person_index])
# Out:
# 李廷熽 李廷 0.8 이정소
# 鄭墀 鄭 0.6666666666666666 정지
# 李章垕 李章 0.8 이장후
# 許禝 許 0.6666666666666666 허직
# 金伈 金 0.6666666666666666 김심
# 朴頎 朴 0.6666666666666666 박기
# 田馪 田 0.6666666666666666 전빈
# 李敉 李 0.6666666666666666 이미
# 朴耋 朴 0.6666666666666666 박질
# 林薈 林 0.6666666666666666 임회
# 金鑌 金 0.6666666666666666 김빈
# 崔瀹之 崔之 0.8 최약지
# 金貔 金 0.6666666666666666 김비
# 金鏗 金 0.6666666666666666 김갱
# 朴叙 朴 0.6666666666666666 박서
# 李士侗 李士 0.8 이사동
# 金㽔 金 0.6666666666666666 김유
# 趙忭 趙 0.6666666666666666 조변
# 裵爚 裵 0.6666666666666666 배약
# 姜仡 姜 0.6666666666666666 강흘
# 金膩 金 0.6666666666666666 김이
# 洪叙疇 洪疇 0.8 홍서주
# 金時霔 金時 0.8 김시주
# 金煒 金 0.6666666666666666 김위
# 孔頎 孔 0.6666666666666666 공기
# 曺好智 曹好智 0.6666666666666666 조호지
# 金軺 金 0.6666666666666666 김초
# 呂箎 呂 0.6666666666666666 여호
# 崔涐 崔 0.6666666666666666 최아
# 孫叙倫 孫倫 0.8 손서윤
# 張鄰臣 張隣臣 0.6666666666666666 장인신
# 金晉錫 金晋錫 0.6666666666666666 김진석
# 崔湑 崔 0.6666666666666666 최서
# 金鏗壽 金壽 0.8 김갱수
# 黃㻶 黃 0.6666666666666666 황필
# 李世蓁 李世 0.8 이세진
# 朴元秢 朴元 0.8 박원영
# 金瑊 金 0.6666666666666666 김감
# 金鏐 金 0.6666666666666666 김유
# 許穧 許 0.6666666666666666 허제
# 南趎 南 0.6666666666666666 남주
# 姜㶏 姜 0.6666666666666666 강은
# 姜胤權 姜允權 0.6666666666666666 강윤권
# 梁訒 梁 0.6666666666666666 양인
# 李訔 李 0.6666666666666666 이은
# 林薈 林 0.6666666666666666 임회
# 金世趎 金世 0.8 김세주
# 秦嶷 秦 0.6666666666666666 진의
# 沈鍧 沈 0.6666666666666666 심굉
# 張彦鄰 張彦隣 0.6666666666666666 장언인
# 權旰 權 0.6666666666666666 권간
# 蘇徯 蘇 0.6666666666666666 소혜
# 裵應褧 裵應 0.8 배응경
# 金柅 金 0.6666666666666666 김이
# 許澄 許 0.6666666666666666 허징
# 康偁 康 0.6666666666666666 강칭
# 朴明榑 朴明 0.8 박명부
# 李璈 李 0.6666666666666666 이오
# 趙郈 趙 0.6666666666666666 조후
# 金寭 金 0.6666666666666666 김혜
# 金簋 金 0.6666666666666666 김궤
# 韓昫 韓 0.6666666666666666 한구
# 田煒 田 0.6666666666666666 전위
# 崔沺 崔 0.6666666666666666 최전
# 鄭沺 鄭 0.6666666666666666 정전
# 李尙馪 李尙 0.8 이상빈
# 李尙馦 李尙 0.8 이상혐
# 徐挺肰 徐挺 0.8 서정연
# 金嶭 金 0.6666666666666666 김알
# 金鍌 金 0.6666666666666666 김선
# 朴思諴 朴思 0.8 박사함
# 韓𧩦 韓 0.6666666666666666 한극
# 宋墁 宋 0.6666666666666666 송만
# 李之馧 李之 0.8 이지온
# 田皞民 田民 0.8 전호민
# 權熀 權 0.6666666666666666 권엽
# 元簋 元 0.6666666666666666 원궤
# 張汝衎 張汝 0.8 장여간
# 朴亨遘 朴亨 0.8 박형구
# 朴瑍 朴 0.6666666666666666 박환
# 曺烶 曺 0.6666666666666666 조정
# 李英馧 李英 0.8 이영온
# 河晉善 河晋善 0.6666666666666666 하진선
# 郭岌 郭 0.6666666666666666 곽급
# 李瑴 李 0.6666666666666666 이곡
# 李時橝 李時 0.8 이시담
# 金𥖝 金 0.6666666666666666 김염
# 李英馦 李英 0.8 이영혐
# 李馣 李 0.6666666666666666 이암
# 李㝡 李 0.6666666666666666 이최
# 李榏 李 0.6666666666666666 이익
# 禹鐤 禹 0.6666666666666666 우정
# 尹樀 尹 0.6666666666666666 윤적
# 金坽 金 0.6666666666666666 김영
# 崔鍌 崔 0.6666666666666666 최선
# 黃壽嶷 黃壽 0.8 황수의
# 韓在垕 韓在 0.8 한재후
# 朱椗 朱 0.6666666666666666 주정
# 金垕 金 0.6666666666666666 김후
# 羅晩榮 羅萬榮 0.6666666666666666 나만영
# 金南賮 金南 0.8 김남신
# 崔垕 崔 0.6666666666666666 최후
# 尹榏 尹 0.6666666666666666 윤익
# 方濈 方 0.6666666666666666 방즙
# 李垕 李 0.6666666666666666 이후
# 洪楀 洪 0.6666666666666666 홍우
# 金晉來 金晋來 0.6666666666666666 김진내
# 余垕 余 0.6666666666666666 여후
# 崔仁垕 崔仁 0.8 최인후
# 黃啓垕 黃啓 0.8 황계후
# 李時栽 李時裁 0.6666666666666666 이시재
# 申湚 申 0.6666666666666666 신인
# 李囿春 李春 0.8 이유춘
# 南溟翮 南溟 0.8 남명핵
# 金聖鎔 金成鎔 0.6666666666666666 김성용
# 金益忱 金益 0.8 김익침
# 鄭震垕 鄭震 0.8 정진후
# 韓始𥙿 韓始裕 0.6666666666666666 한시유
# 金夢垕 金夢 0.8 김몽후
# 金始鑌 金始 0.8 김시빈
# 裵慶垕 裵慶 0.8 배경후
# 金聖垕 金聖 0.8 김성후
# 柳綋 柳 0.6666666666666666 유굉
# 許鐔 許 0.6666666666666666 허심
# 洪㬙 洪 0.6666666666666666 홍위
# 金㙔 金 0.6666666666666666 김위
# 裵晉明 裵晋明 0.6666666666666666 배진명
# 金垕重 金重 0.8 김후중
# 崔龍賢 崔龍 0.8 최용현
# 金琂 金 0.6666666666666666 김언
# 鄭錫垕 鄭錫 0.8 정석후
# 成彦檝 成彦 0.8 성언즙
# 崔德垕 崔德 0.8 최덕후
# 金埅 金 0.6666666666666666 김방
# 李景垕 李景 0.8 이경후
# 李泰馧 李泰 0.8 이태온
# 朴賢輔 朴輔 0.8 박현보
# 李重晉 李重晋 0.6666666666666666 이중진
# 鄭彙晉 鄭彙晋 0.6666666666666666 정휘진
# 金煃 金 0.6666666666666666 김규
# 呂弘㦿 呂弘 0.8 여홍호
# 崔憼 崔 0.6666666666666666 최경
# 鄭琂章 鄭章 0.8 정언장
# 金益垕 金益后 0.6666666666666666 김익후
# 崔夢嵒 崔夢 0.8 최몽암
# 房喆謩 房喆 0.8 방철모
# 成穎 成 0.6666666666666666 성영
# 吳彦洉 吳彦 0.8 오언후
# 李昌爕 李昌燮 0.6666666666666666 이창섭
# 李穦 李 0.6666666666666666 이빈
# 李贇 李 0.6666666666666666 이빈
# 許洉 許 0.6666666666666666 허후
# 黃檏 黃 0.6666666666666666 황박
# 權正忱 權正 0.8 권정침
# 柳楦 柳 0.6666666666666666 유훤
# 金叙九 金九 0.8 김서구
# 申熤 申 0.6666666666666666 신익
# 朱萬离 朱萬 0.8 주만이
# 金寅爕 金寅燮 0.6666666666666666 김인섭
# 金鑧 金 0.6666666666666666 김관
# 許鍒 許 0.6666666666666666 허유
# 鄭珒 鄭 0.6666666666666666 정진
# 尹昌㷜 尹昌 0.8 윤창혁
# 呂弘榦 呂弘 0.8 여홍간
# 李庸逌 李庸 0.8 이용유
# 趙彦㷜 趙彦 0.8 조언혁
# 李敬𥙿 李敬裕 0.6666666666666666 이경유
# 權𢜬 權 0.6666666666666666 권탁
# 金𤩶 金 0.6666666666666666 김업
# 洪箕叙 洪箕 0.8 홍기서
# 姜栳 姜 0.6666666666666666 강노
# 李爗 李 0.6666666666666666 이엽
# 金㙆 金 0.6666666666666666 김굉
# 柳光澺 柳光 0.8 유광억
# 柳櫰 柳 0.6666666666666666 유회
# 趙夢鶠 趙夢 0.8 조몽언
# 金禧爕 金禧燮 0.6666666666666666 김희섭
# 金膺著 金應著 0.6666666666666666 김응저
# 姜德 姜德恒 0.8 강덕항
# 劉師玶 劉師 0.8 유사평
# 姜世楑 姜世 0.8 강세규
# 鄭馦 鄭 0.6666666666666666 정혐
# 盧鎛 盧 0.6666666666666666 노박
# 宋㯙 宋 0.6666666666666666 송철
# 任㸁 任 0.6666666666666666 임한
# 方昜 方 0.6666666666666666 방양
# 李晢 李 0.6666666666666666 이절
# 李㬖 李 0.6666666666666666 이계
# 金履垕 金履 0.8 김이후
# 宋磾 宋 0.6666666666666666 송제
# 安祫 安 0.6666666666666666 안협
# 朴師晉 朴師晋 0.6666666666666666 박사진
# 具晉行 具晋行 0.6666666666666666 구진행
# 金夢柅 金夢 0.8 김몽이
# 崔鴻晉 崔鴻晋 0.6666666666666666 최홍진
# 沈能栻 沈能 0.8 심능식
# 權拚 權 0.6666666666666666 권변
# 趙𣚅 趙 0.6666666666666666 조덕
# 尹稹 尹 0.6666666666666666 윤진
# 林臯鶴 林皐鶴 0.6666666666666666 임고학
# 李頤熙 李熙 0.8 이이희
# 許兟 許 0.6666666666666666 허신
# 李菡甲 李甲 0.8 이함갑
# 金得种 金得 0.8 김득충
# 卓瑊 卓 0.6666666666666666 탁감
# 洪𧛈煥 洪煥 0.8 홍윤환
# 李義𡨽 李義 0.8 이의성
# 李鋗 李 0.6666666666666666 이현
# 崔晉慶 崔晋慶 0.6666666666666666 최진경
# 趙嶷 趙 0.6666666666666666 조의
# 金榶 金 0.6666666666666666 김당
# 姜𣜦 姜 0.6666666666666666 강도
# 鄭顯𤩶 鄭顯 0.8 정현업
# 梁日煒 梁日 0.8 양일위
# 朴在皞 朴在 0.8 박재호
# 金熙逌 金熙 0.8 김희유
# 朴偀 朴 0.6666666666666666 박영
# 鄭𥙿榮 鄭裕榮 0.6666666666666666 정유영
# 李義晉 李義晋 0.6666666666666666 이의진
# 李晉燁 李晋燁 0.6666666666666666 이진엽
# 李晉祥 李晋祥 0.6666666666666666 이진상
# 鄭𣲚 鄭 0.6666666666666666 정인
# 金羲𥙿 金羲裕 0.6666666666666666 김희유
# 黃燝 黃 0.6666666666666666 황경
# 李晉錫 李晋錫 0.6666666666666666 이진석
# 文東瑝 文東 0.8 문동황
# 姜晢一 姜一 0.8 강절일
# 金棱 金 0.6666666666666666 김능
# 朴文𨥺 朴文 0.8 박문홍
# 韓鼎謩 韓鼎 0.8 한정모
# 鮮于澲 鮮于 0.8 선우업
# 李庭垕 李庭 0.8 이정후
# 金宗瑍 金宗 0.8 김종환
# 權鍾䘵 權鍾 0.8 권종녹
# 尹秉鏇 尹秉 0.8 윤병선
# 姜𨪌 姜 0.6666666666666666 강기
# 金載瓛 金載 0.8 김재환
# 申濬皞 申濬 0.8 신준호
# 柳龍䥁 柳龍 0.8 유용함
# 李𤧣 李 0.6666666666666666 이건
# 金晉浩 金晋浩 0.6666666666666666 김진호
# 洪永𧙓 洪永 0.8 홍영조
# 晉命復 晋命復 0.6666666666666666 진명복
# 閔載晉 閔載晋 0.6666666666666666 민재진
# 愼㘽佑 愼佑 0.8 신재우
# 崔相綰 崔相 0.8 최상관
# 金曍英 金英 0.8 김호영
# 金㽥 金 0.6666666666666666 김유
# 兪朢源 兪源 0.8 유망원
# 尹𤨆 尹 0.6666666666666666 윤황
# 鮮于𨯶 鮮于 0.8 선우헌
# 卞鋈 卞 0.6666666666666666 변옥
# 趙鑅 趙 0.6666666666666666 조횡
# 李在祏 李在 0.8 이재석
# 李㝡榮 李榮 0.8 이최영
# 朴宗玕 朴宗 0.8 박종간
# 尹皞燮 尹燮 0.8 윤호섭
# 張錫𥙿 張錫裕 0.6666666666666666 장석유
# 盧𤍤 盧 0.6666666666666666 노장
# 黃岦 黃 0.6666666666666666 황입
# 金達㻐 金達 0.8 김달준
# 李鏡昈 李鏡 0.8 이경호
# 姜忱 姜 0.6666666666666666 강침
# 姜籕 姜 0.6666666666666666 강추
# 許栻 許 0.6666666666666666 허식
# 金淨 金 0.6666666666666666 김정
# 金碾 金 0.6666666666666666 김연
# 李𡹘 李 0.6666666666666666 이계
# 李皞 李 0.6666666666666666 이호
# 田闟 田 0.6666666666666666 전흡
# 鄭賙 鄭 0.6666666666666666 정주
# 金沱 金 0.6666666666666666 김타
# 金九冏 金九 0.8 김구경
# 李煒 李 0.6666666666666666 이위
# 李樛 李 0.6666666666666666 이규
# 李鏵 李 0.6666666666666666 이화
# 李鉐 李 0.6666666666666666 이석
# 李基𧙓 李基 0.8 이기조
# 李穟 李 0.6666666666666666 이수
# 李烓 李 0.6666666666666666 이계
# 申垕 申 0.6666666666666666 신후
# 金楺 金 0.6666666666666666 김유
# 鄭楺 鄭 0.6666666666666666 정유
# 朴衎 朴 0.6666666666666666 박간
# 許鍒 許 0.6666666666666666 허유
# 權偀 權 0.6666666666666666 권영
# 朴筳 朴 0.6666666666666666 박정
# 申槩 申 0.6666666666666666 신개
# 趙叙 趙 0.6666666666666666 조서
# 柳顗 柳 0.6666666666666666 유의
# 柳益之 柳翼之 0.6666666666666666 유익지
# 梁思逖 梁思 0.8 양사적
# 宋寘 宋 0.6666666666666666 송치
# 偰循 循 0.6666666666666666 설순
# 金赭 金 0.6666666666666666 김자
# 金自貽 金自怡 0.6666666666666666 김자이
# 權偲 權 0.6666666666666666 권시
# 朴崷 朴 0.6666666666666666 박추
# 金子鏗 金子 0.8 김자갱
# 權踶 權 0.6666666666666666 권제
# 鄭苯 鄭 0.6666666666666666 정분
# 安修己 安脩己 0.6666666666666666 안수기
# 成壽嶙 成壽 0.8 성수인
# 閔孝懽 閔孝 0.8 민효환
# 趙珸 趙 0.6666666666666666 조오
# 柳宗叙 柳宗 0.8 유종서
# 裵杠 裵 0.6666666666666666 배강
# 許詡 許 0.6666666666666666 허후
# 申蕡 申 0.6666666666666666 신분
# 李季畹 李季 0.8 이계원
# 鄭枻 鄭 0.6666666666666666 정설
# 朴趂 朴 0.6666666666666666 박진
# 柳𥊀 柳 0.6666666666666666 유삼
# 趙季砰 趙季 0.8 조계팽
# 金潧 金 0.6666666666666666 김증
# 李諴長 李長 0.8 이함장
# 朴思斕 朴思 0.8 박사난
# 柳轂 柳 0.6666666666666666 유곡
# 李皎然 李皎 0.8 이교연
# 南輊 南 0.6666666666666666 남지
# 安迢 安 0.6666666666666666 안초
# 許慥 許 0.6666666666666666 허조
# 河漴 河 0.6666666666666666 하충
# 趙璠 趙 0.6666666666666666 조번
# 柳輊 柳 0.6666666666666666 유지
# 丘致岡 丘致崗 0.6666666666666666 구치강
# 李堣 李 0.6666666666666666 이우
# 李垤 李 0.6666666666666666 이질
# 尹慜 尹 0.6666666666666666 윤민
# 崔埥 崔 0.6666666666666666 최정
# 金晐 金 0.6666666666666666 김해
# 南䄎 南 0.6666666666666666 남기
# 曺克治 曹克治 0.6666666666666666 조극치
# 柳睠 柳 0.6666666666666666 유권
# 李繼貞 李繼禎 0.6666666666666666 이계정
# 鄭忻 鄭 0.6666666666666666 정흔
# 許譔 許 0.6666666666666666 허선
# 尹㬦 尹 0.6666666666666666 윤확
# 李墀 李 0.6666666666666666 이지
# 曺兗河 曺河 0.8 조연하
# 金耋 金 0.6666666666666666 김질
# 金嶟 金 0.6666666666666666 김준
# 成俶 成 0.6666666666666666 성숙
# 鄭佸 鄭 0.6666666666666666 정괄
# 權挒 權 0.6666666666666666 권열
# 辛仲琚 辛仲 0.8 신중거
# 崔漢候 崔漢侯 0.6666666666666666 최한후
# 權侹 權 0.6666666666666666 권정
# 許葟 許 0.6666666666666666 허황
# 趙鑌 趙 0.6666666666666666 조빈
# 金克忸 金克 0.8 김극유
# 鄭晣 鄭 0.6666666666666666 정절
# 李垾 李 0.6666666666666666 이한
# 安晉生 安晋生 0.6666666666666666 안진생
# 金訢 金 0.6666666666666666 김흔
# 奇襸 奇 0.6666666666666666 기찬
# 辛季琚 辛季 0.8 신계거
# 李坫 李 0.6666666666666666 이점
# 姜景叙 姜景 0.8 강경서
# 宋軼 宋 0.6666666666666666 송일
# 金硉 金 0.6666666666666666 김율
# 李諿 李 0.6666666666666666 이집
# 朴訒 朴 0.6666666666666666 박인
# 李琚 李 0.6666666666666666 이거
# 李浤 李 0.6666666666666666 이굉
# 權璸 權 0.6666666666666666 권빈
# 金崶 金 0.6666666666666666 김봉
# 奇褚 奇 0.6666666666666666 기저
# 閔頤 閔 0.6666666666666666 민이
# 金磶 金 0.6666666666666666 김석
# 李瑺 李 0.6666666666666666 이상
# 李黿 李 0.6666666666666666 이원
# 李㙉 李 0.6666666666666666 이전
# 姜諿 姜 0.6666666666666666 강집
# 姜澂 姜 0.6666666666666666 강징
# 安覯 安 0.6666666666666666 안구
# 金璫 金 0.6666666666666666 김당
# 金熠 金 0.6666666666666666 김습
# 李云秠 李云 0.8 이운비
# 閔㥳 閔 0.6666666666666666 민원
# 李堣 李 0.6666666666666666 이우
# 金克愊 金克 0.8 김극핍
# 李頫 李 0.6666666666666666 이부
# 權橃 權 0.6666666666666666 권벌
# 李蘋 李 0.6666666666666666 이빈
# 李膂 李 0.6666666666666666 이여
# 金磧 金 0.6666666666666666 김적
# 許硡 許 0.6666666666666666 허굉
# 申鏛 申 0.6666666666666666 신상
# 宋澂 宋 0.6666666666666666 송징
# 金璠 金 0.6666666666666666 김번
# 李迨 李 0.6666666666666666 이태
# 李胖 李 0.6666666666666666 이반
# 黃𣉮 黃 0.6666666666666666 황진
# 李之蕡 李之 0.8 이지분
# 金埏 金 0.6666666666666666 김연
# 金顒 金 0.6666666666666666 김옹
# 李構 李 0.6666666666666666 이구
# 林畡 林 0.6666666666666666 임해
# 金彦琚 金彦 0.8 김언거
# 許礦 許 0.6666666666666666 허광
# 趙邦楨 趙邦禎 0.6666666666666666 조방정
# 李畬 李 0.6666666666666666 이여
# 朴從鱗 朴從麟 0.6666666666666666 박종인
# 羅士愃 羅士 0.8 나사선
# 鄭鍠 鄭 0.6666666666666666 정굉
# 鄭荃 鄭 0.6666666666666666 정전
# 禹鏛 禹 0.6666666666666666 우상
# 柳仲郢 柳仲 0.8 유중영
# 申承澡 申承 0.8 신승조
# 安舳 安 0.6666666666666666 안축
# 申抃 申 0.6666666666666666 신변
# 權輗 權 0.6666666666666666 권예
# 權㻩 權 0.6666666666666666 권겸
# 盧禛 盧 0.6666666666666666 노진
# 安嶒 安 0.6666666666666666 안증
# 洪叙疇 洪疇 0.8 홍서주
# 金漹 金 0.6666666666666666 김언
# 趙希嘏 趙希 0.8 조희하
# 韓㞳 韓 0.6666666666666666 한두
# 李菑 李 0.6666666666666666 이치
# 丁熿 丁 0.6666666666666666 정황
# 李彦忱 李彦 0.8 이언침
# 任鼐臣 任臣 0.8 임내신
# 崔巏 崔 0.6666666666666666 최권
# 金䃴 金 0.6666666666666666 김저
# 南宮忱 南宮 0.8 남궁침
# 梁應鮐 梁應 0.8 양응태
# 金宇顒 金宇 0.8 김우옹
# 李諴 李 0.6666666666666666 이함
# 曹景中 曺景中 0.6666666666666666 조경중
# 郭趕 郭 0.6666666666666666 곽간
# 李䤴 李 0.6666666666666666 이함
# 金玏 金 0.6666666666666666 김늑
# 李墍 李 0.6666666666666666 이기
# 柳溵 柳 0.6666666666666666 유은
# 金誋 金 0.6666666666666666 김기
# 金軔 金 0.6666666666666666 김인
# 李訒 李 0.6666666666666666 이인
# 郭𧾰 郭 0.6666666666666666 곽익
# 南世瑍 南世 0.8 남세환
# 金德鵾 金德 0.8 김덕곤
# 秦溟鴻 秦冥鴻 0.6666666666666666 진명홍
# 河晉寶 河晋寶 0.6666666666666666 하진보
# 尹趌 尹 0.6666666666666666 윤길
# 金德諴 金德 0.8 김덕함
# 郭趪 郭 0.6666666666666666 곽황
# 林頲 林 0.6666666666666666 임정
# 李頤慶 李慶 0.8 이이경
# 崔頲 崔 0.6666666666666666 최정
# 朴顒 朴 0.6666666666666666 박옹
# 羅紉 羅 0.6666666666666666 나인
# 孫遴 孫 0.6666666666666666 손인
# 朴箎 朴 0.6666666666666666 박호
# 崔葕 崔 0.6666666666666666 최연
# 權悏 權 0.6666666666666666 권협
# 李汝馪 李汝 0.8 이여빈
# 尹顗 尹 0.6666666666666666 윤의
# 李𣙇 李 0.6666666666666666 이집
# 徐渻 徐 0.6666666666666666 서성
# 朴文叙 朴文 0.8 박문서
# 朴澡 朴 0.6666666666666666 박조
# 姜綖 姜 0.6666666666666666 강연
# 李讜 李 0.6666666666666666 이당
# 李𡼖 李 0.6666666666666666 이돈
# 姜愐 姜 0.6666666666666666 강면
# 權噵 權 0.6666666666666666 권도
# 吳汝檼 吳汝 0.8 오여은
# 吳晪 吳 0.6666666666666666 오전
# 金坽 金 0.6666666666666666 김영
# 鄭雴 鄭 0.6666666666666666 정입
# 尹昫 尹 0.6666666666666666 윤구
# 金瑬 金 0.6666666666666666 김유
# 李蒧 李 0.6666666666666666 이점
# 沈諿 沈 0.6666666666666666 심집
# 吳汝橃 吳汝 0.8 오여벌
# 李民寏 李民 0.8 이민환
# 鄭岦 鄭 0.6666666666666666 정입
# 李惕 李 0.6666666666666666 이척
# 李惟諴 李惟 0.8 이유함
# 徐忭 徐 0.6666666666666666 서변
# 李時馣 李時 0.8 이시암
# 李艪 李 0.6666666666666666 이노
# 呂焯 呂 0.6666666666666666 여작
# 鄭杺 鄭 0.6666666666666666 정심
# 洪霶 洪 0.6666666666666666 홍방
# 兪晉曾 兪晋曾 0.6666666666666666 유진증
# 金灦 金 0.6666666666666666 김현
# 金𩑃 金 0.6666666666666666 김업
# 李起浡 李起 0.8 이기발
# 李生浡 李生 0.8 이생발
# 李興浡 李興 0.8 이흥발
# 許嵱 許 0.6666666666666666 허용
# 楊時晉 楊時晋 0.6666666666666666 양시진
# 李埁 李 0.6666666666666666 이잠
# 河溍 河 0.6666666666666666 하진
# 李錫晉 李錫晋 0.6666666666666666 이석진
# 金鋿 金 0.6666666666666666 김상
# 林墰 林 0.6666666666666666 임담
# 崔基銆 崔基 0.8 최기백
# 權諿 權 0.6666666666666666 권집
# 吳熽 吳 0.6666666666666666 오소
# 鄭慥 鄭 0.6666666666666666 정조
# 朴𥶇 朴 0.6666666666666666 박노
# 柳椐 柳 0.6666666666666666 유거
# 權寏 權 0.6666666666666666 권환
# 金迬 金 0.6666666666666666 김왕
# 呂𤀂 呂 0.6666666666666666 여경
# 趙釴 趙 0.6666666666666666 조익
# 睦叙欽 睦欽 0.8 목서흠
# 金昈 金 0.6666666666666666 김호
# 權晵 權 0.6666666666666666 권계
# 柳霂 柳 0.6666666666666666 유목
# 金錕 金 0.6666666666666666 김곤
# 韓暿 韓 0.6666666666666666 한희
# 鄭庥 鄭 0.6666666666666666 정휴
# 柳榰 柳 0.6666666666666666 유지
# 李彙晉 李彙晋 0.6666666666666666 이휘진
# 尹棐殷 尹殷 0.8 윤비은
# 朴繘 朴 0.6666666666666666 박율
# 朴𥳍 朴 0.6666666666666666 박심
# 李孝諴 李孝 0.8 이효함
# 金璁 金 0.6666666666666666 김총
# 權垕 權 0.6666666666666666 권후
# 郭崦 郭 0.6666666666666666 곽엄
# 韓琂 韓 0.6666666666666666 한언
# 南碝 南 0.6666666666666666 남연
# 柳俰 柳 0.6666666666666666 유화
# 趙始久 趙時久 0.6666666666666666 조시구
# 李嵂 李 0.6666666666666666 이율
# 南垕 南 0.6666666666666666 남후
# 朴澂 朴 0.6666666666666666 박징
# 申㶅 申 0.6666666666666666 신학
# 權霔 權 0.6666666666666666 권주
# 朴漪 朴 0.6666666666666666 박의
# 權坽 權 0.6666666666666666 권영
# 李時楳 李時 0.8 이시매
# 沈枅 沈 0.6666666666666666 심계
# 許墀 許 0.6666666666666666 허지
# 申湙 申 0.6666666666666666 신역
# 吳䎙 吳 0.6666666666666666 오빈
# 鄭䎖 鄭 0.6666666666666666 정증
# 柳頲 柳 0.6666666666666666 유정
# 李袗 李 0.6666666666666666 이진
# 權𢜫 權 0.6666666666666666 권성
# 權忭 權 0.6666666666666666 권변
# 金鍰 金 0.6666666666666666 김환
# 權𢢝 權 0.6666666666666666 권수
# 沈譔 沈 0.6666666666666666 심선
# 呂㴰 呂 0.6666666666666666 여능
# 鄭錀 鄭 0.6666666666666666 정윤
# 元檝 元 0.6666666666666666 원즙
# 朱楘 朱 0.6666666666666666 주목
# 姜𥙿後 姜裕後 0.6666666666666666 강유후
# 鄭勔 鄭 0.6666666666666666 정면
# 金晉重 金晋重 0.6666666666666666 김진중
# 趙䃏 趙 0.6666666666666666 조성
# 李坽 李 0.6666666666666666 이영
# 姜汝㦿 姜汝 0.8 강여호
# 元樀 元 0.6666666666666666 원적
# 權諔 權 0.6666666666666666 권숙
# 李彙晉 李彙晋 0.6666666666666666 이휘진
# 金政 金 0.6666666666666666 김정
# 金㙫 金 0.6666666666666666 김집
# 權𥛚 權 0.6666666666666666 권적
# 權斗綋 權斗 0.8 권두굉
# 李廷熽 李廷 0.8 이정소
# 洪蒑 洪 0.6666666666666666 홍은
# 申𩅿 申 0.6666666666666666 신박
# 朱炯离 朱炯 0.8 주형이
# 元梲 元 0.6666666666666666 원탈
# 朴烶 朴 0.6666666666666666 박정
# 申𣷯 申 0.6666666666666666 신근
# 尹焜 尹 0.6666666666666666 윤혼
# 金厦梴 金厦 0.8 김하천
# 張善澂 張善 0.8 장선징
# 元㯙 元 0.6666666666666666 원철
# 李渻 李 0.6666666666666666 이성
# 李槳 李 0.6666666666666666 이장
# 閔黯 閔 0.6666666666666666 민암
# 李世垕 李世 0.8 이세후
# 李彙晉 李彙晋 0.6666666666666666 이휘진
# 金致垕 金致 0.8 김치후
# 南躔 南 0.6666666666666666 남전
# 崔鎜 崔 0.6666666666666666 최반
# 南宮垕 南宮 0.8 남궁후
# 李溭 李 0.6666666666666666 이직
# 朴世𤎱 朴世 0.8 박세준
# 韓㙉 韓 0.6666666666666666 한전
# 李頤命 李命 0.8 이이명
# 金霔 金 0.6666666666666666 김주
# 柳埅 柳 0.6666666666666666 유방
# 金澋 金 0.6666666666666666 김횡
# 權慜 權 0.6666666666666666 권민
# 李齊嵒 李齊 0.8 이제암
# 權𢢜 權 0.6666666666666666 권업
# 柳頤玄 柳玄 0.8 유이현
# 李㵓 李 0.6666666666666666 이식
# 趙鏛 趙 0.6666666666666666 조상
# 黃㮋 黃 0.6666666666666666 황욱
# 趙世垕 趙世 0.8 조세후
# 權顈 權 0.6666666666666666 권경
# 金始㷜 金始 0.8 김시혁
# 愼爾晉 愼爾晋 0.6666666666666666 신이진
# 姜檏 姜 0.6666666666666666 강박
# 李時馠 李時 0.8 이시함
# 金天叙 金天 0.8 김천서
# 權賅 權 0.6666666666666666 권해
# 韓頤朝 韓朝 0.8 한이조
# 韓顯謩 韓顯 0.8 한현모
# 安栻 安 0.6666666666666666 안식
# 趙侹 趙 0.6666666666666666 조정
# 柳謇 柳 0.6666666666666666 유건
# 李晉吉 李晋吉 0.6666666666666666 이진길
# 崔晑 崔 0.6666666666666666 최향
# 韓翼謩 韓翼 0.8 한익모
# 李光躋 李光 0.8 이광제
# 李光溭 李光 0.8 이광직
# 洪曕 洪 0.6666666666666666 홍염
# 權熻 權 0.6666666666666666 권흡
# 韓栐 韓 0.6666666666666666 한영
# 沈瑴 沈 0.6666666666666666 심곡
# 申𢢝 申 0.6666666666666666 신수
# 李溎 李 0.6666666666666666 이연
# 姜俒 姜 0.6666666666666666 강흔
# 李宜馣 李宜 0.8 이의암
# 柳橚 柳 0.6666666666666666 유숙
# 李廷𤩶 李廷 0.8 이정업
# 黃柙 黃 0.6666666666666666 황합
# 許晊 許 0.6666666666666666 허질
# 金廧 金 0.6666666666666666 김장
# 柳恊基 柳協基 0.6666666666666666 유협기
# 李埦 李 0.6666666666666666 이완
# 許晪 許 0.6666666666666666 허전
# 沈鉍 沈 0.6666666666666666 심필
# 李錫垕 李錫 0.8 이석후
# 金𥙿己 金裕己 0.6666666666666666 김유기
# 許栮 許 0.6666666666666666 허이
# 權烒 權 0.6666666666666666 권식
# 劉㵙 劉 0.6666666666666666 유청
# 權熀 權 0.6666666666666666 권엽
# 許暕 許 0.6666666666666666 허간
# 柳烇 柳 0.6666666666666666 유전
# 金益耟 金益 0.8 김익거
# 金𥙿憲 金裕憲 0.6666666666666666 김유헌
# 權馦 權 0.6666666666666666 권혐
# 鄭鎏 鄭 0.6666666666666666 정유
# 金𨬠 金 0.6666666666666666 김징
# 姜晉奎 姜晋奎 0.6666666666666666 강진규
# 金鉐 金 0.6666666666666666 김석
# 兪晠煥 兪晟煥 0.6666666666666666 유성환
# 柳厚𧙓 柳厚 0.8 유후조
# 鄭在晉 鄭在晋 0.6666666666666666 정재진
# 盧鎭爕 盧鎭燮 0.6666666666666666 노진섭
# 鄭㵙 鄭 0.6666666666666666 정청
# 姜鏋 姜 0.6666666666666666 강만
# 李秉臯 李秉皐 0.6666666666666666 이병고
# 洪晉游 洪晋游 0.6666666666666666 홍진유
# 李範偰 李範 0.8 이범설
# 崔岦 崔 0.6666666666666666 최입
# 卓諴 卓 0.6666666666666666 탁함
# 洪錀 洪 0.6666666666666666 홍윤
# 權侙 權 0.6666666666666666 권칙
# 許垕 許 0.6666666666666666 허후
# 金戩 金 0.6666666666666666 김전
# 李礥 李 0.6666666666666666 이현
# 黃允垕 黃允 0.8 황윤후
# 李挺檏 李挺 0.8 이정박
# 沈埜 沈 0.6666666666666666 심야
# 李羽晉 李羽晋 0.6666666666666666 이우진
# 柳畊 柳 0.6666666666666666 유경
# 鄭運躋 鄭運 0.8 정운제
# 沈鎜 沈 0.6666666666666666 심반
# 李垿 李 0.6666666666666666 이서
# 李基楨 李基正 0.6666666666666666 이기정
# 鄭顯𥙿 鄭顯裕 0.6666666666666666 정현유
# 柳𤥵 柳 0.6666666666666666 유협
# 尹起晉 尹起晋 0.6666666666666666 윤기진
# 李俒 李 0.6666666666666666 이흔
# 李鄗 李 0.6666666666666666 이호
# 李炳鋈 李炳 0.8 이병옥
# 李晉永 李晋永 0.6666666666666666 이진영
# 權坰 權 0.6666666666666666 권경
# 申垕 申 0.6666666666666666 신후
# 李畬 李 0.6666666666666666 이여
# 李㙽 李 0.6666666666666666 이석
# 李墷 李 0.6666666666666666 이화
# 李𨯶永 李永 0.8 이헌영
# 李景稙 李庚稙 0.6666666666666666 이경직
# 金睟 金 0.6666666666666666 김수
# 金濰 金 0.6666666666666666 김유
# 金㻶 金 0.6666666666666666 김필
# 金礩 金 0.6666666666666666 김질
# 朴叔蓁 朴叔 0.8 박숙진
# 鄭忱 鄭 0.6666666666666666 정침
# 金嶙 金 0.6666666666666666 김인
# 金碏 金 0.6666666666666666 김작
# 安瑭 安 0.6666666666666666 안당
# 金巓 金 0.6666666666666666 김전
# 朴承爚 朴承 0.8 박승약
# 金孝侃 金效侃 0.6666666666666666 김효간
# 李芑 李 0.6666666666666666 이기
# 李耔 李 0.6666666666666666 이자
# 金硡 金 0.6666666666666666 김굉
# 金銛 金 0.6666666666666666 김섬
# 慶俶 慶 0.6666666666666666 경숙
# 李𡊉 李 0.6666666666666666 이말
# 李簡 李 0.6666666666666666 이간
# 閔樑 閔 0.6666666666666666 민양
# 蔡忱 蔡 0.6666666666666666 채침
# 朴稑 朴 0.6666666666666666 박육
# 鄭譍 鄭 0.6666666666666666 정응
# 朴稹 朴 0.6666666666666666 박진
# 尹行晉 尹行晋 0.6666666666666666 윤행진
# 權磌 權 0.6666666666666666 권전
# 安處諴 安處 0.8 안처함
# 金釴 金 0.6666666666666666 김익
# 宋㻩 宋 0.6666666666666666 송겸
# 李薿 李 0.6666666666666666 이의
# 金亹 金 0.6666666666666666 김미
# 尹忭 尹 0.6666666666666666 윤변
# 李頤 李 0.6666666666666666 이이
# 朴世蓊 朴世 0.8 박세옹
# 尹世忱 尹世 0.8 윤세침
# 李賢讜 李賢 0.8 이현당
# 李秫 李 0.6666666666666666 이출
# 李無彊 李無疆 0.6666666666666666 이무강
# 閔荃 閔 0.6666666666666666 민전
# 李璖 李 0.6666666666666666 이거
# 尹杲 尹 0.6666666666666666 윤고
# 南虬年 南年 0.8 남규연
# 沈苓 沈 0.6666666666666666 심영
# 閔箎 閔 0.6666666666666666 민호
# 崔堣 崔 0.6666666666666666 최우
# 任珗 任 0.6666666666666666 임선
# 趙𤩶 趙 0.6666666666666666 조업
# 安馠 安 0.6666666666666666 안함
# 金膂 金 0.6666666666666666 김여
# 金虬 金 0.6666666666666666 김규
# 金士銛 金士 0.8 김사섬
# 鄭惕 鄭 0.6666666666666666 정척
# 李遴 李 0.6666666666666666 이인
# 柳㙉 柳 0.6666666666666666 유전
# 鄭䃫 鄭 0.6666666666666666 정담
# 李蘧 李 0.6666666666666666 이거
# 羅恮 羅 0.6666666666666666 나전
# 崔顒 崔 0.6666666666666666 최옹
# 具忭 具 0.6666666666666666 구변
# 崔弘僴 崔弘 0.8 최홍한
# 徐崦 徐 0.6666666666666666 서엄
# 李廷馣 李廷 0.8 이정암
# 李𥙿仁 李裕仁 0.6666666666666666 이유인
# 金澥 金 0.6666666666666666 김해
# 金戣 金 0.6666666666666666 김규
# 權𢢝 權 0.6666666666666666 권수
# 元膂 元 0.6666666666666666 원여
# 李璁 李 0.6666666666666666 이총
# 奇苓 奇 0.6666666666666666 기영
# 盧㙉 盧 0.6666666666666666 노전
# 許篈 許 0.6666666666666666 허봉
# 韓顒 韓 0.6666666666666666 한옹
# 韓戭 韓 0.6666666666666666 한인
# 羅允忱 羅允 0.8 나윤침
# 金僩 金 0.6666666666666666 김한
# 崔錪 崔 0.6666666666666666 최전
# 李景㟳 李景 0.8 이경율
# 洪仁恕 洪仁U 0.6666666666666666 홍인서
# 柳𧩦 柳 0.6666666666666666 유극
# 尹皞 尹 0.6666666666666666 윤호
# 金汝岉 金汝 0.8 김여물
# 李洁 李 0.6666666666666666 이길
# 韓彦忱 韓彦 0.8 한언침
# 李覮 李 0.6666666666666666 이영
# 申磼 申 0.6666666666666666 신잡
# 辛慶晉 辛慶晋 0.6666666666666666 신경진
# 李慶禥 李慶 0.8 이경기
# 金韞 金 0.6666666666666666 김온
# 李睟光 李光 0.8 이수광
# 韓𢧳 韓 0.6666666666666666 한용
# 尹暒 尹 0.6666666666666666 윤청
# 崔韹 崔 0.6666666666666666 최황
# 李鏗 李 0.6666666666666666 이갱
# 李忔 李 0.6666666666666666 이흘
# 李馪 李 0.6666666666666666 이빈
# 沈忻 沈 0.6666666666666666 심흔
# 李蕆 李 0.6666666666666666 이천
# 李𦸂 李 0.6666666666666666 이심
# 鄭泑 鄭 0.6666666666666666 정유
# 趙濈 趙 0.6666666666666666 조즙
# 李愖 李 0.6666666666666666 이심
# 成晉善 成晋善 0.6666666666666666 성진선
# 李廷馦 李廷 0.8 이정혐
# 尹㬚 尹 0.6666666666666666 윤철
# 沈詻 沈 0.6666666666666666 심액
# 柳湙 柳 0.6666666666666666 유역
# 尹訒 尹 0.6666666666666666 윤인
# 林𢢜 林 0.6666666666666666 임업
# 盧遾 盧 0.6666666666666666 노서
# 朴榟 朴 0.6666666666666666 박재
# 權詗 權 0.6666666666666666 권형
# 權盺 權 0.6666666666666666 권흔
# 宋克訒 宋克 0.8 송극인
# 李涏 李 0.6666666666666666 이정
# 任兗 任 0.6666666666666666 임연
# 金岉 金 0.6666666666666666 김물
# 曺明勗 曺明勖 0.6666666666666666 조명욱
# 趙𤩶 趙 0.6666666666666666 조업
# 具寭 具 0.6666666666666666 구혜
# 柳𢢜 柳 0.6666666666666666 유업
# 朴晉章 朴晋章 0.6666666666666666 박진장
# 李熽 李 0.6666666666666666 이소
# 韓汝溭 韓汝 0.8 한여직
# 金闓 金 0.6666666666666666 김개
# 南橃 南 0.6666666666666666 남벌
# 李𥙆 李 0.6666666666666666 이현
# 權鑊 權 0.6666666666666666 권확
# 李楘 李 0.6666666666666666 이목
# 李楘 李 0.6666666666666666 이목
# 李莯 李 0.6666666666666666 이목
# 李莯 李 0.6666666666666666 이목
# 沈榰 沈 0.6666666666666666 심지
# 李用晉 李用晋 0.6666666666666666 이용진
# 韓明勗 韓明勖 0.6666666666666666 한명욱
# 南宮㯳 南宮 0.8 남궁경
# 李晉英 李晋英 0.6666666666666666 이진영
# 吳䎘 吳 0.6666666666666666 오숙
# 柳瀹 柳 0.6666666666666666 유약
# 朴潡 朴 0.6666666666666666 박돈
# 柳韡 柳 0.6666666666666666 유위
# 韓昅 韓 0.6666666666666666 한겁
# 金絅 金 0.6666666666666666 김경
# 朴簉 朴 0.6666666666666666 박추
# 金榘 金 0.6666666666666666 김구
# 許𡩁 許 0.6666666666666666 허친
# 李晉哲 李晋哲 0.6666666666666666 이진철
# 柳𢡮 柳 0.6666666666666666 유흠
# 金始煒 金始 0.8 김시위
# 趙景禛 趙景 0.8 조경진
# 許㮨 許 0.6666666666666666 허직
# 權怗 權 0.6666666666666666 권첩
# 姜𢢝 姜 0.6666666666666666 강수
# 李穧 李 0.6666666666666666 이제
# 申恜 申 0.6666666666666666 신칙
# 尹昈 尹 0.6666666666666666 윤호
# 黃瀡 黃 0.6666666666666666 황수
# 朴𥶷 朴 0.6666666666666666 박선
# 金矱 金 0.6666666666666666 김확
# 柳洬 柳 0.6666666666666666 유속
# 閔𦸂 閔 0.6666666666666666 민심
# 尹墀 尹 0.6666666666666666 윤지
# 申㥛 申 0.6666666666666666 신극
# 洪𩇉 洪 0.6666666666666666 홍보
# 金霱 金 0.6666666666666666 김휼
# 崔皞 崔 0.6666666666666666 최호
# 洪霫 洪 0.6666666666666666 홍습
# 任絖 任 0.6666666666666666 임광
# 黃㦿 黃 0.6666666666666666 황호
# 權淰 權 0.6666666666666666 권심
# 李莆 李 0.6666666666666666 이보
# 李𥡦 李 0.6666666666666666 이적
# 柳秠 柳 0.6666666666666666 유비
# 洪雴 洪 0.6666666666666666 홍입
# 姜翯 姜 0.6666666666666666 강학
# 李頤祥 李祥 0.8 이이상
# 尹㻩 尹 0.6666666666666666 윤겸
# 李㬅 李 0.6666666666666666 이만
# 柳𥳍 柳 0.6666666666666666 유심
# 洪瑑 洪 0.6666666666666666 홍전
# 權堣 權 0.6666666666666666 권우
# 李袤 李 0.6666666666666666 이무
# 申恦 申 0.6666666666666666 신상
# 李晠傳 李晟傳 0.6666666666666666 이성전
# 朴遾 朴 0.6666666666666666 박서
# 李禂 李 0.6666666666666666 이도
# 沈𪗆 沈 0.6666666666666666 심제
# 閔應恊 閔應協 0.6666666666666666 민응협
# 尹敉 尹 0.6666666666666666 윤미
# 兪㯙 兪 0.6666666666666666 유철
# 李有淐 李有 0.8 이유창
# 沈𢋡 沈 0.6666666666666666 심노
# 李溍 李 0.6666666666666666 이진
# 柳淰 柳 0.6666666666666666 유심
# 李頤賢 李賢 0.8 이이현
# 權澺 權 0.6666666666666666 권억
# 李䅘 李 0.6666666666666666 이내
# 李純馣 李純 0.8 이순암
# 李𡐔 李 0.6666666666666666 이인
# 李守諴 李守 0.8 이수함
# 鄭榏 鄭 0.6666666666666666 정익
# 申洬 申 0.6666666666666666 신속
# 李垕 李 0.6666666666666666 이후
# 李椲 李 0.6666666666666666 이휘
# 金鉽 金 0.6666666666666666 김식
# 洪鐩 洪 0.6666666666666666 홍수
# 吳翮 吳 0.6666666666666666 오핵
# 趙晉錫 趙晋錫 0.6666666666666666 조진석
# 洪葳 洪 0.6666666666666666 홍위
# 兪瑒 兪 0.6666666666666666 유창
# 閔光熽 閔光 0.8 민광소
# 權碖 權 0.6666666666666666 권논
# 沈棇 沈 0.6666666666666666 심총
# 李敏叙 李敏 0.8 이민서
# 具崟 具 0.6666666666666666 구음
# 鄭檏 鄭 0.6666666666666666 정박
# 李堥 李 0.6666666666666666 이무
# 慶㝡 慶 0.6666666666666666 경최
# 李䎘 李 0.6666666666666666 이숙
# 金楀 金 0.6666666666666666 김우
# 柳晉昌 柳晋昌 0.6666666666666666 유진창
# 李柙 李 0.6666666666666666 이합
# 李𤍿 李 0.6666666666666666 이전
# 尹抃 尹 0.6666666666666666 윤변
# 李秞 李 0.6666666666666666 이유
# 尹晢 尹 0.6666666666666666 윤절
# 李嵇 李 0.6666666666666666 이혜
# 尹堦 尹 0.6666666666666666 윤계
# 鄭樍 鄭 0.6666666666666666 정적
# 韓濙 韓 0.6666666666666666 한영
# 權瑎 權 0.6666666666666666 권해
# 李藼 李 0.6666666666666666 이훤
# 李璾 李 0.6666666666666666 이제
# 李壽㬅 李壽 0.8 이수만
# 柳㝚 柳 0.6666666666666666 유연
# 尹葕 尹 0.6666666666666666 윤연
# 洪𧡺 洪 0.6666666666666666 홍기
# 許悏 許 0.6666666666666666 허협
# 權瑍 權 0.6666666666666666 권환
# 安烒 安 0.6666666666666666 안식
# 尹弘离 尹弘 0.8 윤홍이
# 安垕 安 0.6666666666666666 안후
# 閔堦 閔 0.6666666666666666 민계
# 李墪 李 0.6666666666666666 이돈
# 沈橃 沈 0.6666666666666666 심벌
# 權儹 權 0.6666666666666666 권찬
# 申懹 申 0.6666666666666666 신양
# 許嶨 許 0.6666666666666666 허학
# 尹悏 尹 0.6666666666666666 윤협
# 申曅 申 0.6666666666666666 신엽
# 姜鋧 姜 0.6666666666666666 강현
# 李菂 李 0.6666666666666666 이적
# 李琩 李 0.6666666666666666 이창
# 金硡 金 0.6666666666666666 김굉
# 洪受瀗 洪受 0.8 홍수헌
# 洪璛 洪 0.6666666666666666 홍숙
# 李宇晉 李宇晋 0.6666666666666666 이우진
# 李震栻 李震 0.8 이진식
# 柳㬅 柳 0.6666666666666666 유만
# 李𦽦興 李興 0.8 이만흥
# 朴涏 朴 0.6666666666666666 박정
# 李東馣 李東 0.8 이동암
# 申銋 申 0.6666666666666666 신임
# 李頤晩 李晩 0.8 이이만
# 沈樘 沈 0.6666666666666666 심탱
# 成瑍 成 0.6666666666666666 성환
# 趙九畹 趙九 0.8 조구원
# 柳瑍 柳 0.6666666666666666 유환
# 李壄 李 0.6666666666666666 이야
# 李寅熽 李寅 0.8 이인소
# 朴繗 朴 0.6666666666666666 박인
# 姜楧 姜 0.6666666666666666 강영
# 李㙫 李 0.6666666666666666 이집
# 鄭栻 鄭 0.6666666666666666 정식
# 朴熙晉 朴熙晋 0.6666666666666666 박희진
# 任埅 任 0.6666666666666666 임방
# 申鐔 申 0.6666666666666666 신심
# 黃懰 黃 0.6666666666666666 황유
# 韓㵛 韓 0.6666666666666666 한선
# 金橰 金 0.6666666666666666 김고
# 金墰 金 0.6666666666666666 김담
# 安䋊 安 0.6666666666666666 안정
# 沈㙉 沈 0.6666666666666666 심전
# 沈勗之 沈勖之 0.6666666666666666 심욱지
# 柳侗 柳 0.6666666666666666 유동
# 李潝 李 0.6666666666666666 이흡
# 李賢涉 李涉 0.8 이현섭
# 具㢞 具 0.6666666666666666 구익
# 林德躋 林德 0.8 임덕제
# 宋霮 宋 0.6666666666666666 송담
# 柳焵 柳 0.6666666666666666 유강
# 權禛 權 0.6666666666666666 권진
# 羅㷜 羅 0.6666666666666666 나혁
# 李𡊠 李 0.6666666666666666 이갑
# 沈鏗 沈 0.6666666666666666 심갱
# 李春躋 李春 0.8 이춘제
# 兪彦恊 兪彦協 0.6666666666666666 유언협
# 尹㝚 尹 0.6666666666666666 윤연
# 權賮 權 0.6666666666666666 권신
# 朴㻐 朴 0.6666666666666666 박준
# 李日躋 李日 0.8 이일제
# 申澋 申 0.6666666666666666 신횡
# 洪曋 洪 0.6666666666666666 홍담
# 金洎 金 0.6666666666666666 김계
# 沈䥃 沈 0.6666666666666666 심악
# 朴弼榦 朴弼 0.8 박필간
# 朴玶 朴 0.6666666666666666 박평
# 鄭翬良 鄭良 0.8 정휘양
# 安𠍱 安 0.6666666666666666 안집
# 閔堣 閔 0.6666666666666666 민우
# 任𤩶 任 0.6666666666666666 임업
# 韓光恊 韓光協 0.6666666666666666 한광협
# 沈墢 沈 0.6666666666666666 심발
# 沈鏽 沈 0.6666666666666666 심수
# 沈國賢 沈國 0.8 심국현
# 任瑎 任 0.6666666666666666 임해
# 趙曮 趙 0.6666666666666666 조엄
# 李堣 李 0.6666666666666666 이우
# 任㻐 任 0.6666666666666666 임준
# 李晉圭 李晋圭 0.6666666666666666 이진규
# 柳叙五 柳五 0.8 유서오
# 李瀰 李 0.6666666666666666 이미
# 黃榦 黃 0.6666666666666666 황간
# 李溵 李 0.6666666666666666 이은
# 李益烍 李益 0.8 이익선
# 趙㻐 趙 0.6666666666666666 조준
# 金熤 金 0.6666666666666666 김익
# 沈頤之 沈之 0.8 심이지
# 趙瑍 趙 0.6666666666666666 조환
# 朴長爕 朴長燮 0.6666666666666666 박장섭
# 金頤柱 金柱 0.8 김이주
# 沈埉 沈 0.6666666666666666 심협
# 韓鼎𥙿 韓鼎裕 0.6666666666666666 한정유
# 李宗爕 李宗燮 0.6666666666666666 이종섭
# 崔烜 崔 0.6666666666666666 최훤
# 許霮 許 0.6666666666666666 허담
# 韓晩𥙿 韓晩裕 0.6666666666666666 한만유
# 申曮 申 0.6666666666666666 신엄
# 韓光綮 韓光 0.8 한광계
# 崔守忱 崔守 0.8 최수침
# 安筞 安 0.6666666666666666 안책
# 權儐 權 0.6666666666666666 권빈
# 李翼晉 李翼晋 0.6666666666666666 이익진
# 沈晉賢 沈晋賢 0.6666666666666666 심진현
# 鄭㝡成 鄭成 0.8 정최성
# 鄭㝡行 鄭行 0.8 정최행
# 申漵 申 0.6666666666666666 신서
# 李垿 李 0.6666666666666666 이서
# 兪漢㝢 兪漢 0.8 유한우
# 徐有榘 徐有 0.8 서유구
# 姜儐 姜 0.6666666666666666 강빈
# 洪大恊 洪大協 0.6666666666666666 홍대협
# 鄭東榦 鄭東 0.8 정동간
# 尹愭 尹 0.6666666666666666 윤기
# 韓耆𥙿 韓耆裕 0.6666666666666666 한기유
# 尹瀗 尹 0.6666666666666666 윤헌
# 尹穳 尹 0.6666666666666666 윤찬
# 金𨩿 金 0.6666666666666666 김후
# 趙晉和 趙晋和 0.6666666666666666 조진화
# 柳訸 柳 0.6666666666666666 유화
# 沈鈁 沈 0.6666666666666666 심방
# 金鐮 金 0.6666666666666666 김염
# 金基叙 金基 0.8 김기서
# 權傛 權 0.6666666666666666 권용
# 李晉淵 李晋淵 0.6666666666666666 이진연
# 金逌根 金根 0.8 김유근
# 韓晉赫 韓晋赫 0.6666666666666666 한진혁
# 金鏴 金 0.6666666666666666 김노
# 金䥧 金 0.6666666666666666 김선
# 金鍏 金 0.6666666666666666 김위
# 李圭祊 李圭 0.8 이규팽
# 韓鎭㦿 韓鎭 0.8 한진호
# 黃𥞵 黃 0.6666666666666666 황겹
# 權筴 權 0.6666666666666666 권협
# 權溭 權 0.6666666666666666 권직
# 李鼎叙 李鼎 0.8 이정서
# 李寅臯 李寅皐 0.6666666666666666 이인고
# 李範晉 李範晋 0.6666666666666666 이범진
# 鄭㝡朝 鄭朝 0.8 정최조
# 李晉翼 李晋翼 0.6666666666666666 이진익
# 李㘾 李 0.6666666666666666 이우
# 睦仁㘽 睦仁 0.8 목인재
# 李𥙿膺 李裕膺 0.6666666666666666 이유응
# 姜㳣 姜 0.6666666666666666 강노
# 林謇洙 林洙 0.8 임건수
# 洪承𥙿 洪承裕 0.6666666666666666 홍승유
# 趙定爕 趙定燮 0.6666666666666666 조정섭
# 李𥙿承 李裕承 0.6666666666666666 이유승
# 李承臯 李承皐 0.6666666666666666 이승고
# 金永珯 金永 0.8 김영노
# 姜𧄽 姜 0.6666666666666666 강찬
# 韓晢東 韓東 0.8 한절동
# 金㠎 金 0.6666666666666666 김집
# 金嶷 金 0.6666666666666666 김의
# 金隼翼 金翼 0.8 김준익
# 李丙逌 李丙 0.8 이병유
# 李大頤 李大 0.8 이대이
# 許㥌 許 0.6666666666666666 허국
# 玉晉輝 玉晋輝 0.6666666666666666 옥진휘
# 金昌鼐 金昌 0.8 김창내
# 姜繗 姜 0.6666666666666666 강인
# 徐道𥙿 徐道裕 0.6666666666666666 서도유
# 朴鎤 朴 0.6666666666666666 박황
# 李濰 李 0.6666666666666666 이유
# 權愃 權 0.6666666666666666 권선
# 李偰 李 0.6666666666666666 이설
# 張彦忱 張彦 0.8 장언침
# 權世橚 權世 0.8 권세숙
# 羅㶷 羅 0.6666666666666666 나순
# 朴 朴柱 0.6666666666666666 박기주
# 權偌 權 0.6666666666666666 권야
# 金琂 金 0.6666666666666666 김언
# 尹㻻 尹 0.6666666666666666 윤돈
# 李茳 李 0.6666666666666666 이강
# 琴𢢜 琴 0.6666666666666666 금업
# 李苙 李 0.6666666666666666 이입
# 李晩煃 李晩 0.8 이만규
# 張晉遠 張晋遠 0.6666666666666666 장진원
# 朴嶔 朴 0.6666666666666666 박금
# 閔忱 閔 0.6666666666666666 민침
# 李㝡承 李承 0.8 이최승
# 金晉鐸 金晋鐸 0.6666666666666666 김진탁
# 閔惕 閔 0.6666666666666666 민척
# 尹滋畊 尹滋 0.8 윤자경
# 權愭 權 0.6666666666666666 권기
# 全鼐勳 全勳 0.8 전내훈
# 姜詗 姜 0.6666666666666666 강형
# 尹士昀 尹士 0.8 윤사윤
# 柳晉三 柳晋三 0.6666666666666666 유진삼
# 李禬 李 0.6666666666666666 이회
# 崔瑍 崔 0.6666666666666666 최환
# 金炳㴤 金炳 0.8 김병주

# %%
# THESE NEED TO BE THE SAME
assert(len(df_similar_chi_name_lee) == len(df_similar_chi_name_ws))
print(len(df_similar_chi_name_lee), len(df_similar_chi_name_ws))
# Out:
# 1120 1120

# %%
# There are repeats. 
len(df_similar_chi_name_lee['lee_uuid'].unique()),len(df_similar_chi_name_ws['ws_uuid'].unique())
# Out:
# (1118, 1116)

# %%
# Duplicates
df_similar_chi_name_lee = df_similar_chi_name_lee.reset_index()
lee_dup = df_similar_chi_name_lee[df_similar_chi_name_lee['lee_uuid'].duplicated(False)]
lee_dup[['lee_uuid','korname', 'chnname', 'other_chi_name_in_WS_version', 'other_chi_name_in_WS_version_uuid']]
# Out:
#                                  lee_uuid korname chnname  \
# 816  c5b8a0c3-fe87-5004-b7bb-cd6d2c7da9be      이목      李楘
# 817  c5b8a0c3-fe87-5004-b7bb-cd6d2c7da9be      이목      李楘
# 818  a6382748-0883-5c51-afe7-1bebc60152f7      이목      李莯
# 819  a6382748-0883-5c51-afe7-1bebc60152f7      이목      李莯
#
#     other_chi_name_in_WS_version     other_chi_name_in_WS_version_uuid
# 816                            李  a28023af-8791-5c39-9f49-2856c57cf410
# 817                            李  1da79682-6fb5-5029-bca5-9969dd572b9b
# 818                            李  a28023af-8791-5c39-9f49-2856c57cf410
# 819                            李  1da79682-6fb5-5029-bca5-9969dd572b9b

# %%
# Since there are so few I will just manually delete them
lee_dup = lee_dup.drop([816, 819])
lee_dup[['lee_uuid','korname', 'chnname', 'other_chi_name_in_WS_version', 'other_chi_name_in_WS_version_uuid']]
# Out:
#                                  lee_uuid korname chnname  \
# 817  c5b8a0c3-fe87-5004-b7bb-cd6d2c7da9be      이목      李楘
# 818  a6382748-0883-5c51-afe7-1bebc60152f7      이목      李莯
#
#     other_chi_name_in_WS_version     other_chi_name_in_WS_version_uuid
# 817                            李  1da79682-6fb5-5029-bca5-9969dd572b9b
# 818                            李  a28023af-8791-5c39-9f49-2856c57cf410

# %%
# MERGING only on Korean name and year
master2 = pd.DataFrame([])
master2 = pd.merge(df_similar_chi_name_lee, df_similar_chi_name_ws, indicator=True, how='left', left_on=['korname','pass_year'], right_on = ['namehg1','year'])

# Drop duplicate Korean name, Chinese name, and exam year, then rename those columns to be clearer
master2 = master2.drop(columns=['namehg1', 'namehj1', 'year'])
master2 = master2.rename(columns={'korname':'kor_name', 'chnname':'chi_name'})

# These numbers are unequal bc of all of the extra duplicates, etc
len(master2), len(master2['lee_uuid'].unique()), len(master2['ws_uuid'].unique())
# Out:
# (1136, 1118, 1116)

# %%
# Merge these with master
frames = [master, master2]
master = pd.concat(frames, sort=False)

merge3 = master.copy()

# %%
len(master[~master['other_chi_name_in_WS_version'].isnull()])
# Out:
# 1136

# %%
# Update these values
lee_unmerged = data_lee[~data_lee['lee_uuid'].isin(master['lee_uuid'].unique())]
ws_unmerged = data_ws[~data_ws['ws_uuid'].isin(master['ws_uuid'].unique())]

len(ws_unmerged),len(lee_unmerged)
# Out:
# (293, 829)

# %%
# We still have 293 in data_ws that cannot be matched with data_lee
len(data_ws[~data_ws['ws_uuid'].isin(master['ws_uuid'].unique())])
# Out:
# 293

# %% [markdown]
# ## `merge4` - Merge Similar Korean Names - 50%

# %%
master = merge3

# %%
df_similar_kor_name_lee = pd.DataFrame([])
df_similar_kor_name_ws = pd.DataFrame([])

# Iterate through each person in lee_unmerged
# Find that person in ws_person based on Chinese name and exam year
# Determine if if the person has similar Korean names, they are one person
# Look at the repeated_testtaker. If same numbers, fine
# If different numbers, take the larger of the values
# I guess for now, add repeat
for index, row in lee_unmerged.iterrows():
    exam_year = row['pass_year']
    chi_name = row['chnname']
    kor_name = row['korname']
    repeated = row['repeated_testtaker_lee']
    
    # only matching Chinese name and exam year
    ws_person = ws_unmerged[(ws_unmerged['namehj1'] == chi_name) & (ws_unmerged['year'] == exam_year)]
    
    for person_index in range(len(ws_person)):
#         print(ws_person["namehg1"][person_index], kor_name, ws_person["namehj1"][person_index], similar(ws_person["namehg1"][person_index], kor_name))
        if (similar(ws_person["namehg1"].iloc[person_index], kor_name) >= 0.5):
            print(ws_person["namehg1"].iloc[person_index], kor_name, ws_person["namehj1"].iloc[person_index])
            row_copy = row.copy()
            row_copy['other_kor_name_in_WS_version'] = ws_person["namehg1"].iloc[person_index]
            row_copy['other_kor_name_in_WS_version_uuid'] = ws_person["ws_uuid"].iloc[person_index]
            df_similar_kor_name_lee = df_similar_kor_name_lee.append(row_copy)    
            df_similar_kor_name_ws = df_similar_kor_name_ws.append(ws_person)
# Out:
# 표윤 표빈 表贇
# 정윤 정빈 鄭贇
# 유송 유책 柳
# 윤윤 윤빈 尹贇
# 이윤 이빈 李贇
# 이옥 이욱 李稶
# 조윤 조빈 趙贇
# 임박 임부 林
# 최윤 최빈 崔贇

# %% [markdown]
# I understand these names are very different but for now I will just assume they are the same because they look similar enough...?

# %%
assert(len(df_similar_kor_name_lee) == len(df_similar_kor_name_ws))
(len(df_similar_kor_name_lee),len(df_similar_kor_name_ws))
# Out:
# (9, 9)

# %%
# MERGING only on Chinese name and year
master2 = pd.merge(df_similar_kor_name_lee, df_similar_kor_name_ws, indicator=True, how='inner', left_on=['chnname','pass_year'], right_on = ['namehj1','year'])

# Drop duplicate Korean name, Chinese name, and exam year, then rename those columns to be clearer
master2 = master2.drop(columns=['namehg1', 'namehj1', 'year'])
master2 = master2.rename(columns={'korname':'kor_name', 'chnname':'chi_name'})

len(master2), len(master2['lee_uuid'].unique()), len(master2['ws_uuid'].unique())
# Out:
# (9, 9, 9)

# %%
# Merge these with master
frames = [master, master2]
master = pd.concat(frames, sort=False)

merge4 = master.copy()

# %%
# Update these values. There are 284 left in WS we need to merge in
lee_unmerged = data_lee[~data_lee['lee_uuid'].isin(master['lee_uuid'].unique())]
ws_unmerged = data_ws[~data_ws['ws_uuid'].isin(master['ws_uuid'].unique())]
len(ws_unmerged),len(lee_unmerged)
# Out:
# (284, 820)

# %% [markdown]
# ## `merge5` - Merge Similar Chinese Names - 50%

# %%
master = merge4

# %%
# If Chinese names are the same and Korean names are FIFTY PERCENT (this is less than before)
# Use eyes to make sure these are right
# Manually choose the people who are the same

df_similar_chi_name_lee = pd.DataFrame([])
df_similar_chi_name_ws = pd.DataFrame([])

for index, row in lee_unmerged.iterrows():
    exam_year = row['pass_year']
    chi_name = row['chnname']
    kor_name = row['korname']
    
    # only matching Chinese name and exam year
    ws_person = ws_unmerged[(ws_unmerged['namehg1'] == kor_name) & (ws_unmerged['year'] == exam_year)]
    if (len(ws_person) > 0) :
        for person_index in range(len(ws_person)):
            if (similar(ws_person["namehj1"].iloc[person_index], chi_name) >= 0.5):
                print(chi_name, ws_person["namehj1"].iloc[person_index], similar(ws_person["namehj1"].iloc[person_index], chi_name), ws_person['namehg1'].iloc[person_index], row['korname'])
                row_copy = row.copy()
                row_copy['other_chi_name_in_WS_version'] = ws_person.iloc[person_index]["namehj1"]
                row_copy['other_chi_name_in_WS_version_uuid'] = ws_person.iloc[person_index]["ws_uuid"]

                df_similar_chi_name_lee = df_similar_chi_name_lee.append(row_copy)
                df_similar_chi_name_ws = df_similar_chi_name_ws.append(ws_person.iloc[person_index])
# Out:
# 鄭鄰 鄭隣 0.5 정인 정인
# 康福 康輻 0.5 강복 강복
# 安憙 安熹 0.5 안희 안희
# 張晉 張晋 0.5 장진 장진
# 李晉 李晋 0.5 이진 이진
# 李𡎘 李瑛 0.5 이영 이영
# 徐崗 徐岡 0.5 서강 서강
# 郭恂 郭珣 0.5 곽순 곽순
# 徐晉 徐晋 0.5 서진 서진
# 李蹈 李韜 0.5 이도 이도
# 韓淃 韓卷 0.5 한권 한권
# 康晉 康晋 0.5 강진 강진
# 成晉 成晋 0.5 성진 성진
# 孫㴻 孫澍 0.5 손주 손주
# 金冲 金沖 0.5 김충 김충
# 許晉 許晋 0.5 허진 허진
# 李冲 李沖 0.5 이충 이충
# 尹晉 尹晋 0.5 윤진 윤진
# 沈枰 沈坪 0.5 심평 심평
# 鄭恊 鄭協 0.5 정협 정협
# 鄭晉 鄭晋 0.5 정진 정진
# 李惕然 李 0.5 이척연 이척연
# 許頴 許潁 0.5 허영 허영
# 洪墪 洪墩 0.5 홍돈 홍돈
# 權𠌶 權華 0.5 권화 권화

# %%
# THESE NEED TO BE THE SAME
assert(len(df_similar_chi_name_lee) == len(df_similar_chi_name_ws))
print(len(df_similar_chi_name_lee), len(df_similar_chi_name_ws))
# Out:
# 25 25

# %%
# MERGING only on Korean name and year
master2 = pd.DataFrame([])
master2 = pd.merge(df_similar_chi_name_lee, df_similar_chi_name_ws, indicator=True, how='left', left_on=['korname','pass_year'], right_on = ['namehg1','year'])

# Drop duplicate Korean name, Chinese name, and exam year, then rename those columns to be clearer
master2 = master2.drop(columns=['namehg1', 'namehj1', 'year'])
master2 = master2.rename(columns={'korname':'kor_name', 'chnname':'chi_name'})

# These numbers are unequal bc of all of the extra duplicates, etc
len(master2), len(master2['lee_uuid'].unique()), len(master2['ws_uuid'].unique())

# Merge these with master
frames = [master, master2]
master = pd.concat(frames, sort=False)

master = master.reset_index(drop=True)
merge5 = master.copy()

# %%
# Update these values. 259 more to match from WS
lee_unmerged = data_lee[~data_lee['lee_uuid'].isin(master['lee_uuid'].unique())]
ws_unmerged = data_ws[~data_ws['ws_uuid'].isin(master['ws_uuid'].unique())]

len(ws_unmerged),len(lee_unmerged)
# Out:
# (259, 795)

# %% [markdown]
# ## `merge6` - Merge on year,  1-1 Mapping Between both versions for same year, Korean and Chinese names at least 50% similar
# For this one I will ONLY be checking if for the given year, the Korean and Chinese names are more than 50 percent similar

# %%
# Fix a few characters manually

# ws_unmerged = ws_unmerged.replace(to_replace=r'葉', value='葉', regex=True)
# ws_unmerged = ws_unmerged.replace(to_replace=r'省', value='省', regex=True)
# ws_unmerged = ws_unmerged.replace(to_replace=r'龜', value='龜', regex=True)
# # ws_unmerged = ws_unmerged.replace(to_replace=r'葉', value='葉', regex=True)
# # ws_unmerged = ws_unmerged.replace(to_replace=r'葉', value='葉', regex=True)

# %%
master = merge5

# %% [markdown]
# There are now 259 left from WS that I need to merge

# %%
len(ws_unmerged),len(lee_unmerged), len(master)
# Out:
# (259, 795, 14375)

# %%
ws_unique_years_remaining = ws_unmerged['year'].unique()
len(ws_unique_years_remaining)
# Out:
# 179

# %% [markdown]
# Quick check: In the remaining `ws_unmerged`, there are no more repeated testtakers in the same year, while in the remaining `lee_unmerged`, there are still quite a few repeated testtakers in the same year.

# %%
ws_unmerged[ws_unmerged['repeated_testtaker_ws'] == True]
# Out:
# Empty DataFrame
# Columns: [ws_uuid, year, namehg1, namehj1, repeated_testtaker_ws]
# Index: []

# %%
lee_unmerged[lee_unmerged['repeated_testtaker_lee'] == True]
# Out:
#                                                                   lee_uuid  \
# uuid
# 13047f7a-b949-5459-88fc-5b6d4492faf1  13047f7a-b949-5459-88fc-5b6d4492faf1
# b241eaf2-0615-58c0-b079-335335674107  b241eaf2-0615-58c0-b079-335335674107
# adffe1c5-3c4f-54fd-92cc-76e555096767  adffe1c5-3c4f-54fd-92cc-76e555096767
# 36626ade-89d8-5e5f-b42a-ec185c31d2ff       1466      이예      李芮
# 60362653-9ebe-5d6d-96b9-c617c2362ee8       1727     이귀휴     李龜休
# 03f5c21c-a016-5143-83b2-3b99669126e3       1727     이귀휴     李龜休
# 5d0a420e-2b50-511d-89a0-6872d649495b       1466      김유      金紐
# 0b9607ce-798f-5072-afea-5f449eaea629       1466      김유      金紐
# c52db075-f8bc-5bed-bc6e-4333771de0a0       1466     김수온     金守溫
# 20f762dd-6e41-5fc2-bc2c-bac0f02b7dfc       1466     이수남     李壽男
# a079e330-e9cf-5b36-8bfe-b0646d466da6       1466     최숙정     崔淑精
# 90d2c7a3-5e34-5eca-b5ba-05a83d3be62e       1466     최숙정     崔淑精
# ec7822da-ffb5-53b0-81c4-c2cc764e6fa2       1466     김수온     金守溫
#
#                                       repeated_testtaker_lee
# uuid
# 13047f7a-b949-5459-88fc-5b6d4492faf1                    True
# b241eaf2-0615-58c0-b079-335335674107                    True
# adffe1c5-3c4f-54fd-92cc-76e555096767                    True
# 7828bff3-2486-5330-8071-8bec0838a9ce                    True
# 25549b5f-1a17-58eb-8968-f8502dab6361                    True
# eaf75b13-772d-50dc-a565-4165db7d0e55                    True
# 91c2e162-7274-57eb-b7d9-52f1cea28344                    True
# f418d62a-e3e0-5178-a602-8dab89509cb1                    True
# 033c8a4a-c74c-540b-a50b-ccd8bed59184                    True
# 68257fc7-b55f-54df-8c36-f2511835384f                    True
# 1dc793b9-084b-52d0-bb6c-fb8d8b310f54                    True
# 595ad93f-8711-566d-afe0-4773270b7058                    True
# 0b00dcdd-54f7-59f8-84ac-2c92439fac3f                    True
# 92ca9297-4a74-5366-be0d-4b43eed8cdd8                    True
# 25b7af39-06b7-5e78-9d0b-45f04abc838e                    True
# 97ae1844-c21e-5797-aee6-ae14b55a5959                    True
# b0ce4d6a-0568-5c3c-9a81-b94a3979d264                    True
# 1bf16407-0ced-58c0-ba6b-9f4751c5ff38                    True
# efa623aa-06f6-596f-b48f-1492b0c3749b                    True
# 6c792e82-f76e-5203-abcd-2bab6e56d6ec                    True
# e324aaec-07fc-5a90-aabf-f85d70ce7182                    True
# ca82ae66-1c6b-51a6-a1ae-921a6f814f1c                    True
# 278cca66-e561-5fde-8eed-df0e95160f74                    True
# e0d99cb1-9c59-554d-9f0b-1faed3960a51                    True
# f3749b5a-318c-5e43-a2c3-a16e30d0ea2f                    True
# 8889a78a-3b14-5e8d-9b6c-27c300fe8ed0                    True
# 4205f987-1041-5939-8719-95677d8d4ad2                    True
# 36626ade-89d8-5e5f-b42a-ec185c31d2ff                    True
# 60362653-9ebe-5d6d-96b9-c617c2362ee8                    True
# 03f5c21c-a016-5143-83b2-3b99669126e3                    True
# 5d0a420e-2b50-511d-89a0-6872d649495b                    True
# 0b9607ce-798f-5072-afea-5f449eaea629                    True
# c52db075-f8bc-5bed-bc6e-4333771de0a0                    True
# 20f762dd-6e41-5fc2-bc2c-bac0f02b7dfc                    True
# a079e330-e9cf-5b36-8bfe-b0646d466da6                    True
# 90d2c7a3-5e34-5eca-b5ba-05a83d3be62e                    True
# ec7822da-ffb5-53b0-81c4-c2cc764e6fa2                    True

# %%
ws_unmerged[ws_unmerged['year'] == 1486][['namehg1', 'namehj1', 'repeated_testtaker_ws']]
# Out:
#                                      namehg1 namehj1  repeated_testtaker_ws
# uuid
# 26d85c87-fcde-51e7-a35c-3efd1480cc86     변희계     邊希季                  False
# 102cce1f-c7d9-5f39-a419-405f6c67fbd0     정이득     鄭而得                  False

# %%
lee_unmerged[lee_unmerged['pass_year'] == 1486][['korname', 'chnname', 'repeated_testtaker_lee']]
# Out:
#                                      korname chnname  repeated_testtaker_lee
# uuid
# 931545e1-d757-50b2-bbb6-56adec213f40      최부      崔溥                   False
# 93f965e8-88f3-5035-b6e0-9cf94d7eefe6     이대형     李大亨                   False
# 1afe871c-e5d1-553e-b307-21c65dac4535     김준손     金駿孫                   False
# 279c4447-3259-5650-bfa7-04e6653a8f0e     정이교     鄭以僑                   False
# adfd0902-7579-5e49-9054-5b57818193eb     변희효     邊希孝                   False
# 7b72667a-352b-5634-99fd-1d938a34a2dc     정이심     鄭以諶                   False
# d257f663-556f-56e8-9a2f-b7d6d8223fcb     신종호     申從濩                   False
# be8a662d-7991-5b00-a788-d89cd6a1dc0a     박증영     朴增榮                   False
# 36ee22ae-c035-59cb-a1ec-29ee6a584898     민보익     閔輔翼                   False
# 4580d311-f8d1-5cbb-9083-a52517db197d     표연말     表沿沫                   False

# %%
df_similar_lee = pd.DataFrame([])
df_similar_ws = pd.DataFrame([])

# Find 1-1 mappings between the two 
# All of the 1-1 Mappings are the same person except for the year 1935. 

for year in ws_unique_years_remaining:

    ws_person = ws_unmerged[(ws_unmerged['year'] == year)]
    lee_person = lee_unmerged[(lee_unmerged['pass_year'] == year)]

    # Only if there is a 1-1 mapping between the two
    if (len(ws_person) == 1 and len(lee_person) == 1):
        ws_person_name = ws_person['namehg1'].iloc[0].replace('구', '귀')
        lee_person_name = lee_person['korname'].iloc[0]
        ws_person_name_ch = ws_person['namehj1'].iloc[0]
        lee_person_name_ch = lee_person['chnname'].iloc[0]
        
        if (similar(ws_person_name, lee_person_name) >= 0.5) or (similar(ws_person_name_ch, lee_person_name_ch) >= 0.5):
#             print(year, ws_person_name, lee_person_name, ws_person_name_ch, lee_person_name_ch)
            row_copy = lee_person.copy()
            row_copy['other_kor_name_in_WS_version'] = ws_person['namehg1'].iloc[0]
            row_copy['other_chi_name_in_WS_version'] = ws_person_name_ch
            row_copy['other_kor_name_in_WS_version_uuid'] = ws_person["ws_uuid"].iloc[0]
            row_copy['other_chi_name_in_WS_version_uuid'] = ws_person["ws_uuid"].iloc[0]
            
            df_similar_lee = df_similar_lee.append(row_copy)    
            df_similar_ws = df_similar_ws.append(ws_person)    
            
        else:
            print(year, ws_person_name, lee_person_name, ws_person_name_ch, lee_person_name_ch)
# Out:
# 1435.0 노진해 노선경 盧晋諧 盧善卿

# %%
len(df_similar_lee)
# Out:
# 101

# %%
# MERGING only on Chinese name and year
master2 = pd.merge(df_similar_lee, df_similar_ws, indicator=True, how='inner', left_on=['pass_year'], right_on = ['year'])

# Drop duplicate Korean name, Chinese name, and exam year, then rename those columns to be clearer
master2 = master2.drop(columns=['namehg1', 'namehj1', 'year'])
master2 = master2.rename(columns={'korname':'kor_name', 'chnname':'chi_name'})

len(master2), len(master2['lee_uuid'].unique()), len(master2['ws_uuid'].unique())
# Out:
# (101, 101, 101)

# %%
# Merge these with master
frames = [master, master2]
master = pd.concat(frames, sort=False)

merge6 = master.copy()

# %%
# Update these values: 158 Left
lee_unmerged = data_lee[~data_lee['lee_uuid'].isin(master['lee_uuid'].unique())]
ws_unmerged = data_ws[~data_ws['ws_uuid'].isin(master['ws_uuid'].unique())]
len(ws_unmerged),len(lee_unmerged)
# Out:
# (158, 694)

# %% [markdown]
# ## `merge7` Merge on year, 1-many mapping from WS-Lee for the same year

# %%
master = merge6

# %%
# 158 more to merge from WS
len(ws_unmerged),len(lee_unmerged), len(master)
# Out:
# (158, 694, 14476)

# %%
ws_unique_years_remaining = ws_unmerged['year'].unique()
len(ws_unique_years_remaining)
# Out:
# 78

# %%
ws_unmerged[ws_unmerged['year'] == 1636][['namehg1', 'namehj1', 'repeated_testtaker_ws']]
# Out:
#                                      namehg1 namehj1  repeated_testtaker_ws
# uuid
# d20527f9-6166-5eab-9d67-61b2f56d8f70      남선       南                  False

# %%
lee_unmerged[lee_unmerged['pass_year'] == 1636][['korname', 'chnname', 'repeated_testtaker_lee']]
# Out:
#                                      korname chnname  repeated_testtaker_lee
# uuid
# b5c49d52-764c-5561-ab15-0fb1310da88e      남훤      南翧                   False
# 2170c17e-0ee4-51c5-a85e-fa9bdac8595a     남노성     南老星                   False
# 85789025-50fc-58cb-9c0e-2d5925d695dc      이도      李禂                   False
# 4f67f8a3-cb31-505f-9851-e2fc51b609b0     홍명일     洪命一                   False
# 6c7d5fae-8ec9-5e41-8de1-3cc66ced6304     최계훈     崔繼勳                   False
# bcc41e44-5e60-5226-9e94-441342940e47      허계      許啓                   False
# 32151664-286d-518b-97ef-7e500fc45191     신희계     辛喜季                   False

# %% [markdown]
# Find the (Korean names that are 50% similar) and (Chinese names that are 50% similar) for 1-Many mappings (1 is WS). So we need to find the person BEST fits from the Lee version

# %%
df_similar_lee = pd.DataFrame([])
df_similar_ws = pd.DataFrame([])

# Find 1-1 mappings between the two 
# All of the 1-1 Mappings are the same person except for the year 1935. 

for year in ws_unique_years_remaining:

    ws_person = ws_unmerged[(ws_unmerged['year'] == year)]
    lee_persons = lee_unmerged[(lee_unmerged['pass_year'] == year)]

    # Only if there is a 1-1 mapping between the two
    if (len(ws_person) == 1):
#         print(len(lee_person), year)
        
        # Find the Lee person who is the closest 
        kr_highest = 0
        ch_highest = 0
        
        
        temp = pd.DataFrame([])
        for lee_index, lee_row in lee_persons.iterrows():
#             print(lee_persons)
            kr_similarity = similar(ws_person['namehg1'].iloc[0].replace('구', '귀'), lee_row['korname'])
            ch_similarity = similar(ws_person['namehj1'].iloc[0], lee_row['chnname'])
        
            if (kr_similarity >= 0.5 and ch_similarity >= 0.5):
                temp = temp.append([{'kr_similarity': kr_similarity,
                                 'ch_similarity': ch_similarity,
                                 'ws_korname': ws_person['namehg1'].iloc[0],
                                 'lee_korname': lee_row['korname'],
                                 'ws_chnname': ws_person['namehj1'].iloc[0],
                                 'lee_chnname': lee_row['chnname'],
                                 'lee_person': lee_row
                                }])
            
        
        if not temp.empty:
            temp = temp.reset_index(drop=True)
            tempmax = temp.loc[temp['kr_similarity'].idxmax()]
            print(year, tempmax)

            row_copy = tempmax['lee_person'].copy()
            row_copy['other_kor_name_in_WS_version'] = ws_person['namehg1'].iloc[0]
            row_copy['other_chi_name_in_WS_version'] = ws_person['namehj1'].iloc[0]
            row_copy['other_kor_name_in_WS_version_uuid'] = ws_person["ws_uuid"].iloc[0]
            row_copy['other_chi_name_in_WS_version_uuid'] = ws_person["ws_uuid"].iloc[0]
            df_similar_lee = df_similar_lee.append(row_copy)

            df_similar_ws = df_similar_ws.append(ws_person)
#         print(temp.max())
# Out:
# 1427.0 kr_similarity                                             0.666667
# ch_similarity                                             0.666667
# ws_korname                                                     백효참
# lee_korname                                                    백효삼
# ws_chnname                                                     白效參
# lee_chnname                                                    白效參
# lee_person       lee_uuid                  ee212a3c-34cb-58a5-b...
# Name: 0, dtype: object
# 1479.0 kr_similarity                                                    1
# ch_similarity                                             0.666667
# ws_korname                                                     강구손
# lee_korname                                                    강귀손
# ws_chnname                                                     姜龜孫
# lee_chnname                                                    姜龜孫
# lee_person       lee_uuid                  57219107-687b-5578-9...
# Name: 0, dtype: object
# 1480.0 kr_similarity                                                  0.5
# ch_similarity                                                  0.5
# ws_korname                                                      강참
# lee_korname                                                     강삼
# ws_chnname                                                      姜參
# lee_chnname                                                     姜參
# lee_person       lee_uuid                  bb4342d1-d8ee-5bd9-a...
# Name: 0, dtype: object
# 1516.0 kr_similarity                                             0.666667
# ch_similarity                                             0.666667
# ws_korname                                                     이부손
# lee_korname                                                    이전손
# ws_chnname                                                     李傅孫
# lee_chnname                                                    李傳孫
# lee_person       lee_uuid                  ef1dbaeb-2aa6-54e2-b...
# Name: 0, dtype: object
# 1589.0 kr_similarity                                                  0.5
# ch_similarity                                                  0.5
# ws_korname                                                      곽설
# lee_korname                                                     곽열
# ws_chnname                                                      郭說
# lee_chnname                                                     郭說
# lee_person       lee_uuid                  aac9afba-fc0b-5328-a...
# Name: 0, dtype: object
# 1636.0 kr_similarity                                                  0.5
# ch_similarity                                             0.666667
# ws_korname                                                      남선
# lee_korname                                                     남훤
# ws_chnname                                                       南
# lee_chnname                                                     南翧
# lee_person       lee_uuid                  b5c49d52-764c-5561-a...
# Name: 0, dtype: object
# 1686.0 kr_similarity                                             0.666667
# ch_similarity                                             0.666667
# ws_korname                                                     박견선
# lee_korname                                                    박현선
# ws_chnname                                                     朴見善
# lee_chnname                                                    朴見善
# lee_person       lee_uuid                  2fa4e1b6-7668-52ec-b...
# Name: 0, dtype: object
# 1697.0 kr_similarity                                                    1
# ch_similarity                                             0.666667
# ws_korname                                                     심구서
# lee_korname                                                    심귀서
# ws_chnname                                                     沈龜瑞
# lee_chnname                                                    沈龜瑞
# lee_person       lee_uuid                  5b84fbb1-5440-5d9b-a...
# Name: 0, dtype: object
# 1699.0 kr_similarity                                             0.666667
# ch_similarity                                             0.666667
# ws_korname                                                     이진엽
# lee_korname                                                    이진섭
# ws_chnname                                                     李震葉
# lee_chnname                                                    李震葉
# lee_person       lee_uuid                  64b2f7a5-030b-5e36-a...
# Name: 0, dtype: object
# 1707.0 kr_similarity                                                    1
# ch_similarity                                             0.666667
# ws_korname                                                     어유구
# lee_korname                                                    어유귀
# ws_chnname                                                     魚有龜
# lee_chnname                                                    魚有龜
# lee_person       lee_uuid                  f71341b2-dd96-501f-9...
# Name: 0, dtype: object
# 1717.0 kr_similarity                                                    1
# ch_similarity                                             0.666667
# ws_korname                                                     김성구
# lee_korname                                                    김성귀
# ws_chnname                                                     金聖龜
# lee_chnname                                                    金聖龜
# lee_person       lee_uuid                  b25e5d99-d9b6-53e4-a...
# Name: 0, dtype: object
# 1757.0 kr_similarity                                             0.666667
# ch_similarity                                             0.666667
# ws_korname                                                     홍악순
# lee_korname                                                    홍낙순
# ws_chnname                                                     洪樂純
# lee_chnname                                                    洪樂純
# lee_person       lee_uuid                  5ba3f0df-c460-5149-b...
# Name: 0, dtype: object
# 1816.0 kr_similarity                                             0.666667
# ch_similarity                                             0.666667
# ws_korname                                                     전국헌
# lee_korname                                                    김국헌
# ws_chnname                                                     全國憲
# lee_chnname                                                    金國憲
# lee_person       lee_uuid                  d800207d-e9d4-5c8c-b...
# Name: 0, dtype: object
# 1846.0 kr_similarity                                                    1
# ch_similarity                                             0.666667
# ws_korname                                                     조명구
# lee_korname                                                    조명귀
# ws_chnname                                                     趙名龜
# lee_chnname                                                    趙名龜
# lee_person       lee_uuid                  96521a37-529a-5174-a...
# Name: 0, dtype: object
# 1866.0 kr_similarity                                             0.666667
# ch_similarity                                             0.666667
# ws_korname                                                     심상설
# lee_korname                                                    심상열
# ws_chnname                                                     沈相說
# lee_chnname                                                    沈相說
# lee_person       lee_uuid                  452e93fc-9f0d-5870-8...
# Name: 0, dtype: object
# 1876.0 kr_similarity                                             0.666667
# ch_similarity                                             0.666667
# ws_korname                                                     박노참
# lee_korname                                                    박노삼
# ws_chnname                                                     朴魯參
# lee_chnname                                                    朴魯參
# lee_person       lee_uuid                  5aa6c870-9d40-508f-a...
# Name: 0, dtype: object

# %%
df_similar_lee[['korname','other_kor_name_in_WS_version', 'chnname', 'other_chi_name_in_WS_version', 'repeated_testtaker_lee']]
# Out:
#                                      korname other_kor_name_in_WS_version  \
# ee212a3c-34cb-58a5-b235-af2bcad7d58c     백효삼                          백효참
# 57219107-687b-5578-9eca-47809ea11741     강귀손                          강구손
# bb4342d1-d8ee-5bd9-a573-912b43845970      강삼                           강참
# b25e5d99-d9b6-53e4-ab3c-01bc32ce563c                     0.0
# 5ba3f0df-c460-5149-b53b-910689d13ec1                     0.0
# d800207d-e9d4-5c8c-b9d6-19135a55ef8c                     0.0
# 96521a37-529a-5174-a903-4f995ab76036                     0.0
# 452e93fc-9f0d-5870-85e5-c81ca2a5a3c1                     0.0
# 5aa6c870-9d40-508f-abcb-ec0fd7ea5818                     0.0

# %%
len(df_similar_lee)
# Out:
# 16

# %%
# MERGING only on the year, 1-many 
master2 = pd.merge(df_similar_lee, df_similar_ws, indicator=True, how='inner', left_on=['pass_year'], right_on = ['year'])

# Drop duplicate Korean name, Chinese name, and exam year, then rename those columns to be clearer
master2 = master2.drop(columns=['namehg1', 'namehj1', 'year'])
master2 = master2.rename(columns={'korname':'kor_name', 'chnname':'chi_name'})

len(master2), len(master2['lee_uuid'].unique()), len(master2['ws_uuid'].unique())
# Out:
# (16, 16, 16)

# %%
# Merge these with master
frames = [master, master2]
master = pd.concat(frames, sort=False)

merge7 = master.copy()

# %%
# Update these values: 142 Left
lee_unmerged = data_lee[~data_lee['lee_uuid'].isin(master['lee_uuid'].unique())]
ws_unmerged = data_ws[~data_ws['ws_uuid'].isin(master['ws_uuid'].unique())]
len(ws_unmerged),len(lee_unmerged)
# Out:
# (142, 678)

# %% [markdown]
# ## `merge8` Merge Many-to-Many based on the most similar name for each name. Need to revisit this section based on HOW similar these names ACTUALLY are after having domain expert tell me so

# %%
master = merge7

# %%
len(ws_unmerged),len(lee_unmerged)
# Out:
# (142, 678)

# %%
ws_unique_years_remaining = ws_unmerged['year'].unique()
len(ws_unique_years_remaining)
# Out:
# 62

# %%
ws_unique_years_remaining
# Out:
# array([1435.,   nan, 1466., 1486., 1492., 1507., 1514., 1519., 1552.,
#        1553., 1556., 1572., 1579., 1583., 1594., 1597., 1603., 1605.,
#        1606., 1612., 1613., 1616., 1624., 1630., 1635., 1648., 1650.,
#        1663., 1666., 1675., 1676., 1678., 1680., 1691., 1702., 1705.,
#        1721., 1722., 1723., 1727., 1735., 1739., 1744., 1752., 1754.,
#        1756., 1761., 1763., 1766., 1768., 1774., 1775., 1786., 1789.,
#        1792., 1795., 1815., 1825., 1865., 1870., 1887., 1891.])

# %%
ws_unmerged[ws_unmerged['year'] == 1870][['namehg1', 'namehj1', 'repeated_testtaker_ws']]
# Out:
#                                      namehg1 namehj1  repeated_testtaker_ws
# uuid
# a63670da-c7fe-58cc-a9d2-2194cd4a7dba     백악흥     白樂興                  False
# 4af84ca3-781c-5dc1-b1da-f82c84827a1f     신종구     愼鍾龜                  False

# %%
lee_unmerged[lee_unmerged['pass_year'] == 1870][['korname', 'chnname', 'repeated_testtaker_lee']]
# Out:
#                                      korname chnname  repeated_testtaker_lee
# uuid
# bdda417a-35a9-5e2e-bcab-54d87962f399     신종귀     愼鍾龜                   False
# cbb481c4-427e-5b6e-97aa-4b8493f500b1     백낙흥     白樂興                   False

# %%
pd.set_option('display.max_rows', 10)

# %%
lee_persons = lee_unmerged[(lee_unmerged['pass_year'] == year)].copy()
lee_persons.drop
# Out:
# <bound method DataFrame.drop of                                                                   lee_uuid  \
# uuid
# 646e87be-8e55-52e9-9fb0-70ff31998fac  646e87be-8e55-52e9-9fb0-70ff31998fac
# 0f5f5bce-06b4-5fda-bf73-626d26da0617  0f5f5bce-06b4-5fda-bf73-626d26da0617
#
#                                       pass_year korname chnname  \
# uuid
# 646e87be-8e55-52e9-9fb0-70ff31998fac       1891     황낙성     黃樂成
# 0f5f5bce-06b4-5fda-bf73-626d26da0617       1891     박예양     朴澧陽
#
#                                       repeated_testtaker_lee
# uuid
# 646e87be-8e55-52e9-9fb0-70ff31998fac                   False
# 0f5f5bce-06b4-5fda-bf73-626d26da0617                   False  >

# %%
df_similar_lee = pd.DataFrame([])
df_similar_ws = pd.DataFrame([])

# Find 1-1 mappings between the two 
# All of the 1-1 Mappings are the same person except for the year 1935. 

for year in ws_unique_years_remaining:

    ws_persons = ws_unmerged[(ws_unmerged['year'] == year)]
    lee_persons = lee_unmerged[(lee_unmerged['pass_year'] == year)]

    for ws_index, ws_row in ws_persons.iterrows():

        # Find the Lee person who is the closest 
        kr_highest = 0
        ch_highest = 0
        
        temp = pd.DataFrame([])
        for lee_index, lee_row in lee_persons.iterrows():
#             print(lee_persons)
            kr_similarity = similar(ws_row['namehg1'].replace('구', '귀'), lee_row['korname'])
            ch_similarity = similar(ws_row['namehj1'], lee_row['chnname'])
        
            if (kr_similarity >= 0.5 and ch_similarity >= 0.5):
                temp = temp.append([{'kr_similarity': kr_similarity,
                                 'ch_similarity': ch_similarity,
                                 'ws_korname': ws_row['namehg1'],
                                 'lee_korname': lee_row['korname'],
                                 'ws_chnname': ws_row['namehj1'],
                                 'lee_chnname': lee_row['chnname'],
                                 'lee_person': lee_row
                                }])
                # Remove this lee_row from lee_persons
#                 print(lee_index)
                lee_persons.drop(index=lee_index)
                
        if not temp.empty:
            temp = temp.reset_index(drop=True)
            tempmax = temp.loc[temp['kr_similarity'].idxmax()]
#             print(temp.max())
#             print(year, tempmax)

            row_copy = tempmax['lee_person'].copy()
            row_copy['other_kor_name_in_WS_version'] = ws_row['namehg1']
            row_copy['other_chi_name_in_WS_version'] = ws_row['namehj1']
            row_copy['other_kor_name_in_WS_version_uuid'] = ws_row["ws_uuid"]
            row_copy['other_chi_name_in_WS_version_uuid'] = ws_row["ws_uuid"]
            
            ws_copy = ws_row.copy()
            ws_copy['other_kor_name_in_Lee_version'] = row_copy['korname']
            
            df_similar_lee = df_similar_lee.append(row_copy)
            df_similar_ws = df_similar_ws.append(ws_copy)

# %%
# count

# %% [markdown]
# ### NOTE: May need someone to manually check that these are the same person, but they look the same to me...

# %%
# namecheck = df_similar_lee[['pass_year', 'korname','other_kor_name_in_WS_version', 'chnname', 'other_chi_name_in_WS_version', 'repeated_testtaker_lee', 'lee_uuid']].sort_values(by='pass_year')
# namecheck.to_csv('namecheck.csv')

# %%
# NOTE: I am going to merge these for now.

# %%
pd.set_option('display.max_rows', None)
df_similar_lee[['pass_year', 'korname','other_kor_name_in_WS_version', 'chnname', 'other_chi_name_in_WS_version', 'repeated_testtaker_lee', 'lee_uuid']].sort_values(by='pass_year')
# Out:
#                                       pass_year korname  \
# 0e0499fc-6df4-55a3-9d82-cd005ac1feef     1466.0      김귀
# adfd0902-7579-5e49-9054-5b57818193eb     1486.0     변희효
# bdc87d0b-2e57-50c8-aec0-b53b9a99ea84     1492.0     강숙돌
# 5da21798-30c7-54ed-8156-1e0d6ad8a2c1     1492.0      이귀
# b5886799-19aa-5d80-b7b0-d34db467f368     1507.0     박귀원
# f0cf27a4-e2e4-53fb-8a0e-3dab60b2b3bf     1507.0      조삼
# 52ef0959-dcbd-5aff-bef2-5de97b8bf341     1514.0     최희삼
# c8879ecf-b35a-5c71-97d6-7f138ae0843e     1514.0     이귀영
# 70cf46a8-d110-5c1f-bf7f-602f7bc90638     1519.0     김희열
# 3bf50186-81a5-50b1-858c-7f760d03c7b0     1519.0      이기
# ec0d4b80-b0a8-56f5-b0ce-f5fe3d7ffa60     1552.0     이귀수
# d49781e9-1f45-5d81-9a3f-1094bc408623     1552.0     황삼성
# ae1c6771-1747-52e9-8319-3cb950bd1836     1553.0      송거
# db9b5731-0c99-5d9e-8f05-875d9ecb1cab     1553.0     한세해
# 87ce1804-0b38-514b-9b7e-970d21fda5fb     1556.0      유기
# ac95c643-e08e-552a-9096-46a26ebfa26e     1556.0      임책
# af79f7d0-e60e-5ae2-b9c0-50e9cf5eba30     1572.0     여응귀
# 835da0e5-24ae-536c-a603-6fe643da1bfa     1579.0     홍이상
# 1186c14f-fbae-5708-891b-0e6d73e20391     1579.0     김응귀
# 66815424-350a-5eff-b9e9-f40132021c71     1583.0      이괵
# c9ad2a93-c0c5-5002-8b9a-0052d1a1b061     1583.0     박몽열
# 58df55a4-a9a3-5ca6-81fa-f91bbefdc2b0     1594.0     박동열
# ec4a8013-efe1-5fbd-9925-d30dab414523     1594.0      정혹
# 007663f1-f2c5-5381-aea5-62781d814cfd     1597.0      허적
# d66e32e6-095e-5f9d-a79b-2e85f3a6b72a     1597.0     양몽열
# da6fa8df-76d7-5f50-9a17-fbafd1e0ecb1     1603.0      박한
# 6b64cf75-af4c-5d83-8a6d-e8f2d0af1c40     1603.0     김의민
# a88eb92c-07d5-5120-9c42-9506082bd9a4     1605.0      이진
# 563a2d19-d811-5f1c-a1a9-13533ff85611     1605.0      한언
# 447318fc-7ff0-5101-ac1b-06d5a46ad657     1606.0      허실
# 89d57c01-598a-5f0b-b1fa-9a68646ee540     1606.0     정명열
# 6a5ab210-f043-547d-acd0-2e610a2db27a     1612.0     신이우
# 45eca6d9-e752-559c-a125-d66001acd563     1612.0     권성오
# 2723f754-ca5f-5ec6-996c-da16754d7d65     1613.0     남성신
# 315a1e3a-36e9-5e8b-8696-bf34381a6514     1613.0      임동
# 8ecacacb-c7c3-5e19-980d-89edc09d70e0     1616.0     윤좌벽
# 51a9070f-1d7d-51e5-aa45-cba4a09634a0     1616.0      신기
# ec4a8013-efe1-5fbd-9925-d30dab414523                           정곡      鄭㷤
# 007663f1-f2c5-5381-aea5-62781d814cfd                           허해      許𥛚
# d66e32e6-095e-5f9d-a79b-2e85f3a6b72a                          양몽설     梁夢說
# da6fa8df-76d7-5f50-9a17-fbafd1e0ecb1                           박간      朴𤥚
# 6b64cf75-af4c-5d83-8a6d-e8f2d0af1c40                          전의민     金義民
# a88eb92c-07d5-5120-9c42-9506082bd9a4                           이전      李瑱
# 563a2d19-d811-5f1c-a1a9-13533ff85611                           한업      韓琂
# 447318fc-7ff0-5101-ac1b-06d5a46ad657                           허포      許宲
# 89d57c01-598a-5f0b-b1fa-9a68646ee540                          정명설     丁鳴說
# 6a5ab210-f043-547d-acd0-2e610a2db27a                          신역우     申易于
# 45eca6d9-e752-559c-a125-d66001acd563                          권생오     權省吾
# 2723f754-ca5f-5ec6-996c-da16754d7d65                          남생신     南省身
# 315a1e3a-36e9-5e8b-8696-bf34381a6514                           임연      林埬
# 8ecacacb-c7c3-5e19-980d-89edc09d70e0                          윤좌피     尹左辟
# 51a9070f-1d7d-51e5-aa45-cba4a09634a0                           신계      申垍
# 4887bf9a-c584-5e76-972c-6f6ad26716ae                          심동구     沈東龜
# 6db3120e-f986-550c-aaf5-d74aaae5c328                          강봉현     姜鳳覽
# 2e66ac37-a640-5fa2-8996-29535f2e786a                           오박      吳竱
# 9f4a9657-d7fb-595c-abae-668a9c6248c6                           이척      李崵
# 58bdad43-7983-5ba4-9d4e-4fdc7b11ce19                          노인전     盧仁瑱
# 66ba9607-3686-5d23-8b54-da17b19c1c4d                          채성구     蔡聖龜
# a46c3d94-c08c-5ddb-8109-24c86eab2efd                           이신      李垶
# a46c3d94-c08c-5ddb-8109-24c86eab2efd                           이예      李垶
# 7c284df1-9cbd-556c-b089-a96e2be391e3                          윤득설     尹得說
# 90c3498b-2cda-52e2-b9bb-c8e352eee7d0                          강시생     康時省
# fd736942-ad20-5d11-a7de-f2813a8155a5                           이선      李䆄
# cb3e8608-ff5f-5244-9dbf-980cb0a58a1e                          조구석     趙龜錫
# 86e16d5c-4b96-5a71-a1b8-e47411dcdfce                          홍성구     洪聖龜
# 3db74ca6-2719-50e6-966a-2721ebdc3992                          이시생     李時省
# 7f87f882-4ea6-5081-95ee-d5af44859318                          홍석구     洪錫龜
# 59c6e9de-5f32-5f48-a93f-31b1ecd64a98                           유천      柳梴
# 78259dfb-4fff-5d0d-a320-4afbb3a34e0c                          노의지     盧說之
# d940793a-b564-5316-8b66-d62fb34f4a29                           오의      吳嶷
# ceca811e-fbad-5457-98f2-43977acc1758                           권설      權說
# c6ee1211-5bdd-5668-91e5-73930d6e3a42                          김일생     金日省
# cc878fb8-e23d-5ce5-8812-88e2a5221109                          홍유구     洪有龜
# 02b07ad6-55a4-5ae4-abee-4b2b8c9e126e                          이징구     李徵龜
# 642b5594-6d64-5f18-84db-683c463aecc1                          이태구     李泰龜
# b5886799-19aa-5d80-b7b0-d34db467f368                          朴龜元
# f0cf27a4-e2e4-53fb-8a0e-3dab60b2b3bf                           趙參
# 52ef0959-dcbd-5aff-bef2-5de97b8bf341                          崔希參
# c8879ecf-b35a-5c71-97d6-7f138ae0843e                          李龜齡
# 70cf46a8-d110-5c1f-bf7f-602f7bc90638                          金希說
# 3bf50186-81a5-50b1-858c-7f760d03c7b0                            李
# ec0d4b80-b0a8-56f5-b0ce-f5fe3d7ffa60                          李龜壽
# d49781e9-1f45-5d81-9a3f-1094bc408623                          黃三省
# ae1c6771-1747-52e9-8319-3cb950bd1836                            宋
# db9b5731-0c99-5d9e-8f05-875d9ecb1cab                          崔世瀣
# 87ce1804-0b38-514b-9b7e-970d21fda5fb                            柳
# ac95c643-e08e-552a-9096-46a26ebfa26e                            林
# af79f7d0-e60e-5ae2-b9c0-50e9cf5eba30                          呂應龜
# 835da0e5-24ae-536c-a603-6fe643da1bfa                          洪麟祥
# 1186c14f-fbae-5708-891b-0e6d73e20391                          金應龜
# 66815424-350a-5eff-b9e9-f40132021c71                            李
# c9ad2a93-c0c5-5002-8b9a-0052d1a1b061                          朴夢說
# 58df55a4-a9a3-5ca6-81fa-f91bbefdc2b0                          朴東說
# ec4a8013-efe1-5fbd-9925-d30dab414523                            鄭
# 007663f1-f2c5-5381-aea5-62781d814cfd                            許
# d66e32e6-095e-5f9d-a79b-2e85f3a6b72a                          梁夢說
# da6fa8df-76d7-5f50-9a17-fbafd1e0ecb1                            朴
# 6b64cf75-af4c-5d83-8a6d-e8f2d0af1c40                          全義民
# a88eb92c-07d5-5120-9c42-9506082bd9a4                            李
# 563a2d19-d811-5f1c-a1a9-13533ff85611                            韓
# 447318fc-7ff0-5101-ac1b-06d5a46ad657                            許
# 89d57c01-598a-5f0b-b1fa-9a68646ee540                          丁鳴說
# 6a5ab210-f043-547d-acd0-2e610a2db27a                          申易于
# 45eca6d9-e752-559c-a125-d66001acd563                          權省吾
# 2723f754-ca5f-5ec6-996c-da16754d7d65                          南省身
# 315a1e3a-36e9-5e8b-8696-bf34381a6514                            林
# 8ecacacb-c7c3-5e19-980d-89edc09d70e0                           尹左
# 51a9070f-1d7d-51e5-aa45-cba4a09634a0                            申
# 4887bf9a-c584-5e76-972c-6f6ad26716ae                          沈東龜
# 6db3120e-f986-550c-aaf5-d74aaae5c328                          姜鳳賢
# 2e66ac37-a640-5fa2-8996-29535f2e786a                            吳
# 9f4a9657-d7fb-595c-abae-668a9c6248c6                            李
# 58bdad43-7983-5ba4-9d4e-4fdc7b11ce19                           盧仁
# 66ba9607-3686-5d23-8b54-da17b19c1c4d                          蔡聖龜
# a46c3d94-c08c-5ddb-8109-24c86eab2efd                            李
# a46c3d94-c08c-5ddb-8109-24c86eab2efd                            李
# 7c284df1-9cbd-556c-b089-a96e2be391e3                          尹得說
# 90c3498b-2cda-52e2-b9bb-c8e352eee7d0                          康時省
# fd736942-ad20-5d11-a7de-f2813a8155a5                            李
# a46c3d94-c08c-5ddb-8109-24c86eab2efd     1635.0      이성
#
#                                      other_kor_name_in_WS_version chnname  \
# a46c3d94-c08c-5ddb-8109-24c86eab2efd                           이신      李垶
# a46c3d94-c08c-5ddb-8109-24c86eab2efd                           이예      李垶
#
#                                      other_chi_name_in_WS_version  \
# a46c3d94-c08c-5ddb-8109-24c86eab2efd                            李
# a46c3d94-c08c-5ddb-8109-24c86eab2efd                            李
#
#                                       repeated_testtaker_lee  \
# a46c3d94-c08c-5ddb-8109-24c86eab2efd                     0.0
# a46c3d94-c08c-5ddb-8109-24c86eab2efd                     0.0
#
#                                                                   lee_uuid
# a46c3d94-c08c-5ddb-8109-24c86eab2efd  a46c3d94-c08c-5ddb-8109-24c86eab2efd
# a46c3d94-c08c-5ddb-8109-24c86eab2efd  a46c3d94-c08c-5ddb-8109-24c86eab2efd

# %%
# MERGING only on the year, 1-many ; and also the Korean name that we determined was most similar
master2 = pd.merge(df_similar_lee, df_similar_ws, indicator=True, how='inner', left_on=['pass_year', 'korname'], right_on = ['year', 'other_kor_name_in_Lee_version'])

# Drop duplicate Korean name, Chinese name, and exam year, then rename those columns to be clearer
master2 = master2.drop(columns=['namehg1', 'namehj1', 'year'])
master2 = master2.rename(columns={'korname':'kor_name', 'chnname':'chi_name'})

len(master2), len(master2['lee_uuid'].unique()), len(master2['ws_uuid'].unique())
# Out:
# (134, 131, 132)

# %% [markdown]
# I will just drop all four of these because these duplicates are annoying and get in the way right now

# %%
master2[master2.duplicated(['ws_uuid'], keep=False)][['pass_year', 'kor_name','other_kor_name_in_WS_version', 'chi_name', 'other_chi_name_in_WS_version', 'repeated_testtaker_lee', 'lee_uuid', 'ws_uuid']].sort_values(by='pass_year')
# Out:
#     pass_year kor_name other_kor_name_in_WS_version chi_name  \
# 43     1635.0       이성                           이신       李垶
# 44     1635.0       이성                           이신       李垶
# 45     1635.0       이성                           이예       李垶
# 46     1635.0       이성                           이예       李垶
#
#    other_chi_name_in_WS_version  repeated_testtaker_lee  \
# 43                            李                     0.0
# 44                            李                     0.0
# 45                            李                     0.0
# 46                            李                     0.0
#
#                                 lee_uuid                               ws_uuid
# 43  a46c3d94-c08c-5ddb-8109-24c86eab2efd  2202ff57-a1dd-522f-befe-078025b63fcb
# 44  a46c3d94-c08c-5ddb-8109-24c86eab2efd  e935f2a7-258d-506b-ab77-e57a3685c3ad
# 45  a46c3d94-c08c-5ddb-8109-24c86eab2efd  2202ff57-a1dd-522f-befe-078025b63fcb
# 46  a46c3d94-c08c-5ddb-8109-24c86eab2efd  e935f2a7-258d-506b-ab77-e57a3685c3ad

# %%
master2 = master2.drop([43, 44, 45, 46])

# %%
master2[master2.duplicated(['ws_uuid'], keep=False)][['pass_year', 'kor_name','other_kor_name_in_WS_version', 'chi_name', 'other_chi_name_in_WS_version', 'repeated_testtaker_lee', 'lee_uuid', 'ws_uuid']].sort_values(by='pass_year')
# Out:
# Empty DataFrame
# Columns: [pass_year, kor_name, other_kor_name_in_WS_version, chi_name, other_chi_name_in_WS_version, repeated_testtaker_lee, lee_uuid, ws_uuid]
# Index: []

# %%
# Merge these with master
frames = [master, master2]
master = pd.concat(frames, sort=False)

merge8 = master.copy()

# %%
# Update these values: 12 Left
lee_unmerged = data_lee[~data_lee['lee_uuid'].isin(master['lee_uuid'].unique())]
ws_unmerged = data_ws[~data_ws['ws_uuid'].isin(master['ws_uuid'].unique())]
len(ws_unmerged),len(lee_unmerged)
# Out:
# (12, 548)

# %% [markdown]
# ## `merge9` - Manual Merge!

# %%
master = merge8

# %%
len(ws_unmerged),len(lee_unmerged), len(master)
# Out:
# (12, 548, 14622)

# %%
14622 + 548 + 12
# Out:
# 15182

# %%
master = master.filter(['lee_uuid', 'ws_uuid'])

# %% [markdown]
# For the ones that do not match, just add them with the corresponding uuid, and leave the other uuid blank

# %%
ws_unmerged_filter = ws_unmerged.filter(['ws_uuid'])
ws_unmerged_filter["lee_uuid"] = None

lee_unmerged_filter = lee_unmerged.filter(['lee_uuid'])
lee_unmerged_filter["ws_uuid"] = None

# %%
len(ws_unmerged_filter), len(lee_unmerged_filter)
# Out:
# (12, 548)

# %%
# Merge these with master
frames = [master, ws_unmerged_filter, lee_unmerged_filter]
master = pd.concat(frames, sort=False)

merge9 = master.copy()

# %%
len(master)
# Out:
# 15182

# %% [markdown]
# # Clean up Master

# %%
len(master)
# Out:
# 15182

# %%
master = master.reset_index(drop=True)

# %% [markdown]
# Last thing - each thing in master table gets an ID

# %%
master['uuid'] = [uuid.uuid4() for _ in range(len(master.index))]
master = master.set_index('uuid')

# %%
master.head()
# Out:
#                                                                   lee_uuid  \
# uuid
# 89aa92b3-4343-420d-8d0b-2c648e24ce57  4b854af7-3d4b-51c9-802e-117ff4825291
# 2e90dc82-5b92-4762-a1f4-aadcc0761b7e  8a1e8a21-4d10-5ae3-b92d-51acfbb31ba6
# defd7e17-7e15-457e-99f6-de7602627700  fecc75c4-0045-5485-b47c-851767e002e3
# 3b7d01b1-4ffc-4648-9fbe-2afd3467d6db  8688b608-b1fb-55ab-a77e-a10268ac80af
# 4d4981e8-d1be-487f-baf1-d98155806432  46963c7a-bb8b-52f1-a06a-f128133fe0ab
#
#                                                                    ws_uuid
# uuid
# 89aa92b3-4343-420d-8d0b-2c648e24ce57  660a2a20-d407-5ad0-b364-cd9e7edbb82c
# 2e90dc82-5b92-4762-a1f4-aadcc0761b7e  85fe658e-5b35-50b1-a41b-aeb916ae13bb
# defd7e17-7e15-457e-99f6-de7602627700  9b6c41ef-f960-5856-9a25-99c0f379e59f
# 3b7d01b1-4ffc-4648-9fbe-2afd3467d6db  ceff916a-aab9-58f5-a84e-9f424a5587f0
# 4d4981e8-d1be-487f-baf1-d98155806432  eb3b33fc-139f-5a8e-952e-c26a1c7b0b48

# %%
len(master['lee_uuid'].unique()), len(master['ws_uuid'].unique()), len(master)
# Out:
# (15152, 14608, 15182)

# %%
# Export
master.to_csv('/Users/yenniejun/Documents/code/JoseonMunkwa/data/Merged_Munkwa.csv')
